# %% [markdown]
# ## 📘 Section A：基礎操作（第 1-10 題）
#
# 本節涵蓋 Dictionary 的基礎操作：
# - 建立字典
# - 讀取資料
# - 使用 get() 安全查詢
# - 新增和更新資料
# - 檢查長度和 key 是否存在
# - 使用 keys()、values()、items()
#
# ---

# %% [markdown]
# ### 練習 01：建立空字典
#
# **題目**：請使用兩種方法建立空字典，並印出它們的型別。
#
# **要求**：
# 1. 使用 `{}` 建立空字典 `d1`
# 2. 使用 `dict()` 建立空字典 `d2`
# 3. 分別印出 `d1` 和 `d2` 的內容與型別
#
# **預期輸出**：
# ```
# d1: {}
# d1 型別: <class 'dict'>
# d2: {}
# d2 型別: <class 'dict'>
# ```

# %%
# TODO: 練習 01
# 1. 使用 {} 建立 d1


# 2. 使用 dict() 建立 d2


# 3. 印出 d1 和 d2 的內容與型別

# %% [markdown]
# ### 練習 02：建立並讀取字典
#
# **題目**：建立一個學生資料字典，並讀取特定資料。
#
# **要求**：
# 1. 建立字典 `student`，包含以下資料：
#    - name: 'Alice'
#    - age: 20
#    - grade: 'A'
# 2. 使用 `student['name']` 印出學生姓名
# 3. 使用 `student['age']` 印出學生年齡
#
# **預期輸出**：
# ```
# 姓名: Alice
# 年齡: 20
# ```

# %%
# TODO: 練習 02
# 1. 建立 student 字典


# 2. 印出姓名


# 3. 印出年齡

# %% [markdown]
# ### 練習 03：使用 get() 避免錯誤
#
# **題目**：使用 `get()` 方法安全地查詢字典中不存在的 key。
#
# **已知資料**：
# ```python
# product = {'name': 'iPhone', 'price': 30000, 'brand': 'Apple'}
# ```
#
# **要求**：
# 1. 使用 `get()` 查詢 `'stock'` 這個 key（不存在）
# 2. 如果不存在，讓它回傳 `0`
# 3. 印出結果
#
# **預期輸出**：
# ```
# 庫存數量: 0
# ```

# %%
# TODO: 練習 03
product = {'name': 'iPhone', 'price': 30000, 'brand': 'Apple'}

# 使用 get() 查詢 stock，預設值為 0


# 印出庫存數量

# %% [markdown]
# ### 練習 04：get() 與直接查詢的差異
#
# **題目**：比較使用 `d[key]` 和 `d.get(key)` 的差異。
#
# **已知資料**：
# ```python
# capitals = {'台灣': '台北', '日本': '東京', '韓國': '首爾'}
# ```
#
# **要求**：
# 1. 使用 `get()` 查詢 `'美國'`（不存在），預設回傳 `'查無此國家'`
# 2. 印出結果
# 3. **進階思考**：如果改用 `capitals['美國']` 會發生什麼事？（可註解測試）
#
# **預期輸出**：
# ```
# 美國的首都: 查無此國家
# ```

# %%
# TODO: 練習 04
capitals = {'台灣': '台北', '日本': '東京', '韓國': '首爾'}

# 使用 get() 查詢美國，預設值為 '查無此國家'


# 進階：測試直接查詢會發生什麼（可註解）
# print(capitals['美國'])  # 會引發 KeyError

# %% [markdown]
# ### 練習 05：新增資料
#
# **題目**：在現有字典中新增資料。
#
# **已知資料**：
# ```python
# user = {'username': 'john123', 'email': 'john@example.com'}
# ```
#
# **要求**：
# 1. 新增 `'age'` 為 `25`
# 2. 新增 `'city'` 為 `'Taipei'`
# 3. 印出完整的 `user` 字典
#
# **預期輸出**：
# ```
# {'username': 'john123', 'email': 'john@example.com', 'age': 25, 'city': 'Taipei'}
# ```

# %%
# TODO: 練習 05
user = {'username': 'john123', 'email': 'john@example.com'}

# 新增 age 和 city


# 印出完整字典

# %% [markdown]
# ### 練習 06：更新資料
#
# **題目**：更新字典中已存在的資料。
#
# **已知資料**：
# ```python
# scores = {'Alice': 85, 'Bob': 70, 'Cindy': 92}
# ```
#
# **要求**：
# 1. 將 Bob 的成績從 70 更新為 75
# 2. 將 Alice 的成績從 85 更新為 90
# 3. 印出更新後的 `scores` 字典
#
# **預期輸出**：
# ```
# {'Alice': 90, 'Bob': 75, 'Cindy': 92}
# ```

# %%
# TODO: 練習 06
scores = {'Alice': 85, 'Bob': 70, 'Cindy': 92}

# 更新 Bob 和 Alice 的成績


# 印出更新後的字典

# %% [markdown]
# ### 練習 07：使用 len() 計算字典大小
#
# **題目**：計算字典中有幾個 key-value 配對。
#
# **已知資料**：
# ```python
# inventory = {'apple': 50, 'banana': 30, 'orange': 45, 'grape': 20}
# ```
#
# **要求**：
# 1. 使用 `len()` 計算 `inventory` 有幾種商品
# 2. 印出結果（格式：「庫存中有 X 種商品」）
#
# **預期輸出**：
# ```
# 庫存中有 4 種商品
# ```

# %%
# TODO: 練習 07
inventory = {'apple': 50, 'banana': 30, 'orange': 45, 'grape': 20}

# 計算商品種類數量


# 印出結果

# %% [markdown]
# ### 練習 08：使用 in 檢查 key 是否存在
#
# **題目**：檢查特定的 key 是否存在於字典中。
#
# **已知資料**：
# ```python
# menu = {'pizza': 200, 'burger': 150, 'pasta': 180}
# ```
#
# **要求**：
# 1. 檢查 `'pizza'` 是否在 `menu` 中，印出 `True` 或 `False`
# 2. 檢查 `'steak'` 是否在 `menu` 中，印出 `True` 或 `False`
# 3. 使用 `if` 判斷：如果 `'burger'` 在 menu 中，印出「有漢堡」
#
# **預期輸出**：
# ```
# pizza 在菜單中: True
# steak 在菜單中: False
# 有漢堡
# ```

# %%
# TODO: 練習 08
menu = {'pizza': 200, 'burger': 150, 'pasta': 180}

# 檢查 pizza 是否存在


# 檢查 steak 是否存在


# 使用 if 判斷 burger

# %% [markdown]
# ### 練習 09：使用 keys()、values()、items()
#
# **題目**：分別印出字典的所有 key、所有 value、以及所有 key-value 配對。
#
# **已知資料**：
# ```python
# colors = {'red': '紅色', 'blue': '藍色', 'green': '綠色'}
# ```
#
# **要求**：
# 1. 印出所有的 key（使用 `keys()`）
# 2. 印出所有的 value（使用 `values()`）
# 3. 印出所有的 key-value 配對（使用 `items()`）
#
# **預期輸出**：
# ```
# 所有的 key: dict_keys(['red', 'blue', 'green'])
# 所有的 value: dict_values(['紅色', '藍色', '綠色'])
# 所有的配對: dict_items([('red', '紅色'), ('blue', '藍色'), ('green', '綠色')])
# ```

# %%
# TODO: 練習 09
colors = {'red': '紅色', 'blue': '藍色', 'green': '綠色'}

# 印出所有的 key


# 印出所有的 value


# 印出所有的配對

# %% [markdown]
# ### 練習 10：轉換 keys、values 為 list
#
# **題目**：將字典的 keys 和 values 轉換為 list。
#
# **已知資料**：
# ```python
# grades = {'math': 95, 'english': 88, 'science': 92}
# ```
#
# **要求**：
# 1. 將 `grades.keys()` 轉換為 list，存入變數 `subjects`
# 2. 將 `grades.values()` 轉換為 list，存入變數 `scores`
# 3. 分別印出 `subjects` 和 `scores`
#
# **預期輸出**：
# ```
# 科目: ['math', 'english', 'science']
# 分數: [95, 88, 92]
# ```

# %%
# TODO: 練習 10
grades = {'math': 95, 'english': 88, 'science': 92}

# 轉換 keys 為 list


# 轉換 values 為 list


# 印出結果

# %% [markdown]
# ---
#
# ## 📗 Section B：實作操作（第 11-20 題）
#
# 本節涵蓋 Dictionary 的實作操作：
# - 刪除資料（del / pop）
# - 使用 for 迴圈走訪字典
# - 計算 values 的加總和平均
# - 字典的相等性比較
# - list of dict 的操作
#
# 💡 **提示**：這部分開始會需要結合 for 迴圈和條件判斷，記得先思考邏輯再動手寫！
#
# ---

# %% [markdown]
# ### 練習 11：使用 del 刪除資料
#
# **題目**：使用 `del` 刪除字典中的特定資料。
#
# **已知資料**：
# ```python
# cart = {'apple': 3, 'banana': 2, 'orange': 5, 'grape': 1}
# ```
#
# **要求**：
# 1. 刪除 `'grape'`（使用 `del`）
# 2. 刪除 `'banana'`（使用 `del`）
# 3. 印出刪除後的 `cart` 字典
#
# **預期輸出**：
# ```
# {'apple': 3, 'orange': 5}
# ```

# %%
# TODO: 練習 11
cart = {'apple': 3, 'banana': 2, 'orange': 5, 'grape': 1}

# 刪除 grape 和 banana


# 印出刪除後的字典

# %% [markdown]
# ### 練習 12：使用 pop() 刪除並取得值
#
# **題目**：使用 `pop()` 刪除資料並取得被刪除的值。
#
# **已知資料**：
# ```python
# settings = {'volume': 80, 'brightness': 70, 'language': 'zh-TW'}
# ```
#
# **要求**：
# 1. 使用 `pop()` 刪除 `'brightness'`，並將回傳值存入變數 `old_brightness`
# 2. 印出 `old_brightness` 的值
# 3. 印出刪除後的 `settings` 字典
#
# **預期輸出**：
# ```
# 原亮度: 70
# 刪除後: {'volume': 80, 'language': 'zh-TW'}
# ```

# %%
# TODO: 練習 12
settings = {'volume': 80, 'brightness': 70, 'language': 'zh-TW'}

# 使用 pop() 刪除 brightness 並取得值


# 印出原亮度


# 印出刪除後的字典

# %% [markdown]
# ### 練習 13：使用 for 走訪字典的 key
#
# **題目**：使用 for 迴圈走訪字典，印出每個 key 和對應的 value。
#
# **已知資料**：
# ```python
# fruits = {'apple': 50, 'banana': 30, 'orange': 40}
# ```
#
# **要求**：
# 1. 使用 `for key in fruits:` 走訪字典
# 2. 在迴圈內印出每個水果的名稱和價格（格式：「apple: 50元」）
#
# **預期輸出**：
# ```
# apple: 50元
# banana: 30元
# orange: 40元
# ```

# %%
# TODO: 練習 13
fruits = {'apple': 50, 'banana': 30, 'orange': 40}

# 使用 for 走訪並印出

# %% [markdown]
# ### 練習 14：使用 items() 走訪字典
#
# **題目**：使用 `items()` 方法同時取得 key 和 value。
#
# **已知資料**：
# ```python
# countries = {'Taiwan': 'Taipei', 'Japan': 'Tokyo', 'Korea': 'Seoul'}
# ```
#
# **要求**：
# 1. 使用 `for country, capital in countries.items():` 走訪字典
# 2. 印出每個國家和首都（格式：「Taiwan 的首都是 Taipei」）
#
# **預期輸出**：
# ```
# Taiwan 的首都是 Taipei
# Japan 的首都是 Tokyo
# Korea 的首都是 Seoul
# ```

# %%
# TODO: 練習 14
countries = {'Taiwan': 'Taipei', 'Japan': 'Tokyo', 'Korea': 'Seoul'}

# 使用 items() 走訪並印出

# %% [markdown]
# ### 練習 15：計算 values 的總和
#
# **題目**：計算字典中所有 values 的總和。
#
# **已知資料**：
# ```python
# expenses = {'rent': 15000, 'food': 8000, 'transport': 3000, 'entertainment': 2000}
# ```
#
# **要求**：
# 1. 使用 for 迴圈走訪 `expenses.values()`
# 2. 計算所有支出的總和
# 3. 印出總支出金額（格式：「總支出: 28000 元」）
#
# **預期輸出**：
# ```
# 總支出: 28000 元
# ```
#
# 💡 **提示**：也可以使用 `sum(expenses.values())` 一行完成！

# %%
# TODO: 練習 15
expenses = {'rent': 15000, 'food': 8000, 'transport': 3000, 'entertainment': 2000}

# 方法1：使用 for 迴圈


# 方法2：使用 sum()（選做）

# %% [markdown]
# ---
#
# ## 🎯 暫時完成前 15 題
#
# 恭喜你完成了前 15 題練習！
#
# ### 📊 目前進度
# - ✅ Section A：基礎操作（第 1-10 題）
# - ✅ Section B：實作操作（第 11-15 題）
# - ⏳ Section B：實作操作（第 16-20 題）- 待補充
# - ⏳ Section C：進階操作（第 21-30 題）- 待補充
#
# ### 💪 自我檢查
#
# 在進入下一階段前，請確認你已經掌握：
# - [ ] 能夠建立和讀取字典
# - [ ] 知道何時使用 `get()` 而非 `d[key]`
# - [ ] 能夠新增、更新、刪除字典資料
# - [ ] 熟悉 `keys()`、`values()`、`items()` 的用法
# - [ ] 能夠使用 for 迴圈走訪字典
#
# ### 🚀 繼續加油！
#
# 後續 15 題將包含：
# - 計算平均值
# - 字典相等性比較
# - list of dict 操作
# - 巢狀字典
# - 計數器應用
# - dict comprehension
# - 資料清理
# - 綜合專案
#
# ---

# %%
# TODO: 練習 16
test_scores = {'test1': 85, 'test2': 92, 'test3': 78, 'test4': 88, 'test5': 95}

# 計算總和、次數、平均


# 印出平均分數

# %% [markdown]
# ### 練習 17：字典的相等性比較（順序不影響）
#
# **題目**：測試字典的相等性，驗證順序不同但內容相同的字典是否相等。
#
# **要求**：
# 1. 建立 `dict1 = {'a': 1, 'b': 2, 'c': 3}`
# 2. 建立 `dict2 = {'c': 3, 'a': 1, 'b': 2}`（順序不同）
# 3. 建立 `dict3 = {'a': 1, 'b': 2}`（少一個元素）
# 4. 印出 `dict1 == dict2` 的結果
# 5. 印出 `dict1 == dict3` 的結果
#
# **預期輸出**：
# ```
# dict1 == dict2: True
# dict1 == dict3: False
# ```
#
# 💡 **重點**：字典比較時，**順序不重要**，只看 key-value 配對是否相同！

# %%
# TODO: 練習 17
# 建立三個字典


# 比較並印出結果

# %% [markdown]
# ### 練習 18：找出最高分
#
# **題目**：從成績字典中找出最高分及對應的學生姓名。
#
# **已知資料**：
# ```python
# scores = {'Alice': 85, 'Bob': 92, 'Cindy': 78, 'David': 95, 'Eva': 88}
# ```
#
# **要求**：
# 1. 找出最高分數（可使用 `max(scores.values())`）
# 2. 找出獲得最高分的學生姓名
# 3. 印出結果（格式：「最高分: David, 95 分」）
#
# **預期輸出**：
# ```
# 最高分: David, 95 分
# ```
#
# 💡 **提示**：可以用 for 迴圈配合 if 條件找出最高分的學生

# %%
# TODO: 練習 18
scores = {'Alice': 85, 'Bob': 92, 'Cindy': 78, 'David': 95, 'Eva': 88}

# 找出最高分和對應學生


# 印出結果

# %% [markdown]
# ### 練習 19：處理 list of dict（學生資料）
#
# **題目**：處理包含多個字典的 list，印出所有學生資料。
#
# **已知資料**：
# ```python
# students = [
#     {'name': 'Alice', 'age': 20, 'major': 'CS'},
#     {'name': 'Bob', 'age': 21, 'major': 'Math'},
#     {'name': 'Cindy', 'age': 19, 'major': 'Physics'}
# ]
# ```
#
# **要求**：
# 1. 使用 for 迴圈走訪 `students` list
# 2. 對每個學生，印出其資料（格式：「Alice, 20歲, 主修: CS」）
#
# **預期輸出**：
# ```
# Alice, 20歲, 主修: CS
# Bob, 21歲, 主修: Math
# Cindy, 19歲, 主修: Physics
# ```

# %%
# TODO: 練習 19
students = [
    {'name': 'Alice', 'age': 20, 'major': 'CS'},
    {'name': 'Bob', 'age': 21, 'major': 'Math'},
    {'name': 'Cindy', 'age': 19, 'major': 'Physics'}
]

# 走訪 list of dict 並印出

# %% [markdown]
# ### 練習 20：從 list of dict 中篩選資料
#
# **題目**：從學生資料中找出年齡大於等於 20 歲的學生。
#
# **已知資料**：
# ```python
# students = [
#     {'name': 'Alice', 'age': 20},
#     {'name': 'Bob', 'age': 19},
#     {'name': 'Cindy', 'age': 22},
#     {'name': 'David', 'age': 18}
# ]
# ```
#
# **要求**：
# 1. 走訪 students list
# 2. 找出所有 age >= 20 的學生
# 3. 印出符合條件的學生姓名
#
# **預期輸出**：
# ```
# 年齡 >= 20 的學生:
# Alice
# Cindy
# ```

# %%
# TODO: 練習 20
students = [
    {'name': 'Alice', 'age': 20},
    {'name': 'Bob', 'age': 19},
    {'name': 'Cindy', 'age': 22},
    {'name': 'David', 'age': 18}
]

# 篩選並印出年齡 >= 20 的學生
print("年齡 >= 20 的學生:")

# %% [markdown]
# ---
#
# ## 📙 Section C：進階操作（第 21-30 題）
#
# 本節涵蓋 Dictionary 的進階應用：
# - 巢狀字典（nested dict）
# - 使用 get() 實作計數器
# - dict comprehension
# - 資料清理（處理 None、空字串）
# - 綜合應用專案
#
# 💡 **提示**：這部分難度較高，需要結合前面學到的所有技巧。建議先畫圖或寫出邏輯，再開始寫程式！
#
# ---

# %% [markdown]
# ### 練習 21：巢狀字典的讀取
#
# **題目**：從巢狀字典中讀取資料。
#
# **已知資料**：
# ```python
# company = {
#     'name': 'TechCorp',
#     'employees': {
#         'CEO': 'John',
#         'CTO': 'Mary',
#         'CFO': 'David'
#     },
#     'location': 'Taipei'
# }
# ```
#
# **要求**：
# 1. 印出公司名稱
# 2. 印出 CTO 的名字（需要兩層索引：`company['employees']['CTO']`）
# 3. 印出公司地點
#
# **預期輸出**：
# ```
# 公司名稱: TechCorp
# CTO: Mary
# 地點: Taipei
# ```

# %%
# TODO: 練習 21
company = {
    'name': 'TechCorp',
    'employees': {
        'CEO': 'John',
        'CTO': 'Mary',
        'CFO': 'David'
    },
    'location': 'Taipei'
}

# 印出指定資料

# %% [markdown]
# ### 練習 22：巢狀字典的新增與修改
#
# **題目**：在巢狀字典中新增和修改資料。
#
# **已知資料**：
# ```python
# profile = {
#     'username': 'john123',
#     'info': {
#         'email': 'john@example.com',
#         'phone': '0912-345-678'
#     }
# }
# ```
#
# **要求**：
# 1. 在 `info` 中新增 `'city': 'Taipei'`
# 2. 將 `phone` 更新為 `'0987-654-321'`
# 3. 印出完整的 `profile` 字典
#
# **預期輸出**：
# ```python
# {
#     'username': 'john123',
#     'info': {
#         'email': 'john@example.com',
#         'phone': '0987-654-321',
#         'city': 'Taipei'
#     }
# }
# ```

# %%
# TODO: 練習 22
profile = {
    'username': 'john123',
    'info': {
        'email': 'john@example.com',
        'phone': '0912-345-678'
    }
}

# 新增和修改巢狀字典的資料


# 印出完整字典

# %% [markdown]
# ### 練習 23：字串字元計數器（使用 get）
#
# **題目**：統計字串中每個字元出現的次數（不使用 defaultdict，改用 get 方法）。
#
# **已知資料**：
# ```python
# text = "hello"
# ```
#
# **要求**：
# 1. 建立空字典 `counter = {}`
# 2. 使用 for 迴圈走訪 text 中的每個字元
# 3. 使用 `counter[char] = counter.get(char, 0) + 1` 來計數
# 4. 印出 counter 字典
#
# **預期輸出**：
# ```
# {'h': 1, 'e': 1, 'l': 2, 'o': 1}
# ```
#
# 💡 **重點**：`get(key, 0)` 表示如果 key 不存在則回傳 0，避免 KeyError！

# %%
# TODO: 練習 23
text = "hello"
counter = {}

# 使用 for + get() 統計每個字元


# 印出結果

# %% [markdown]
# ### 練習 24：投票統計系統
#
# **題目**：統計投票結果，計算每個候選人得票數。
#
# **已知資料**：
# ```python
# votes = ['Alice', 'Bob', 'Alice', 'Cindy', 'Bob', 'Alice', 'Bob', 'Cindy']
# ```
#
# **要求**：
# 1. 建立空字典 `vote_count = {}`
# 2. 走訪 votes list
# 3. 對每個候選人，使用 `get()` 來累計票數
# 4. 印出每個候選人的得票數
# 5. 找出並印出獲勝者（得票最多的人）
#
# **預期輸出**：
# ```
# 投票結果:
# Alice: 3 票
# Bob: 3 票
# Cindy: 2 票
# 獲勝者: Alice (或 Bob，兩者票數相同)
# ```

# %%
# TODO: 練習 24
votes = ['Alice', 'Bob', 'Alice', 'Cindy', 'Bob', 'Alice', 'Bob', 'Cindy']
vote_count = {}

# 統計票數


# 印出投票結果
print("投票結果:")


# 找出獲勝者

# %% [markdown]
# ### 練習 25：Dict Comprehension 基礎
#
# **題目**：使用 dict comprehension 從 list 建立字典。
#
# **已知資料**：
# ```python
# numbers = [1, 2, 3, 4, 5]
# ```
#
# **要求**：
# 1. 使用 dict comprehension 建立字典，格式為 `{數字: 數字的平方}`
# 2. 例如：`{1: 1, 2: 4, 3: 9, 4: 16, 5: 25}`
# 3. 印出結果
#
# **預期輸出**：
# ```
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# ```
#
# 💡 **語法提示**：`{key: value for item in list}`

# %%
# TODO: 練習 25
numbers = [1, 2, 3, 4, 5]

# 使用 dict comprehension 建立平方字典


# 印出結果

# %% [markdown]
# ### 練習 26：Dict Comprehension 進階（帶條件）
#
# **題目**：使用 dict comprehension 篩選並建立字典。
#
# **已知資料**：
# ```python
# fruits = ['apple', 'banana', 'cherry', 'date', 'elderberry']
# ```
#
# **要求**：
# 1. 使用 dict comprehension 建立字典
# 2. key 為水果名稱，value 為水果名稱的長度
# 3. 只包含長度大於 5 的水果
# 4. 印出結果
#
# **預期輸出**：
# ```
# {'banana': 6, 'cherry': 6, 'elderberry': 10}
# ```
#
# 💡 **語法提示**：`{key: value for item in list if 條件}`

# %%
# TODO: 練習 26
fruits = ['apple', 'banana', 'cherry', 'date', 'elderberry']

# 使用 dict comprehension + 條件篩選


# 印出結果

# %% [markdown]
# ### 練習 27：資料清理 - 移除 None 值
#
# **題目**：清理字典，移除 value 為 None 的項目。
#
# **已知資料**：
# ```python
# data = {'name': 'Alice', 'age': None, 'city': 'Taipei', 'phone': None, 'email': 'alice@example.com'}
# ```
#
# **要求**：
# 1. 建立新字典 `cleaned_data`
# 2. 只保留 value 不是 None 的項目
# 3. 印出清理後的字典
#
# **預期輸出**：
# ```
# {'name': 'Alice', 'city': 'Taipei', 'email': 'alice@example.com'}
# ```
#
# 💡 **提示**：可以用 for + if，或使用 dict comprehension

# %%
# TODO: 練習 27
data = {'name': 'Alice', 'age': None, 'city': 'Taipei', 'phone': None, 'email': 'alice@example.com'}

# 清理資料（移除 None）


# 印出清理後的字典

# %% [markdown]
# ### 練習 28：資料清理 - 移除空字串和 None
#
# **題目**：清理字典，移除 value 為 None 或空字串的項目。
#
# **已知資料**：
# ```python
# form_data = {
#     'username': 'john123',
#     'password': 'secret',
#     'email': '',
#     'phone': None,
#     'address': 'Taipei',
#     'company': ''
# }
# ```
#
# **要求**：
# 1. 建立新字典 `valid_data`
# 2. 只保留 value 不是 None 且不是空字串的項目
# 3. 印出清理後的字典
#
# **預期輸出**：
# ```
# {'username': 'john123', 'password': 'secret', 'address': 'Taipei'}
# ```
#
# 💡 **提示**：條件可以是 `if value is not None and value != ''`

# %%
# TODO: 練習 28
form_data = {
    'username': 'john123',
    'password': 'secret',
    'email': '',
    'phone': None,
    'address': 'Taipei',
    'company': ''
}

# 清理資料（移除 None 和空字串）


# 印出清理後的字典

# %% [markdown]
# ### 練習 29：綜合應用 - 購物車統計
#
# **題目**：統計購物車中每個商品的總價。
#
# **已知資料**：
# ```python
# # 購物車：每筆訂單包含商品名稱和數量
# cart = [
#     {'product': 'apple', 'quantity': 3},
#     {'product': 'banana', 'quantity': 2},
#     {'product': 'apple', 'quantity': 1},
#     {'product': 'orange', 'quantity': 5},
#     {'product': 'banana', 'quantity': 3}
# ]
#
# # 商品價格表
# prices = {'apple': 30, 'banana': 20, 'orange': 25}
# ```
#
# **要求**：
# 1. 計算每個商品的總購買數量（apple 總共買了 4 個）
# 2. 計算每個商品的總金額（數量 × 單價）
# 3. 計算購物車總金額
# 4. 印出結果
#
# **預期輸出**：
# ```
# 商品統計:
# apple: 4 個, 總計 120 元
# banana: 5 個, 總計 100 元
# orange: 5 個, 總計 125 元
# 購物車總金額: 345 元
# ```

# %%
# TODO: 練習 29
cart = [
    {'product': 'apple', 'quantity': 3},
    {'product': 'banana', 'quantity': 2},
    {'product': 'apple', 'quantity': 1},
    {'product': 'orange', 'quantity': 5},
    {'product': 'banana', 'quantity': 3}
]

prices = {'apple': 30, 'banana': 20, 'orange': 25}

# 步驟1: 統計每個商品的總數量


# 步驟2: 計算每個商品的總金額


# 步驟3: 計算購物車總金額


# 印出結果

# %% [markdown]
# ### 練習 30：綜合應用 - 學生成績報表
#
# **題目**：產生學生成績統計報表。
#
# **已知資料**：
# ```python
# students_scores = [
#     {'name': 'Alice', 'math': 85, 'english': 92, 'science': 88},
#     {'name': 'Bob', 'math': 78, 'english': 85, 'science': 90},
#     {'name': 'Cindy', 'math': 92, 'english': 88, 'science': 85},
#     {'name': 'David', 'math': 88, 'english': 90, 'science': 92}
# ]
# ```
#
# **要求**：
# 1. 為每個學生計算總分和平均分
# 2. 找出總分最高的學生
# 3. 計算全班每科的平均分
# 4. 產生報表並印出
#
# **預期輸出**：
# ```
# 個人成績:
# Alice - 總分: 265, 平均: 88.33
# Bob - 總分: 253, 平均: 84.33
# Cindy - 總分: 265, 平均: 88.33
# David - 總分: 270, 平均: 90.0
#
# 最高分學生: David (270 分)
#
# 全班各科平均:
# math: 85.75
# english: 88.75
# science: 88.75
# ```

# %%
# TODO: 練習 30
students_scores = [
    {'name': 'Alice', 'math': 85, 'english': 92, 'science': 88},
    {'name': 'Bob', 'math': 78, 'english': 85, 'science': 90},
    {'name': 'Cindy', 'math': 92, 'english': 88, 'science': 85},
    {'name': 'David', 'math': 88, 'english': 90, 'science': 92}
]

# 步驟1: 計算每個學生的總分和平均


# 步驟2: 找出總分最高的學生


# 步驟3: 計算全班每科平均


# 印出報表

# %% [markdown]
# ---
#
# ## 🎉 恭喜完成全部 30 題！
#
# 你已經完成了所有 Python Dictionary 練習題！
#
# ### 📊 完整進度
# - ✅ Section A：基礎操作（第 1-10 題）
# - ✅ Section B：實作操作（第 11-20 題）
# - ✅ Section C：進階操作（第 21-30 題）
#
# ---
#
# ## 🔍 自我檢查清單
#
# 完成練習後，請確認你已經掌握以下技能：
#
# ### 基礎操作
# - [ ] 建立字典（`{}` 和 `dict()`）
# - [ ] 讀取資料（`d[key]` 和 `d.get(key, default)`）
# - [ ] 新增和更新資料
# - [ ] 刪除資料（`del` 和 `pop()`）
# - [ ] 檢查 key 是否存在（`in`）
# - [ ] 使用 `len()`、`keys()`、`values()`、`items()`
#
# ### 進階操作
# - [ ] 使用 for 迴圈走訪字典
# - [ ] 計算統計值（總和、平均、最大值）
# - [ ] 理解字典的相等性比較
# - [ ] 處理 list of dict
# - [ ] 操作巢狀字典
# - [ ] 使用 `get()` 實作計數器
# - [ ] 使用 dict comprehension
# - [ ] 資料清理（移除 None、空字串）
#
# ---
#
# ## ⚠️ 常見錯誤提醒
#
# ### 1. KeyError 錯誤
# ```python
# # ❌ 錯誤：直接存取不存在的 key
# print(d['不存在的key'])  # KeyError!
#
# # ✅ 正確：使用 get() 方法
# print(d.get('不存在的key', '預設值'))
# ```
#
# ### 2. 忘記字典是可變的
# ```python
# # 字典是 mutable，修改會影響原字典
# d = {'a': 1}
# d['b'] = 2  # d 變成 {'a': 1, 'b': 2}
# ```
#
# ### 3. items() 解包錯誤
# ```python
# # ❌ 錯誤：只用一個變數
# for item in d.items():
#     print(item)  # 會印出 tuple: ('key', 'value')
#
# # ✅ 正確：解包成兩個變數
# for key, value in d.items():
#     print(key, value)
# ```
#
# ### 4. 在迴圈中修改字典大小
# ```python
# # ❌ 危險：在走訪時刪除元素
# for key in d:
#     del d[key]  # RuntimeError!
#
# # ✅ 正確：先複製 keys
# for key in list(d.keys()):
#     del d[key]
# ```
#
# ---
#
# ## 🛠️ Debug 建議
#
# 當程式出錯時，可以使用以下方法檢查：
#
# ```python
# # 1. 印出整個字典，檢查結構
# print(d)
#
# # 2. 印出所有的 key，確認 key 名稱
# print(d.keys())
#
# # 3. 印出所有的 value，檢查資料
# print(d.values())
#
# # 4. 印出字典大小
# print(len(d))
#
# # 5. 檢查某個 key 是否存在
# print('某key' in d)
# ```
#
# ---
#
# ## 🚀 下一步學習
#
# 完成 Dictionary 練習後，建議繼續學習：
#
# 1. **Try-Except 錯誤處理**：更安全地處理 KeyError 等錯誤
# 2. **檔案讀寫**：從檔案讀取資料存入字典
# 3. **JSON 格式**：字典與 JSON 的轉換
# 4. **實際專案應用**：
#    - 設定檔管理
#    - API 資料處理
#    - 資料庫查詢結果
#    - 網頁表單資料
#
# ---
#
# ## 💪 持續練習
#
# 想要更進階的練習？可以嘗試：
#
# 1. 實作一個電話簿系統（新增、查詢、刪除聯絡人）
# 2. 實作一個成績管理系統
# 3. 實作一個庫存管理系統
# 4. 實作一個簡單的快取系統
# 5. 處理真實的 JSON 資料
#
# ---
#
# **Happy Coding! 🐍**
#
# 記得：多練習、多思考、多嘗試！
