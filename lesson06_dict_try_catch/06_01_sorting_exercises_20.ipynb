# %%
numbers = [42, 15, 88, 3, 67, 21]

# TODO: 使用 sorted() 排序並印出結果

# %% [markdown]
# ## 題目 2
#
# 使用 `sorted()` 將以下字串串列依字母順序排序，並印出排序結果。
#
# 資料：`fruits = ['mango', 'apple', 'orange', 'banana', 'kiwi']`
#
# 提醒：字串排序是依照字母順序（A-Z）

# %%
fruits = ['mango', 'apple', 'orange', 'banana', 'kiwi']

# TODO: 使用 sorted() 排序並印出結果

# %% [markdown]
# ## 題目 3
#
# 使用 `sort()` 方法將以下串列排序，並分別印出排序前和排序後的串列，觀察原串列是否改變。
#
# 資料：`scores = [78, 92, 65, 88, 71]`
#
# 步驟：
# 1. 先印出排序前的串列
# 2. 使用 `scores.sort()` 排序
# 3. 再印出排序後的串列

# %%
scores = [78, 92, 65, 88, 71]

# TODO: 印出排序前的串列

# TODO: 使用 sort() 排序

# TODO: 印出排序後的串列

# %% [markdown]
# ## 題目 4
#
# 使用 `sorted()` 將以下串列排序，並分別印出原串列和排序後的新串列，觀察原串列是否改變。
#
# 資料：`prices = [299, 150, 499, 99, 350]`
#
# 步驟：
# 1. 使用 `sorted()` 排序並將結果存到新變數 `sorted_prices`
# 2. 印出原串列 `prices`
# 3. 印出新串列 `sorted_prices`

# %%
prices = [299, 150, 499, 99, 350]

# TODO: 使用 sorted() 排序並存到 sorted_prices

# TODO: 印出原串列 prices

# TODO: 印出新串列 sorted_prices

# %% [markdown]
# ## 題目 5
#
# 使用 `sorted()` 加上 `reverse=True` 參數，將以下數字串列由大到小排序，並印出結果。
#
# 資料：`temperatures = [25, 18, 32, 10, 28, 15]`

# %%
temperatures = [25, 18, 32, 10, 28, 15]

# TODO: 使用 sorted() 和 reverse=True 排序並印出結果

# %% [markdown]
# ## 題目 6
#
# 使用 `sorted()` 加上 `reverse=True` 參數，將以下字串串列由大到小（Z→A）排序，並印出結果。
#
# 資料：`colors = ['red', 'blue', 'green', 'yellow', 'purple']`

# %%
colors = ['red', 'blue', 'green', 'yellow', 'purple']

# TODO: 使用 sorted() 和 reverse=True 排序並印出結果

# %% [markdown]
# ## 題目 7
#
# 先使用 `sorted()` 排序，然後對排序後的串列使用 `pop()` 移除最後一個元素，觀察原串列是否改變。
#
# 資料：`numbers = [50, 30, 70, 20, 60]`
#
# 步驟：
# 1. 使用 `sorted()` 排序並存到新變數 `sorted_numbers`
# 2. 對 `sorted_numbers` 使用 `pop()` 移除最後一個元素
# 3. 印出原串列 `numbers`
# 4. 印出修改後的 `sorted_numbers`

# %%
numbers = [50, 30, 70, 20, 60]

# TODO: 使用 sorted() 排序並存到 sorted_numbers

# TODO: 對 sorted_numbers 使用 pop()

# TODO: 印出原串列 numbers

# TODO: 印出 sorted_numbers

# %% [markdown]
# ## 題目 8
#
# 使用 `sorted()` 加上 `key=len` 參數，將以下字串串列依字串長度由小到大排序，並印出結果。
#
# 資料：`animals = ['cat', 'elephant', 'dog', 'butterfly', 'ant', 'tiger']`

# %%
animals = ['cat', 'elephant', 'dog', 'butterfly', 'ant', 'tiger']

# TODO: 使用 sorted() 和 key=len 排序並印出結果

# %% [markdown]
# ## 題目 9
#
# 使用 `sorted()` 加上 `key=len` 和 `reverse=True` 參數，將以下字串串列依字串長度由大到小排序，並印出結果。
#
# 資料：`countries = ['Japan', 'USA', 'Brazil', 'UK', 'Australia', 'Canada']`

# %%
countries = ['Japan', 'USA', 'Brazil', 'UK', 'Australia', 'Canada']

# TODO: 使用 sorted()、key=len 和 reverse=True 排序並印出結果

# %% [markdown]
# ## 題目 10
#
# 使用 `sorted()` 加上 `key=abs` 參數，將以下數字串列依絕對值大小排序，並印出結果。
#
# 資料：`nums = [-15, 8, -3, 20, -25, 12]`
#
# 提醒：`abs()` 函式可以計算數字的絕對值，例如 `abs(-15)` 會得到 `15`

# %%
nums = [-15, 8, -3, 20, -25, 12]

# TODO: 使用 sorted() 和 key=abs 排序並印出結果

# %% [markdown]
# ## 題目 11
#
# 使用自訂函式 `square()` 作為 `key` 參數，將以下數字串列依平方值排序，並印出結果。
#
# 資料：`numbers = [3, -5, 2, -8, 1]`
#
# 已提供函式定義：
# ```python
# def square(x):
#     return x ** 2
# ```

# %%
numbers = [3, -5, 2, -8, 1]

def square(x):
    return x ** 2

# TODO: 使用 sorted() 和 key=square 排序並印出結果

# %% [markdown]
# ## 題目 12
#
# 使用自訂函式 `second()` 作為 `key` 參數，將以下字串串列依第二個字母排序，並印出結果。
#
# 資料：`words = ['apple', 'banana', 'cherry', 'date', 'elderberry']`
#
# 已提供函式定義：
# ```python
# def second(s):
#     return s[1]
# ```

# %%
words = ['apple', 'banana', 'cherry', 'date', 'elderberry']

def second(s):
    return s[1]

# TODO: 使用 sorted() 和 key=second 排序並印出結果

# %% [markdown]
# ## 題目 13
#
# 定義一個函式 `last_letter()`，回傳字串的最後一個字母，並使用它作為 `key` 參數排序以下字串串列。
#
# 資料：`fruits = ['kiwi', 'mango', 'grape', 'peach', 'lemon']`
#
# 提示：使用 `s[-1]` 可以取得字串的最後一個字元

# %%
fruits = ['kiwi', 'mango', 'grape', 'peach', 'lemon']

# TODO: 定義函式 last_letter(s)，回傳 s[-1]

# TODO: 使用 sorted() 和 key=last_letter 排序並印出結果

# %% [markdown]
# ## 題目 14
#
# 完成函式 `count_vowels()`，計算字串中母音（a, e, i, o, u）的數量，並使用它作為 `key` 參數排序以下字串串列。
#
# 資料：`words = ['python', 'code', 'awesome', 'fun', 'learn']`
#
# 提示：
# - 母音字母為 'aeiou'
# - 需要用迴圈檢查每個字母是否為母音

# %%
words = ['python', 'code', 'awesome', 'fun', 'learn']

def count_vowels(s):
    vowels = "aeiou"
    count = 0
    # TODO: 用 for 迴圈計算母音數量
    # TODO: 檢查每個字母是否在 vowels 中
    # TODO: 回傳 count
    pass

# TODO: 使用 sorted() 和 key=count_vowels 排序並印出結果

# %% [markdown]
# ## 題目 15
#
# 使用 `key=len` 將以下字串串列依長度排序，並觀察長度相同的字串順序。
#
# 資料：`words = ['dog', 'cat', 'elephant', 'ant', 'bee', 'fox']`
#
# 觀察問題：
# - `dog`, `cat`, `ant`, `bee`, `fox` 都是 3 個字元
# - 它們在排序後的順序是什麼？
# - 是否保持原本的相對順序？（這稱為「穩定排序」）

# %%
words = ['dog', 'cat', 'elephant', 'ant', 'bee', 'fox']

# TODO: 使用 sorted() 和 key=len 排序並印出結果

# TODO: 觀察相同長度的字串順序

# %% [markdown]
# ## 題目 16
#
# 使用 `key=len` 和 `reverse=True` 將以下字串串列依長度由大到小排序，並觀察相同長度字串的順序。
#
# 資料：`animals = ['tiger', 'lion', 'bear', 'wolf', 'eagle', 'snake']`
#
# 觀察問題：
# - `tiger`, `eagle`, `snake` 都是 5 個字元
# - `lion`, `bear`, `wolf` 都是 4 個字元
# - 在反向排序時，相同長度的字串順序是否依然穩定？

# %%
animals = ['tiger', 'lion', 'bear', 'wolf', 'eagle', 'snake']

# TODO: 使用 sorted()、key=len 和 reverse=True 排序並印出結果

# TODO: 觀察相同長度的字串順序

# %% [markdown]
# ## 題目 17
#
# 將以下 tuple 串列依每個 tuple 的第二個值（索引 1）排序，並印出結果。
#
# 資料：`students = [('Alice', 85), ('Bob', 92), ('Charlie', 78), ('David', 95)]`
#
# 提示：
# - 定義一個函式 `get_second()`，回傳 tuple 的第二個元素
# - 或者使用 lambda（如果你已經學過）：`lambda x: x[1]`

# %%
students = [('Alice', 85), ('Bob', 92), ('Charlie', 78), ('David', 95)]

# TODO: 定義函式 get_second()，回傳 tuple 的第二個元素 (item[1])

# TODO: 使用 sorted() 和 key=get_second 排序並印出結果

# %% [markdown]
# ## 題目 18
#
# 將以下字典串列依 `'price'` 鍵的值由小到大排序，並印出結果。
#
# 資料：
# ```python
# products = [
#     {'name': 'apple', 'price': 50},
#     {'name': 'banana', 'price': 30},
#     {'name': 'cherry', 'price': 80},
#     {'name': 'date', 'price': 45}
# ]
# ```
#
# 提示：定義一個函式 `get_price()`，回傳字典的 `'price'` 值

# %%
products = [
    {'name': 'apple', 'price': 50},
    {'name': 'banana', 'price': 30},
    {'name': 'cherry', 'price': 80},
    {'name': 'date', 'price': 45}
]

# TODO: 定義函式 get_price()，回傳字典的 'price' 值

# TODO: 使用 sorted() 和 key=get_price 排序並印出結果

# %% [markdown]
# ## 題目 19
#
# 將以下字典串列依 `'rating'` 鍵的值由大到小排序，並印出結果。
#
# 資料：
# ```python
# movies = [
#     {'title': 'Movie A', 'rating': 8.5},
#     {'title': 'Movie B', 'rating': 9.2},
#     {'title': 'Movie C', 'rating': 7.8},
#     {'title': 'Movie D', 'rating': 9.0}
# ]
# ```
#
# 提示：
# - 定義一個函式 `get_rating()`，回傳字典的 `'rating'` 值
# - 記得使用 `reverse=True`

# %%
movies = [
    {'title': 'Movie A', 'rating': 8.5},
    {'title': 'Movie B', 'rating': 9.2},
    {'title': 'Movie C', 'rating': 7.8},
    {'title': 'Movie D', 'rating': 9.0}
]

# TODO: 定義函式 get_rating()，回傳字典的 'rating' 值

# TODO: 使用 sorted()、key=get_rating 和 reverse=True 排序並印出結果

# %% [markdown]
# ## 題目 20
#
# 綜合練習：將以下數字串列依平方值排序後，印出排序結果的最後一個元素。
#
# 資料：`numbers = [-3, 5, -7, 2, -1, 4]`
#
# 步驟：
# 1. 定義函式 `square(x)`，回傳 `x ** 2`
# 2. 使用 `sorted()` 和 `key=square` 排序
# 3. 將排序結果存到變數 `sorted_nums`
# 4. 印出 `sorted_nums[-1]`（最後一個元素）

# %%
numbers = [-3, 5, -7, 2, -1, 4]

# TODO: 定義函式 square(x)，回傳 x ** 2

# TODO: 使用 sorted() 和 key=square 排序，存到 sorted_nums

# TODO: 印出 sorted_nums[-1]
