# %% [markdown]
# ---
#
# ## Section 1：匯入套件
#
# 首先，讓我們匯入今天會用到的套件。

# %%
# 匯入 pandas 和 matplotlib
import pandas as pd
import matplotlib.pyplot as plt

print("✅ 套件載入成功！")

# %% [markdown]
# ---
#
# ## Section 2：讀取資料並快速查看
#
# 讓我們讀取捷運資料，並看看資料的大小和前幾筆內容。

# %%
# 讀取 CSV 檔案
df = pd.read_csv('../../data/mrt.csv')

print("✅ 資料讀取成功！")

# %%
# 查看資料大小
df.shape

# %%
# 查看前 10 筆資料
df.head(10)

# %% [markdown]
# ---
#
# ## Section 3：觀察欄位資訊
#
# 使用 `info()` 來看看每個欄位的資料型別。

# %%
# 查看欄位資訊
df.info()

# %% [markdown]
# ---
#
# ## Section 4：第一次分析 — 計算每個統計期的平均進站人次
#
# ### 🎯 任務說明
#
# 請你完成以下任務：
# 1. 以「統計期」當作分組欄位
# 2. 計算每個統計期的「進站人次」平均值
# 3. 把結果存到變數 `period_avg_in`
#
# ### 💡 提示（請自己完成）
#
# ✅ **你要做什麼：**
# 按照某個欄位分組，然後計算另一個欄位的平均值。
#
# 🔎 **去 learning 對照：**
# `lesson11_12_data/lesson11_learning_first_analysis.ipynb` 的 **Section 5：第一次分析 — 計算每天的平均訂單金額**
#
# 💡 **小提醒：**
# - 用 groupby() 依照「統計期」分組
# - 選擇要計算的欄位「進站人次」
# - 計算平均值

# %%
# TODO：請自己完成
# 提示：df.groupby('統計期')['進站人次'].mean()

# period_avg_in = ...（請自己完成）

# 暫時先印完成訊息
print("✅ 請完成上面的程式碼")

# %% [markdown]
# ---
#
# ## Section 5：畫折線圖 — 觀察進站人次的時間趨勢
#
# ### 🎯 任務說明
#
# 請你把 `period_avg_in` 的結果畫成折線圖：
# - X 軸：統計期
# - Y 軸：平均進站人次
#
# ### 💡 提示（請自己完成）
#
# ✅ **你要做什麼：**
# 把剛才計算的結果，用折線圖呈現出來。
#
# 🔎 **去 learning 對照：**
# `lesson11_12_data/lesson11_learning_first_analysis.ipynb` 的 **Section 6：第一次畫圖 🎨**
#
# 💡 **小提醒：**
# - X 軸資料：groupby 結果的 index（統計期）
# - Y 軸資料：groupby 結果的數值（平均進站人次）
# - 可以把 Series 轉成 list：`list(period_avg_in)`

# %%
# TODO：請自己完成
# 提示：plt.figure(), plt.plot(), plt.title(), plt.xlabel(), plt.ylabel(), plt.grid(), plt.show()

# plt.figure(...)
# plt.plot(...)
# plt.title(...)
# plt.xlabel(...)
# plt.ylabel(...)
# plt.grid(...)
# plt.show()

# 暫時先印完成訊息
print("✅ 請完成上面的程式碼")

# %% [markdown]
# ---
#
# ## Section 6：反思問題
#
# ### 🤔 請思考以下問題：
#
# #### 1. groupby() 的目的是什麼？
#
# **你的答案：**
#
# （請在這裡寫下你的想法）
#
# ---
#
# #### 2. 折線圖在看什麼？
#
# 觀察剛才畫的圖，你能看出：
# - 進站人次有增加還是減少的趨勢？
# - 哪個統計期的進站人次最多？
#
# **你的答案：**
#
# （請在這裡寫下你的想法）

# %% [markdown]
# ---
#
# ## 🎉 完成！
#
# 恭喜你完成這份練習！你已經學會：
#
# 1. ✅ 用 pandas 讀取 CSV 檔案
# 2. ✅ 用 shape、head()、info() 快速檢查資料
# 3. ✅ 用 groupby() 進行分組統計
# 4. ✅ 把分析結果畫成折線圖
#
# 這些都是資料分析的核心技能！繼續加油！🚀
