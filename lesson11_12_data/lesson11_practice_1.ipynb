# %% [markdown]
# ---
#
# ## Section 1：匯入套件
#
# 這一段已經幫你完成了！直接執行即可。
#
# 我們需要：
# - **pandas** - 處理表格資料
# - **matplotlib** - 畫圖

# %%
import pandas as pd
import matplotlib.pyplot as plt

print("✅ 套件載入成功！")

# %% [markdown]
# ---
#
# ## Section 2：讀取資料
#
# ### 📊 你的任務
#
# 使用 **pandas** 讀取 `orders.csv` 檔案。
#
# ### 💡 提示
#
# - 使用 `pd.read_csv()` 函數
# - 檔案名稱是 `'orders.csv'`
# - 記得用引號包起來

# %%
# TODO：請用 pandas 讀取 orders.csv
df = __________________

print("✅ 資料讀取成功！")

# %% [markdown]
# ---
#
# ## Section 3：查看資料
#
# ### 👀 你的任務
#
# 看前幾筆資料，確認欄位是否正確。
#
# ### 💡 提示
#
# - 使用 DataFrame 的 `.head()` 方法
# - 預設會顯示前 5 筆資料

# %%
# TODO：顯示前 5 筆資料
df.__________()

# %% [markdown]
# ### 🔍 確認欄位
#
# 你應該會看到兩個欄位：
# - **date** - 訂單日期
# - **order_amount** - 訂單金額
#
# 如果看到這兩個欄位，就代表讀取成功了！

# %% [markdown]
# ---
#
# ## Section 4：轉換日期格式
#
# ### 📅 你的任務
#
# 將 `date` 欄位轉成日期格式。
#
# ### 💡 提示
#
# - 使用 `pd.to_datetime()` 函數
# - 要轉換的欄位是 `df['date']`

# %%
# TODO：把 date 欄位轉成日期格式
df['date'] = __________________

print("✅ 日期格式轉換成功！")
print(f"轉換後的型別：{df['date'].dtype}")

# %% [markdown]
# ---
#
# ## Section 5：簡單分析
#
# ### 📊 你的任務
#
# 計算每天的平均訂單金額。
#
# ### 🤔 為什麼要這樣做？
#
# 因為每天可能有多筆訂單，我們想知道「平均來說，每天的訂單金額是多少」。
#
# ### 💡 提示
#
# - 使用 `df.groupby('date')['order_amount'].mean()`
# - 這會把相同日期的訂單分組，然後計算平均值

# %%
# TODO：依 date 分組，計算平均訂單金額
daily_avg = __________________

print("✅ 分析完成！")
print()
print("每天的平均訂單金額：")
print(daily_avg)

# %% [markdown]
# ---
#
# ## Section 6：畫圖
#
# ### 📈 你的任務
#
# 畫折線圖，顯示每天的平均訂單金額。
#
# ### 💡 提示
#
# - 第一個空格填入：`daily_avg.index`（日期）
# - 第二個空格填入：`daily_avg.values`（平均金額）
#
# ### 🎨 為什麼用折線圖？
#
# 因為我們的資料是「時間序列」，折線圖可以清楚顯示隨時間變化的趨勢。

# %%
# TODO：補完以下程式碼
plt.figure(figsize=(10, 6))
plt.plot(__________, __________, marker='o', linewidth=2, color='blue')
plt.title('每天的平均訂單金額', fontsize=16)
plt.xlabel('日期', fontsize=12)
plt.ylabel('平均訂單金額（元）', fontsize=12)
plt.grid(True, alpha=0.3)
plt.show()

print("✅ 圖表繪製完成！")

# %% [markdown]
# ### 🎉 恭喜！
#
# 如果你看到一張折線圖，就代表你成功了！
#
# 從圖表中，你可以看到每一天的平均訂單金額變化。

# %% [markdown]
# ---
#
# ## Section 7：Checkpoint — 確認完成度
#
# ### ✅ 請確認以下項目
#
# - [ ] **我成功讀取 CSV**
#   → 使用 `pd.read_csv('orders.csv')`
#
# - [ ] **我看得懂欄位**
#   → `date` 是日期，`order_amount` 是訂單金額
#
# - [ ] **我畫出第一張圖**
#   → 使用 `plt.plot()` 畫出折線圖
#
# ---
#
# ### 🎯 如果以上都完成了
#
# **恭喜你！**你已經完成了第一次完整的資料分析流程：
#
# 1. ✅ 讀取資料
# 2. ✅ 查看資料
# 3. ✅ 整理資料
# 4. ✅ 分析資料
# 5. ✅ 視覺化資料
#
# 這就是資料分析的基本流程！

# %% [markdown]
# ---
#
# ## Section 8：學習反思
#
# 請花幾分鐘回答以下問題：
#
# ### 問題 1：哪一個步驟最卡？
#
# （請在下方填寫）
#
#
#
# ---
#
# ### 問題 2：哪一段你覺得最有成就感？
#
# （請在下方填寫）
#
#
#
# ---
#
# ### 💡 給自己的話
#
# 如果有些地方卡住了，**這很正常**！
#
# 重要的是：
# - 你已經親手完成了第一次資料分析
# - 你知道整個流程是怎麼運作的
# - 之後會越來越熟練
#
# **繼續加油！** 💪🚀
#
# ---
#
# ### 📚 下一步
#
# 如果你想再練習一次：
# 1. 重新開啟這份 Notebook
# 2. 清除所有輸出
# 3. 再做一遍
#
# 熟能生巧！
