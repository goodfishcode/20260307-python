# %% [markdown]
# ---
#
# ## 題目 1：基本讀取 - read() 全部內容
#
# **題目說明：**
#
# 請先建立一個名為 `intro.txt` 的檔案，內容如下：
# ```
# Welcome to JWClub!
# Let's learn Python together.
# ```
#
# 然後讀取 `intro.txt` 的全部內容並印出。
#
# **預期輸出：**
# ```
# Welcome to JWClub!
# Let's learn Python together.
# ```

# %%
# 第一步：建立 intro.txt
# 在此處寫程式碼

# %%
# 第二步：讀取並印出全部內容
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 2：基本寫入 - write() 建立檔案
#
# **題目說明：**
#
# 請建立一個名為 `greeting.txt` 的檔案，並寫入以下內容：
# ```
# Hello JWClub
# Have a nice day
# ```
#
# 記得：
# - 使用 `'w'` 模式
# - 需要自己加換行符號 `\n`
# - 寫完要 `close()`
#
# **完成後可以用讀取方式驗證內容是否正確。**

# %%
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 3：讀取一行 - readline()
#
# **題目說明：**
#
# 請先建立一個名為 `courses.txt` 的檔案，內容如下：
# ```
# Python Programming
# Web Development
# Data Science
# ```
#
# 然後讀取並印出**第一行**內容。
#
# **預期輸出：**
# ```
# Python Programming
# ```

# %%
# 第一步：建立 courses.txt
# 在此處寫程式碼

# %%
# 第二步：讀取第一行
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 4：續寫模式 - 'a' 附加內容
#
# **題目說明：**
#
# 承接題目 2 的 `greeting.txt`，請使用 `'a'` 模式（append）在檔案結尾續寫一行：
# ```
# See you at JWClub!
# ```
#
# **提示：** 續寫不會覆蓋原有內容
#
# **預期結果（完整檔案內容）：**
# ```
# Hello JWClub
# Have a nice day
# See you at JWClub!
# ```

# %%
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 5：readlines() + for 迴圈印出所有行
#
# **題目說明：**
#
# 承接題目 3 的 `courses.txt`，請使用 `readlines()` 讀取所有行，並用 for 迴圈逐行印出。
#
# **預期輸出：**
# ```
# Python Programming
# Web Development
# Data Science
# ```
#
# **提示：** 使用 `print(line, end='')` 避免多餘的空白行

# %%
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 6：writelines() 寫入多行
#
# **題目說明：**
#
# 請建立一個名為 `members.txt` 的檔案，使用 `writelines()` 將以下 list 內容寫入：
#
# ```python
# names = ['Alice\n', 'Bob\n', 'Charlie\n', 'Diana']
# ```
#
# **預期結果（檔案內容）：**
# ```
# Alice
# Bob
# Charlie
# Diana
# ```

# %%
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 7：print(file=f) 寫入檔案
#
# **題目說明：**
#
# 請建立一個名為 `scores.txt` 的檔案，使用 `print(file=f)` 將以下 dictionary 寫入：
#
# ```python
# scores = {'Alice': 95, 'Bob': 87, 'Charlie': 92}
# ```
#
# **預期結果（檔案內容）：**
# ```
# {'Alice': 95, 'Bob': 87, 'Charlie': 92}
# ```
#
# **提示：** `print(file=f)` 會自動換行，且可以直接印出複雜資料結構

# %%
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 8：續寫模式 'a' + 多行附加
#
# **題目說明：**
#
# 承接題目 6 的 `members.txt`，請使用 `'a'` 模式續寫以下兩行：
# ```
# Eve
# Frank
# ```
#
# **預期結果（完整檔案內容）：**
# ```
# Alice
# Bob
# Charlie
# Diana
# Eve
# Frank
# ```
#
# **提示：** 記得 Diana 後面原本沒有換行，所以續寫前要先加一個 `\n`

# %%
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 9：for 迴圈處理 - 去除換行符號
#
# **題目說明：**
#
# 請先建立一個名為 `colors.txt` 的檔案，內容如下：
# ```
# Red
# Green
# Blue
# Yellow
# ```
#
# 然後讀取檔案，用 for 迴圈逐行處理，**去除每行的換行符號** `\n`，並印出 `顏色: [顏色名稱]`
#
# **預期輸出：**
# ```
# 顏色: Red
# 顏色: Green
# 顏色: Blue
# 顏色: Yellow
# ```
#
# **提示：** 使用 `.strip()` 或 `.rstrip('\n')` 去除換行符號

# %%
# 第一步：建立 colors.txt
# 在此處寫程式碼

# %%
# 第二步：讀取並處理
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 10：for 迴圈處理 - 計算包含關鍵字的行數
#
# **題目說明：**
#
# 請先建立一個名為 `reviews.txt` 的檔案，內容如下：
# ```
# JWClub courses are amazing!
# I love the teaching style.
# JWClub instructors are very helpful.
# The materials are well organized.
# I recommend JWClub to everyone.
# ```
#
# 然後讀取檔案，計算包含 `'JWClub'` 這個關鍵字的行數，並印出結果。
#
# **預期輸出：**
# ```
# 包含 'JWClub' 的行數: 3
# ```
#
# **提示：** 使用 `if 'JWClub' in line:` 來判斷

# %%
# 第一步：建立 reviews.txt
# 在此處寫程式碼

# %%
# 第二步：計算包含關鍵字的行數
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 🎯 題目 1-10 完成！
#
# ### 已練習的技能
#
# ✅ 基本讀取：`read()`, `readline()`, `readlines()`
# ✅ 基本寫入：`write()`, `writelines()`, `print(file=f)`
# ✅ 續寫模式：`'a'` append
# ✅ for 迴圈處理：去除換行、計數、篩選
#
# ### 繼續加油！還有 10 題等著你！💪

# %% [markdown]
# ---
#
# ## 題目 11：讀取部分內容 - read(size)
#
# **題目說明：**
#
# 請先建立一個名為 `slogan.txt` 的檔案，內容如下：
# ```
# JWClub - Your Learning Partner!
# ```
#
# 然後：
# 1. 讀取前 7 個字元並印出
# 2. 再讀取接下來的 10 個字元並印出
#
# **預期輸出：**
# ```
# JWClub
# - Your Lea
# ```
#
# **提示：** 注意游標位置，第二次 read 會從第一次結束的地方繼續

# %%
# 第一步：建立 slogan.txt
# 在此處寫程式碼

# %%
# 第二步：讀取指定字元數
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 12：多次 readline() - 交換行順序
#
# **題目說明：**
#
# 請先建立一個名為 `students.txt` 的檔案，內容如下：
# ```
# 第一名: Alice
# 第二名: Bob
# 第三名: Charlie
# ```
#
# 然後讀取三行，以**倒序（由下到上）**印出。
#
# **預期輸出：**
# ```
# 第三名: Charlie
# 第二名: Bob
# 第一名: Alice
# ```
#
# **提示：** 使用三次 `readline()`，儲存到變數後再反向印出

# %%
# 第一步：建立 students.txt
# 在此處寫程式碼

# %%
# 第二步：讀取並倒序印出
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 13：for 迴圈 + 條件 - 篩選特定內容
#
# **題目說明：**
#
# 請先建立一個名為 `products.txt` 的檔案，內容如下：
# ```
# Apple - 50
# Banana - 30
# Orange - 60
# Grape - 25
# Mango - 45
# ```
#
# 然後讀取檔案，只印出**價格大於等於 40** 的產品（包含整行）。
#
# **預期輸出：**
# ```
# Apple - 50
# Orange - 60
# Mango - 45
# ```
#
# **提示：**
# - 使用 `split(' - ')` 分割產品名稱和價格
# - 將價格轉換為 int 再比較

# %%
# 第一步：建立 products.txt
# 在此處寫程式碼

# %%
# 第二步：篩選並印出價格 >= 40 的產品
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 14：for 迴圈 + write() - 轉換並寫入新檔
#
# **題目說明：**
#
# 承接題目 13 的 `products.txt`，請讀取該檔案，將所有產品名稱改為大寫，然後寫入到新檔案 `products_upper.txt`。
#
# **預期結果（products_upper.txt 內容）：**
# ```
# APPLE - 50
# BANANA - 30
# ORANGE - 60
# GRAPE - 25
# MANGO - 45
# ```
#
# **提示：** 使用 `.upper()` 方法將字串轉為大寫

# %%
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 15：計算數字總和
#
# **題目說明：**
#
# 請先建立一個名為 `numbers.txt` 的檔案，內容如下（每行一個數字）：
# ```
# 100
# 200
# 150
# 300
# 250
# ```
#
# 然後讀取檔案，計算所有數字的總和並印出。
#
# **預期輸出：**
# ```
# 總和: 1000
# ```
#
# **提示：** 使用 `int()` 將每行字串轉換為數字

# %%
# 第一步：建立 numbers.txt
# 在此處寫程式碼

# %%
# 第二步：計算總和
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 16：print(file=f) 批量寫入
#
# **題目說明：**
#
# 請建立一個名為 `multiplication_table.txt` 的檔案，將 **7 的乘法表**（1x7 到 9x7）使用 `print(file=f)` 寫入檔案。
#
# **預期結果（檔案內容）：**
# ```
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# ```
#
# **提示：** 使用 for 迴圈搭配 `print(file=f)`

# %%
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 17：讀取並統計字數
#
# **題目說明：**
#
# 請先建立一個名為 `article.txt` 的檔案，內容如下：
# ```
# Welcome to JWClub!
# Learn Python with us.
# JWClub makes learning fun and easy.
# Join JWClub today!
# ```
#
# 然後讀取檔案，計算並印出：
# 1. 總行數
# 2. 總字數（以空格分隔計算）
#
# **預期輸出：**
# ```
# 總行數: 4
# 總字數: 16
# ```
#
# **提示：** 使用 `.split()` 將每行分割成單字

# %%
# 第一步：建立 article.txt
# 在此處寫程式碼

# %%
# 第二步：統計行數和字數
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 18：合併多個檔案
#
# **題目說明：**
#
# 請先建立兩個檔案：
#
# **part1.txt：**
# ```
# This is part 1.
# JWClub is great!
# ```
#
# **part2.txt：**
# ```
# This is part 2.
# Learning is fun!
# ```
#
# 然後將這兩個檔案的內容合併，寫入到新檔案 `combined.txt`。
#
# **預期結果（combined.txt 內容）：**
# ```
# This is part 1.
# JWClub is great!
# This is part 2.
# Learning is fun!
# ```
#
# **提示：**
# 1. 先讀取 part1.txt 的內容
# 2. 再讀取 part2.txt 的內容
# 3. 將兩者寫入 combined.txt

# %%
# 第一步：建立 part1.txt 和 part2.txt
# 在此處寫程式碼

# %%
# 第二步：合併到 combined.txt
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 19：讀取並建立索引列表
#
# **題目說明：**
#
# 承接題目 3 的 `courses.txt`（內容為 Python Programming, Web Development, Data Science），請讀取該檔案，為每一行加上編號，然後寫入到新檔案 `courses_indexed.txt`。
#
# **預期結果（courses_indexed.txt 內容）：**
# ```
# 1. Python Programming
# 2. Web Development
# 3. Data Science
# ```
#
# **提示：**
# - 使用 `enumerate()` 或手動計數
# - 記得去除原本的換行符號

# %%
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 題目 20：綜合應用 - 學生成績處理
#
# **題目說明：**
#
# 請先建立一個名為 `grades.txt` 的檔案，內容如下：
# ```
# Alice,85,90,88
# Bob,78,82,80
# Charlie,92,95,90
# Diana,88,85,87
# ```
#
# 格式為：姓名,國文,英文,數學
#
# 請讀取檔案，計算每位學生的平均成績，然後將結果寫入到新檔案 `grades_avg.txt`。
#
# **預期結果（grades_avg.txt 內容）：**
# ```
# Alice: 87.67
# Bob: 80.0
# Charlie: 92.33
# Diana: 86.67
# ```
#
# **提示：**
# 1. 使用 `.split(',')` 分割每行
# 2. 將成績字串轉換為數字
# 3. 計算平均值
# 4. 格式化輸出（可用 `round()` 或 f-string）

# %%
# 第一步：建立 grades.txt
# 在此處寫程式碼

# %%
# 第二步：計算平均並寫入 grades_avg.txt
# 在此處寫程式碼

# %% [markdown]
# ---
#
# ## 🎉 恭喜完成全部 20 題！
#
# ### 你已經掌握的技能
#
# ✅ **檔案開啟與關閉**
# - `open()` 搭配不同 mode（'r', 'w', 'a'）
# - `close()` 正確關閉檔案
#
# ✅ **讀取方法**
# - `read()` - 讀取全部或指定字元數
# - `readline()` - 逐行讀取
# - `readlines()` - 讀取所有行到 list
#
# ✅ **寫入方法**
# - `write()` - 寫入字串
# - `writelines()` - 寫入序列
# - `print(file=f)` - 使用 print 寫入
#
# ✅ **進階應用**
# - 游標位置控制
# - for 迴圈處理檔案內容
# - 字串處理（split, strip, upper）
# - 資料轉換（字串 ↔ 數字）
# - 條件篩選
# - 多檔案操作
# - 資料統計與計算
#
# ### 📚 下一步學習
#
# - `with` 語句（自動關閉檔案）
# - CSV 檔案處理
# - JSON 檔案處理
# - 異常處理（Exception Handling）
#
# ### 💪 持續練習，精進技能！
#
# 記得：**熟能生巧**，多寫多練習才能真正掌握檔案處理！
