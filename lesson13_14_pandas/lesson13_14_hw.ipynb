# %% [markdown]
# ---
#
# ## Part 0｜Setup - 讀取資料
#
# ### 🎯 任務說明
#
# 首先，我們要把資料讀進來，並做初步觀察。
#
# **請完成以下步驟：**
# 1. import pandas 和 numpy
# 2. 讀取 `data/hw_dirty_orders.csv`
# 3. 觀察資料的前幾筆、後幾筆、隨機幾筆
# 4. 確認資料的大小（幾列、幾欄）
# 5. 列出所有欄位名稱
#
# ---
#
# ### 📌 提示
# - 使用 `pd.read_csv()`
# - 使用 `df.head()`, `df.tail()`, `df.sample()`
# - 使用 `df.shape` 和 `df.columns`

# %%
# TODO: import pandas 和 numpy

# %%
# TODO: 讀取 data/hw_dirty_orders.csv
# df = pd.read_csv(...)

# %%
# TODO: 顯示前 5 筆資料

# %%
# TODO: 顯示後 5 筆資料

# %%
# TODO: 隨機顯示 5 筆資料（設定 random_state=42）

# %%
# TODO: 顯示資料大小（幾列 x 幾欄）

# %%
# TODO: 列出所有欄位名稱

# %% [markdown]
# **🤔 初步觀察：**
#
# 從上面的結果，你發現什麼問題了嗎？
#
# （請在這裡寫下你的觀察）
# -
# -
# -

# %% [markdown]
# ---
#
# ## Part 1｜Data Profiling - 深度檢查資料
#
# ### 🎯 Exercise 1.1：檢查資料型別和基本統計
#
# **任務：**
# - 使用 `df.info()` 查看每個欄位的資料型別、非空值數量
# - 使用 `df.describe(include='all')` 查看所有欄位的統計資訊
#
# **要注意的問題：**
# - 哪些欄位應該是數字但顯示為 object？
# - 哪些欄位應該是日期但顯示為 object？
# - 哪些欄位的非空值數量不等於總列數（代表有缺值）？

# %%
# TODO: 使用 df.info() 檢查資料型別

# %%
# TODO: 使用 df.describe(include='all') 查看統計資訊

# %% [markdown]
# **🤔 你的發現：**
#
# 1. 哪些欄位的資料型別看起來不對？
#
# （請在這裡寫下）
# -
# -
#
# 2. 有哪些欄位有缺值？
#
# （請在這裡寫下）
# -
# -

# %% [markdown]
# ---
#
# ### 🎯 Exercise 1.2：統計缺值數量
#
# **任務：**
# - 計算每個欄位的缺值數量
# - 找出缺值數量 > 0 的欄位

# %%
# TODO: 計算每個欄位的缺值數量
# 提示：使用 df.isna().sum()

# %% [markdown]
# ---
#
# ### 🎯 Exercise 1.3：檢查類別欄位的唯一值
#
# **任務：**
# 請檢查以下欄位的唯一值和分布：
# - `channel`
# - `category`
# - `member_level`
# - `payment_status`
#
# 看看有沒有格式不一致的問題（例如：大小寫、空格）

# %%
# TODO: 檢查 channel 欄位的唯一值和統計

# %%
# TODO: 檢查 category 欄位的唯一值和統計

# %%
# TODO: 檢查 member_level 欄位的唯一值和統計

# %%
# TODO: 檢查 payment_status 欄位的唯一值和統計

# %% [markdown]
# **🤔 你發現的格式問題：**
#
# （請在這裡寫下你發現的問題）
# -
# -
# -

# %% [markdown]
# ---
#
# ## Part 2｜Missing Values - 處理缺值
#
# ### 🎯 Exercise 2.1：建立清理用的 DataFrame
#
# **任務：**
# - 複製 df 成 df_clean，避免修改原始資料

# %%
# TODO: 建立 df_clean

# %% [markdown]
# ---
#
# ### 🎯 Exercise 2.2：找出特定欄位的缺值
#
# **任務：**
# 請找出以下欄位的缺值列，並觀察這些訂單：
# - `order_date` 缺值的訂單
# - `customer_name` 缺值的訂單
# - `member_level` 缺值的訂單
# - `payment_status` 缺值的訂單

# %%
# TODO: 列出 order_date 缺值的訂單

# %%
# TODO: 列出 customer_name 缺值的訂單

# %%
# TODO: 列出 member_level 缺值的訂單

# %%
# TODO: 列出 payment_status 缺值的訂單

# %% [markdown]
# ---
#
# ### 🎯 Exercise 2.3：決定缺值處理策略並執行
#
# **任務：**
# 請根據業務邏輯，決定每個欄位的缺值要如何處理：
# - `order_date`：？（刪除 / 填補 / 保留）
# - `customer_name`：？（刪除 / 填補 / 保留）
# - `order_amount`：？（計算 / 刪除）
# - `unit_price`：？（計算 / 刪除）
# - `member_level`：？（填入預設值 / 刪除）
# - `payment_status`：？（填入 'unknown' / 刪除）
#
# **💡 思考：**
# - 必要欄位（訂單分析一定需要的）→ 刪除
# - 可計算欄位（可以從其他欄位推算）→ 計算
# - 非必要欄位（不影響主要分析）→ 填入預設值或 unknown
#
# **請在下方執行你的處理策略，並加上註解說明理由。**

# %%
# TODO: 處理 order_date 缺值
# 理由：

# %%
# TODO: 處理 customer_name 缺值
# 理由：

# %%
# TODO: 處理 member_level 缺值
# 理由：

# %%
# TODO: 處理 payment_status 缺值
# 理由：

# %%
# TODO: 檢查處理後還剩幾筆資料

# %% [markdown]
# ---
#
# ## Part 3｜Type Conversion - 資料型別轉換
#
# ### 🎯 Exercise 3.1：轉換日期格式
#
# **任務：**
# - 將 `order_date` 轉換成 datetime 格式
# - 檢查是否有無效日期
# - 處理無效日期（刪除或標記）
#
# **💡 提示：**
# - 使用 `pd.to_datetime(errors='coerce')`
# - 無效日期會變成 NaT

# %%
# TODO: 將 order_date 轉換成 datetime

# %%
# TODO: 檢查是否有無效日期（NaT）

# %%
# TODO: 列出無效日期的訂單

# %%
# TODO: 處理無效日期（你決定要刪除還是其他處理方式）

# %% [markdown]
# ---
#
# ### 🎯 Exercise 3.2：轉換數值格式
#
# **任務：**
# 將以下欄位轉換成數值格式：
# - `qty`
# - `unit_price`（注意：可能有逗號和 $ 符號）
# - `order_amount`（注意：可能有逗號和引號）
# - `shipping_fee`
#
# **💡 提示：**
# - 先用 `.str.replace()` 移除特殊字元
# - 再用 `pd.to_numeric(errors='coerce')` 轉換

# %%
# TODO: 轉換 qty

# %%
# TODO: 轉換 unit_price（記得先處理 $ 和逗號）

# %%
# TODO: 轉換 order_amount（記得先處理逗號）

# %%
# TODO: 轉換 shipping_fee

# %%
# TODO: 檢查轉換後的資料型別

# %%
# TODO: 檢查轉換後產生的新缺值

# %% [markdown]
# ---
#
# ### 🎯 Exercise 3.3：處理可計算的缺值
#
# **任務：**
# - 如果 `order_amount` 缺值但有 `qty` 和 `unit_price`，計算 order_amount
# - 如果 `unit_price` 缺值但有 `order_amount` 和 `qty`，計算 unit_price

# %%
# TODO: 計算缺失的 order_amount

# %%
# TODO: 計算缺失的 unit_price

# %% [markdown]
# ---
#
# ## Part 4｜String Cleaning - 文字欄位清理
#
# ### 🎯 Exercise 4.1：統一大小寫
#
# **任務：**
# 將以下欄位統一轉成小寫：
# - `channel`
# - `payment_status`

# %%
# TODO: 統一 channel 為小寫

# %%
# TODO: 統一 payment_status 為小寫

# %% [markdown]
# ---
#
# ### 🎯 Exercise 4.2：去除空白字元
#
# **任務：**
# 去除以下欄位的前後空白：
# - `customer_name`
# - `region`
# - `member_level`

# %%
# TODO: 去除空白

# %% [markdown]
# ---
#
# ## Part 5｜Duplicates & Logic Checks - 重複與邏輯檢查
#
# ### 🎯 Exercise 5.1：找出並處理重複訂單
#
# **任務：**
# - 找出重複的 order_id
# - 決定保留哪一筆（第一筆 / 最後一筆）
# - 刪除重複的訂單

# %%
# TODO: 找出重複的 order_id

# %%
# TODO: 刪除重複的訂單

# %% [markdown]
# ---
#
# ### 🎯 Exercise 5.2：偵測不合理的數值
#
# **任務：**
# 找出並處理以下不合理的資料：
# - `qty` <= 0 的訂單
# - `order_amount` < 0 的訂單（可能是退款，要特別標記）
# - `unit_price` 異常高或異常低的訂單

# %%
# TODO: 找出 qty <= 0 的訂單

# %%
# TODO: 處理 qty <= 0 的訂單（刪除或修正）

# %%
# TODO: 找出 order_amount < 0 的訂單

# %%
# TODO: 建立 is_refund 欄位標記負數金額

# %% [markdown]
# ---
#
# ## Part 6｜Final Check & Export - 最終檢查與輸出
#
# ### 🎯 Exercise 6.1：確認關鍵欄位沒有缺值
#
# **任務：**
# 檢查以下關鍵欄位是否還有缺值：
# - `order_id`
# - `order_date`
# - `order_amount`
# - `payment_status`

# %%
# TODO: 檢查關鍵欄位的缺值

# %% [markdown]
# ---
#
# ### 🎯 Exercise 6.2：確認資料型別正確
#
# **任務：**
# 檢查所有欄位的資料型別是否正確

# %%
# TODO: 檢查資料型別

# %% [markdown]
# ---
#
# ### 🎯 Exercise 6.3：統計清理結果
#
# **任務：**
# 統計並印出清理前後的差異

# %%
# TODO: 統計清理結果
# - 原始資料筆數
# - 清理後筆數
# - 刪除筆數
# - 刪除率

# %% [markdown]
# ---
#
# ### 🎯 Exercise 6.4：儲存清理後的資料
#
# **任務：**
# 將清理後的資料儲存為 `data/hw_clean_orders.csv`

# %%
# TODO: 儲存清理後的資料

# %%
# TODO: 顯示清理後資料的前 10 筆

# %% [markdown]
# ---
#
# ## 🎉 作業完成！
#
# ### ✅ 作業檢查清單
#
# 請確認你已經完成：
#
# #### 📊 資料觀察
# - ✅ 讀取資料並觀察基本資訊
# - ✅ 使用 info() 和 describe() 檢查資料
# - ✅ 統計缺值數量
# - ✅ 檢查類別欄位的唯一值
#
# #### 🧹 資料清理
# - ✅ 處理缺值（刪除 / 填補 / 計算）
# - ✅ 轉換日期格式並處理無效日期
# - ✅ 轉換數值格式並處理特殊字元
# - ✅ 統一文字大小寫
# - ✅ 去除空白字元
# - ✅ 刪除重複訂單
# - ✅ 處理不合理數值
#
# #### 📝 最終檢查
# - ✅ 確認關鍵欄位沒有缺值
# - ✅ 確認資料型別正確
# - ✅ 統計清理前後的差異
# - ✅ 儲存清理後的資料
#
# #### 💭 思考與記錄
# - ✅ 在每個步驟寫下觀察和處理邏輯
# - ✅ 說明為什麼選擇這樣處理
# - ✅ 記錄遇到的問題和解決方法
#
# ---
#
# ### 📝 作業自我評估
#
# 請回答以下問題：
#
# 1. **最困難的部分是什麼？**
#
#    （請寫下）
#
# 2. **你學到了什麼？**
#
#    （請寫下）
#
# 3. **如果重新做一次，你會改變什麼處理方式？**
#
#    （請寫下）
#
# 4. **在真實工作中，你認為還需要注意什麼？**
#
#    （請寫下）
#
# ---
#
# **恭喜你完成作業！記得把 notebook 和清理後的 CSV 檔都交出來喔！** 🎉
