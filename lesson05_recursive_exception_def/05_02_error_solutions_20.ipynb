# %% [markdown]
# ## 第一部分：判斷錯誤類型解答（第 1～10 題）
#
# ---

# %% [markdown]
# ### 題目 1-1 解答
#
# **題目重述：**
# 字串 `book = '聯成Python'`，嘗試存取 `book[20]`
#
# **錯誤類型：** `IndexError: string index out of range`
#
# **為什麼會錯：**
# - 字串 '聯成Python' 的長度是 7
# - 有效的索引是 0, 1, 2, 3, 4, 5, 6
# - 索引 20 已經超出範圍了
# - Python 不會默認超出範圍的索引，必須檢查索引是否合法
#
# **修正後的程式碼：**

# %%
# 方法：先檢查長度，再取用有效的索引
book = '聯成Python'
print(f'字串長度：{len(book)}')
print(f'第 1 個字（索引 0）：{book[0]}')
print(f'最後一個字（索引 -1）：{book[-1]}')

# %% [markdown]
# **✅ 正確輸出：**
# ```
# 字串長度：7
# 第 1 個字（索引 0）：聯
# 最後一個字（索引 -1）：n
# ```
#
# **延伸提醒：**
# - 使用 `len(s)` 檢查字串/列表的長度
# - 有效索引範圍是 `0` 到 `len(s) - 1`
# - 可以用負索引存取（-1 = 最後一個，-2 = 倒數第二個）
# - 在存取索引前，一定要確認索引在範圍內

# %% [markdown]
# ---
#
# ### 題目 1-2 解答
#
# **題目重述：**
# ```python
# age = 25
# name = 'Bob'
# info = name + age
# ```
#
# **錯誤類型：** `TypeError: can only concatenate str (not "int") to str`
#
# **為什麼會錯：**
# - `name` 是字串 ('Bob')
# - `age` 是整數 (25)
# - Python 不允許直接將字串和整數相加
# - 只有相同類型的資料才能用 `+` 合併
#
# **修正後的程式碼：**

# %%
# 方法 1：轉換整數成字串
age = 25
name = 'Bob'
info = name + str(age)
print(info)

# 方法 2：使用格式化字符串（更推薦）
info2 = f'{name}{age}'
print(info2)

# 方法 3：使用 format()
info3 = '{}{}'.format(name, age)
print(info3)

# %% [markdown]
# **✅ 正確輸出：**
# ```
# Bob25
# Bob25
# Bob25
# ```
#
# **延伸提醒：**
# - 使用 `str()` 轉換整數為字串
# - 使用 `int()` / `float()` 轉換字串為數字
# - 用 `f'{變數}'` 格式化字符串最方便（Python 3.6+）
# - 遇到 TypeError 時，先用 `print(type(x))` 檢查資料類型

# %% [markdown]
# ---
#
# ### 題目 1-3 解答
#
# **題目重述：**
# ```python
# if score > 60
#     print('及格')
# ```
#
# **錯誤類型：** `SyntaxError: invalid syntax`
#
# **為什麼會錯：**
# - `if` 語句後面必須有冒號 `:`
# - Python 用冒號來表示「一個區塊的開始」
# - 少掉冒號，Python 無法理解程式碼結構
#
# **修正後的程式碼：**

# %%
# 修正：加上冒號，並正確縮排
score = 75
if score > 60:  # 記得冒號！
    print('及格')

# %% [markdown]
# **✅ 正確輸出：**
# ```
# 及格
# ```
#
# **延伸提醒：**
# - 所有的控制結構都需要冒號：`if`, `else`, `elif`, `for`, `while`, `def`, `class`
# - 冒號後面的內容要縮排（通常 4 個空格）
# - 如果看到 "SyntaxError: invalid syntax"，先檢查冒號

# %% [markdown]
# ---
#
# ### 題目 1-4 解答
#
# **題目重述：**
# ```python
# score = int('python')
# ```
#
# **錯誤類型：** `ValueError: invalid literal for int() with base 10: 'python'`
#
# **為什麼會錯：**
# - `int()` 的作用是把「看起來像數字的字串」轉成整數
# - 'python' 不是數字，所以無法轉換
# - 這是「值錯誤」（ValueError），不是類型錯誤
#
# **修正後的程式碼：**

# %%
# 方法 1：直接用有效的數字字串
score = int('95')
print(f'分數：{score}')

# 方法 2：先檢查是否為數字，再轉換
user_input = 'python'
if user_input.isdigit():
    score2 = int(user_input)
    print(f'分數：{score2}')
else:
    print('輸入不是有效的數字')

# %% [markdown]
# **✅ 正確輸出：**
# ```
# 分數：95
# 輸入不是有效的數字
# ```
#
# **延伸提醒：**
# - 在轉換前，用 `.isdigit()` 檢查字串是否為純數字
# - 如果是使用者輸入，一定要驗證後再轉換
# - 浮點數的檢查稍微複雜一點，可以用 try-except（後面課程會教）

# %% [markdown]
# ---
#
# ### 題目 1-5 解答
#
# **題目重述：**
# ```python
# print(name)
# ```
# （name 變數尚未定義）
#
# **錯誤類型：** `NameError: name 'name' is not defined`
#
# **為什麼會錯：**
# - 使用了一個尚未被定義的變數 `name`
# - Python 無法找到這個變數的值
# - NameError 通常表示變數名拼錯或忘記定義
#
# **修正後的程式碼：**

# %%
# 修正：先定義變數，再使用
name = 'Alice'
print(name)

# %% [markdown]
# **✅ 正確輸出：**
# ```
# Alice
# ```
#
# **延伸提醒：**
# - 變數要先定義（賦值）才能使用
# - NameError 通常表示拼字錯誤或順序錯誤
# - 如果不確定變數是否已定義，可以在開發環境中看「變數面板"（VSCode 有 Debug 功能）

# %% [markdown]
# ---
#
# ### 題目 1-6 解答
#
# **題目重述：**
# ```python
# result = 1 / 0
# ```
#
# **錯誤類型：** `ZeroDivisionError: division by zero`
#
# **為什麼會錯：**
# - 在數學上，除以 0 是未定義的
# - Python 不允許任何數字除以 0
# - 這是一個常見的邏輯錯誤
#
# **修正後的程式碼：**

# %%
# 方法 1：改成除以有效的數字
result = 1 / 10
print(f'結果：{result}')

# 方法 2：在除法前檢查分母
dividend = 100
divisor = 0

if divisor != 0:
    result2 = dividend / divisor
    print(f'{dividend} / {divisor} = {result2}')
else:
    print('分母不能為 0')

# %% [markdown]
# **✅ 正確輸出：**
# ```
# 結果：0.1
# 分母不能為 0
# ```
#
# **延伸提醒：**
# - 在做除法前，一定要檢查分母是否為 0
# - 使用 `if divisor != 0:` 來防止這類錯誤
# - 在計算平均數時也要小心（例如 sum / count，count 不能是 0）

# %% [markdown]
# ---
#
# ### 題目 1-7 解答
#
# **題目重述：**
# ```python
# for i in 5:
#     print(i)
# ```
#
# **錯誤類型：** `TypeError: 'int' object is not iterable`
#
# **為什麼會錯：**
# - `for` 迴圈需要「可迭代」的對象（例如列表、字串、range）
# - 整數 5 無法被迭代，因為它不是序列
# - 必須用 `range(5)` 來生成可迭代的序列
#
# **修正後的程式碼：**

# %%
# 修正：用 range() 來生成序列
for i in range(5):
    print(i)

# %% [markdown]
# **✅ 正確輸出：**
# ```
# 0
# 1
# 2
# 3
# 4
# ```
#
# **延伸提醒：**
# - `for` 迴圈常見用法：`for x in 列表:`, `for x in 字串:`, `for x in range(n):`
# - `range(5)` 產生 [0, 1, 2, 3, 4]
# - 如果想遍歷列表索引，用 `for i in range(len(lst)):`
# - 如果想直接遍歷元素，用 `for item in lst:`

# %% [markdown]
# ---
#
# ### 題目 1-8 解答
#
# **題目重述：**
# ```python
# if x > 10
#         print('x 很大')
# ```
#
# **錯誤類型：** 有多個錯誤
# - `SyntaxError`：缺少冒號
# - `IndentationError` 或 `SyntaxError`：縮排不規則
#
# **為什麼會錯：**
# - `if` 後面缺少冒號 `:`
# - 後面的縮排過多（應該 4 個空格，卻是 8 個）
# - Python 對縮排很敏感，不規則縮排會導致錯誤
#
# **修正後的程式碼：**

# %%
# 修正：加冒號，正確縮排（4 個空格）
x = 15
if x > 10:  # 加冒號
    print('x 很大')  # 4 個空格的縮排

# %% [markdown]
# **✅ 正確輸出：**
# ```
# x 很大
# ```
#
# **延伸提醒：**
# - Python 嚴格要求縮排（通常 4 個空格）
# - 不要混用 tab 和空格，容易出錯
# - VSCode 可以自動幫你縮排，選項 → 格式化
# - 看到 IndentationError，先檢查空格數量

# %% [markdown]
# ---
#
# ### 題目 1-9 解答
#
# **題目重述：**
# ```python
# students = ['Alice', 'Bob', 'Charlie']
# print(students[5])
# ```
#
# **錯誤類型：** `IndexError: list index out of range`
#
# **為什麼會錯：**
# - 列表 `students` 有 3 個元素（索引 0, 1, 2）
# - 索引 5 已經超出範圍
# - 列表的索引限制和字串一樣
#
# **修正後的程式碼：**

# %%
# 修正：使用有效的索引
students = ['Alice', 'Bob', 'Charlie']
print(f'列表長度：{len(students)}')
print(f'第 1 個學生：{students[0]}')
print(f'最後一個學生：{students[-1]}')
print(f'所有學生：{students}')

# %% [markdown]
# **✅ 正確輸出：**
# ```
# 列表長度：3
# 第 1 個學生：Alice
# 最後一個學生：Charlie
# 所有學生：['Alice', 'Bob', 'Charlie']
# ```
#
# **延伸提醒：**
# - 列表索引的有效範圍是 0 到 `len(list) - 1`
# - 用 `-1` 可以存取最後一個元素，`-2` 是倒數第二個
# - 在迴圈中，常用 `for item in list:` 直接遍歷，避免索引超出

# %% [markdown]
# ---
#
# ### 題目 1-10 解答
#
# **題目重述：**
# ```python
# nums = [1, 2, 3]
# for i in range(nums):
#     print(nums[i])
# ```
#
# **錯誤類型：** `TypeError: 'list' object cannot be interpreted as an integer`
#
# **為什麼會錯：**
# - `range()` 需要一個整數參數（例如 `range(5)`）
# - 傳入列表 `nums` 會導致 TypeError，因為列表不是整數
# - 應該用 `range(len(nums))` 來取得列表長度
#
# **修正後的程式碼：**

# %%
# 方法 1：使用 range(len(list))
nums = [1, 2, 3]
for i in range(len(nums)):
    print(f'索引 {i}: {nums[i]}')

print('---')

# 方法 2：直接遍歷列表（更簡潔）
for num in nums:
    print(f'元素: {num}')

# %% [markdown]
# **✅ 正確輸出：**
# ```
# 索引 0: 1
# 索引 1: 2
# 索引 2: 3
# ---
# 元素: 1
# 元素: 2
# 元素: 3
# ```
#
# **延伸提醒：**
# - `range()` 只接受整數，不接受列表或字串
# - 如果想遍歷列表，優先用 `for item in list:` 而不是 `for i in range(len(list)):`
# - 只有當你需要索引時，才用 `range(len(list))`

# %% [markdown]
# ---
#
# ## 📝 已完成第 1～10 題
#
# 恭喜！你已經學會了 7 種常見錯誤的判斷和修正方法：
# - ✅ IndexError（索引超出範圍）
# - ✅ TypeError（類型不相容）
# - ✅ SyntaxError（語法錯誤）
# - ✅ ValueError（值錯誤）
# - ✅ NameError（名稱未定義）
# - ✅ ZeroDivisionError（除以零）
# - ✅ IndentationError（縮排錯誤）
#
# ### 🎯 下一步
#
# **請繼續產第 11～20 題**的解答（修正程式讓它正常運作）
#
# 💪 加油！

# %% [markdown]
# ## 第二部分：修正程式讓它正常運作解答（第 11～20 題）
#
# ---
#
# ### 題目 2-1 解答
#
# **題目重述：**
# 計算三個數字的總和，程式碼缺右括號
#
# **問題所在：**
# ```python
# print(total  # 漏掉結尾的右括號
# ```
#
# **修正後的程式碼：**

# %%
a = 10
b = 20
c = 30
total = a + b + c
print(total)  # 加上結尾的右括號

# %% [markdown]
# **✅ 正確輸出：**
# ```
# 60
# ```
#
# **延伸提醒：**
# - 檢查括號是否成對：一個 `(` 一定要對應一個 `)`
# - VSCode 會用顏色標記括號配對，可以幫助檢查
# - 如果看到 SyntaxError 和「括號」相關的訊息，先數一遍括號
#
# ---
#
# ### 題目 2-2 解答
#
# **題目重述：**
# 轉換年齡為整數，檢查是否成人（>=18）
#
# **問題所在：**
# ```python
# if age >= 18        # 漏冒號
#     print('成人')   # 漏冒號
# else                # 漏冒號
#     print('未成年')
# ```
#
# **修正後的程式碼：**

# %%
age_str = "25"
age = int(age_str)
if age >= 18:  # 加冒號
    print('成人')
else:  # 加冒號
    print('未成年')

# %% [markdown]
# **✅ 正確輸出：**
# ```
# 成人
# ```
#
# **延伸提醒：**
# - `if`, `else`, `elif` 後面都要加冒號
# - 記住：「所有控制結構都需要冒號」（if, for, while, def, class）
#
# ---
#
# ### 題目 2-3 解答
#
# **題目重述：**
# 從字串提取第 1、3、5 個字，組成新字串，不能修改字串
#
# **問題所在：**
# ```python
# result[0] = 'X'  # 字串不可變，無法直接修改索引
# ```
#
# **修正後的程式碼：**

# %%
text = '聯成電腦Python'
result = text[0] + text[2] + text[4]
print(f'提取結果：{result}')

# 如果想修改，要重新組合字符串
new_result = 'X' + result[1] + result[2]
print(f'修改後：{new_result}')

# %% [markdown]
# **✅ 正確輸出：**
# ```
# 提取結果：聯電P
# 修改後：X電P
# ```
#
# **延伸提醒：**
# - 字符串是「不可變」(immutable) 的，只能重新組合
# - 如果要修改，可以轉成列表，修改後再轉回字符串
# - 列表是「可變」(mutable) 的，可以直接修改元素
#
# ---
#
# ### 題目 2-4 解答
#
# **題目重述：**
# 計算列表中每個元素的平方
#
# **問題所在：**
# ```python
# for i in range(len(numbers)+1):  # +1 導致索引超出範圍
#     square = numbers[i] ** 2
# ```
#
# **修正後的程式碼：**

# %%
numbers = [5, 10, 15]
for i in range(len(numbers)):  # 移除 +1
    square = numbers[i] ** 2
    print(f'{numbers[i]} 的平方是 {square}')

# %% [markdown]
# **✅ 正確輸出：**
# ```
# 5 的平方是 25
# 10 的平方是 100
# 15 的平方是 225
# ```
#
# **延伸提醒：**
# - `range(len(list))` 產生 0 到 `len(list) - 1`
# - 千萬不要加 `+1`！常見的陷阱
# - 更簡潔的寫法：`for num in numbers:`，直接遍歷元素
#
# ---
#
# ### 題目 2-5 解答
#
# **題目重述：**
# 計算平均分數
#
# **問題所在：**
# ```python
# average = total / (len(scores) - 4)  # len(scores) = 4，所以 4-4 = 0，除以零！
# ```
#
# **修正後的程式碼：**

# %%
scores = [85, 90, 78, 95]
total = sum(scores)
average = total / len(scores)  # 改成除以個數，不是 (len - 4)
print(f'分數：{scores}')

# %%
print(f'平均分數：{average}')

# %% [markdown]
# **✅ 正確輸出：**
# ```
# 分數：[85, 90, 78, 95]
# 平均分數：87.0
# ```
#
# **延伸提醒：**
# - 平均分數的公式：`sum / count`
# - 常見的錯誤：對分母計算錯誤
# - 計算前先用 `print(len(scores))` 檢查有多少個元素
#
# ---
#
# ### 題目 2-6 解答
#
# **題目重述：**
# 列印星號圖案，第 i 行印 i 個星號
#
# **問題所在：**
# ```python
# for i in range(3)   # 漏冒號
#     print('*' * i)  # 縮排問題
# ```
#
# **修正後的程式碼：**

# %%
for i in range(3):  # 加冒號
    print('*' * i)  # 正確縮排

# %% [markdown]
# **✅ 正確輸出：**
# ```
# (空白)
# *
# **
# ```
#
# **延伸提醒：**
# - `range(3)` 產生 0, 1, 2
# - `'*' * 0` = '' (空字符串)
# - `'*' * 1` = '*'
# - `'*' * 2` = '**'
#
# ---
#
# ### 題目 2-7 解答
#
# **題目重述：**
# 過濾列表中的偶數
#
# **問題所在：**
# ```python
# if num % 2 = 0:  # 應該是 ==，不是 =
# ```
#
# **修正後的程式碼：**

# %%
numbers = [1, 2, 3, 4, 5, 6]
evens = []
for num in numbers:
    if num % 2 == 0:  # 改成 == （比較），不是 = （賦值）
        evens.append(num)
print(evens)

# %% [markdown]
# **✅ 正確輸出：**
# ```
# [2, 4, 6]
# ```
#
# **延伸提醒：**
# - `=` 是賦值（assignment）
# - `==` 是比較（comparison）
# - 在條件判斷中一定要用 `==`！
# - 常見錯誤：`if x = 5:` 應該是 `if x == 5:`
#
# ---
#
# ### 題目 2-8 解答
#
# **題目重述：**
# 檢查字符串是否為迴文
#
# **問題所在：**
# ```python
# if word = reversed_word:  # 應該是 ==，不是 =
# ```
#
# **修正後的程式碼：**

# %%
# 測試迴文
word1 = 'racecar'
reversed_word1 = word1[::-1]
if word1 == reversed_word1:  # 改成 == （比較）
    print(f'{word1} 是迴文')
else:
    print(f'{word1} 不是迴文')

print('---')

# 測試非迴文
word2 = 'hello'
reversed_word2 = word2[::-1]
if word2 == reversed_word2:
    print(f'{word2} 是迴文')
else:
    print(f'{word2} 不是迴文')

# %% [markdown]
# **✅ 正確輸出：**
# ```
# racecar 是迴文
# ---
# hello 不是迴文
# ```
#
# **延伸提醒：**
# - `word[::-1]` 是反轉字符串的技巧（步長為 -1）
# - 同樣的錯誤很常見，一定要記住：條件判斷用 `==`！
#
# ---
#
# ### 題目 2-9 解答
#
# **題目重述：**
# 計算字典中所有值的總和
#
# **問題所在：**
# ```python
# print(total  # 漏右括號
# ```
#
# **修正後的程式碼：**

# %%
data = {'a': 10, 'b': 20, 'c': 30}
total = 0
for key in data:
    total = total + data[key]
print(total)  # 加上結尾的右括號

# %% [markdown]
# **✅ 正確輸出：**
# ```
# 60
# ```
#
# **延伸提醒：**
# - 遍歷字典時，`for key in data:` 會取得所有的鍵（key）
# - 要取得值，用 `data[key]`
# - 括號不成對是常見的語法錯誤，數一遍括號可以快速找到問題
#
# ---
#
# ### 題目 2-10 解答
#
# **題目重述：**
# 將字符串轉大寫，計數其中有多少個字母（不計空格）
#
# **問題所在：**
# ```python
# for char in upper_text  # 漏冒號
#     if char != ' ':     # 縮排問題
# ```
#
# **修正後的程式碼：**

# %%
text = 'Python Programming'
upper_text = text.upper()
count = 0
for char in upper_text:  # 加冒號
    if char != ' ':  # 正確縮排
        count = count + 1
print(f'字母個數：{count}')

# %% [markdown]
# **✅ 正確輸出：**
# ```
# 字母個數：17
# ```
#
# **延伸提醒：**
# - `for char in string:` 逐個迭代字符串中的字符
# - `.upper()` 轉大寫，`.lower()` 轉小寫
# - `char != ' '` 表示「不等於空格」
#
# ---
#
# ## 📝 恭喜完成！
#
# 你已經完成了全部 20 題的解答與解析！
#
# ### 🎯 學習成果
#
# **第 1～10 題（判斷錯誤類型）**
# - 學會識別 7 種常見錯誤
# - 理解每種錯誤的原因
# - 知道如何修正
#
# **第 11～20 題（修正程式）**
# - 練習實際修正程式碼
# - 理解邏輯錯誤和語法錯誤的區別
# - 增強程式碼品質意識
#
# ### 🚀 最後建議
#
# 1. **再做一次**：關掉解答，自己再做一遍練習題，看看是否都會
# 2. **舉一反三**：試著寫出自己的錯誤程式碼，看是否能正確判斷
# 3. **預防為主**：養成好習慣（檢查括號、縮排、冒號、比較符號）
# 4. **準備下一步**：學習 `try-except` 來主動捕捉和處理錯誤
#
# 祝學習愉快！🎉
