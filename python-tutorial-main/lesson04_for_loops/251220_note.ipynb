# %%
for num in range(3):
    print(num)
# Out:
# 0
# 1
# 2

# %%
lst = [10, 20, 30]
# lst[:2]
print(lst[:2])
# Out:
# [10, 20]

# %%
for i in range(1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
