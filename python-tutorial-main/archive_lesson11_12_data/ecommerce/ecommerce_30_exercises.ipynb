# %% [markdown]
# ## 題目 1：載入必要套件
#
# 載入 numpy、pandas、matplotlib.pyplot 三個套件

# %% [markdown]
# ## 題目 2：讀取資料
#
# 讀取 ecommerce_sales.csv 檔案並存入變數 df

# %% [markdown]
# ## 題目 3：顯示前 10 筆資料
#
# 使用適當方法顯示資料的前 10 筆

# %% [markdown]
# ## 題目 4：查看資料大小
#
# 印出資料的列數與欄數

# %% [markdown]
# ## 題目 5：列出所有欄位名稱
#
# 印出 DataFrame 的所有欄位名稱

# %% [markdown]
# ## 題目 6：篩選高價訂單
#
# 篩選出 price 大於 3000 的所有訂單

# %% [markdown]
# ## 題目 7：篩選特定地區
#
# 篩選出 region 為 'North' 的所有訂單

# %% [markdown]
# ## 題目 8：多條件篩選
#
# 篩選出 quantity 大於 3 且 channel 為 'Online' 的訂單

# %% [markdown]
# ## 題目 9：依單價排序
#
# 將資料依 price 由大到小排序，顯示前 5 筆

# %% [markdown]
# ## 題目 10：計算特定類別的訂單數
#
# 計算 category 為 'Electronics' 的訂單總數

# %% [markdown]
# ## 題目 11：計算營收欄位
#
# 新增 revenue 欄位，計算公式為 price × quantity

# %% [markdown]
# ## 題目 12：計算利潤欄位
#
# 新增 profit 欄位，計算公式為 (price - cost) × quantity

# %% [markdown]
# ## 題目 13：計算利潤率
#
# 新增 profit_margin 欄位，計算公式為 profit / revenue

# %% [markdown]
# ## 題目 14：計算總營收與總利潤
#
# 分別計算並印出所有訂單的總營收與總利潤

# %% [markdown]
# ## 題目 15：找出營收最高的訂單
#
# 找出並顯示 revenue 最高的那一筆訂單的完整資料

# %% [markdown]
# ## 題目 16：各類別總營收
#
# 使用 groupby 計算每個 category 的總營收

# %% [markdown]
# ## 題目 17：各地區訂單數與平均營收
#
# 使用 groupby 計算每個 region 的訂單數和平均營收

# %% [markdown]
# ## 題目 18：各通路的總營收與總利潤
#
# 使用 groupby 計算每個 channel 的總營收與總利潤

# %% [markdown]
# ## 題目 19：建立地區與類別交叉表
#
# 使用 pivot_table 建立 region（列）× category（欄）的營收交叉表

# %% [markdown]
# ## 題目 20：找出表現最好的產品
#
# 使用 groupby 找出總營收最高的前 3 個 product

# %% [markdown]
# ## 題目 21：計算營收的平均值、中位數與標準差
#
# 使用 numpy 函數計算 revenue 的平均值、中位數與標準差

# %% [markdown]
# ## 題目 22：計算營收的 90 分位數
#
# 使用 numpy 計算 revenue 的 90 分位數

# %% [markdown]
# ## 題目 23：分析前 20% 訂單的營收貢獻
#
# 計算營收前 20% 的訂單對總營收的貢獻百分比

# %% [markdown]
# ## 題目 24：使用 np.where 將訂單分級
#
# 新增 order_level 欄位，將訂單依營收分為三級：
# - revenue >= 10000：'High'
# - revenue >= 5000：'Medium'
# - 其他：'Low'

# %% [markdown]
# ## 題目 25：計算各級別訂單的數量與總營收
#
# 使用 groupby 統計每個 order_level 的訂單數與總營收

# %% [markdown]
# ## 題目 26：繪製營收分布直方圖
#
# 使用 matplotlib 繪製 revenue 的分布直方圖，設定 20 個區間

# %% [markdown]
# ## 題目 27：繪製各類別營收長條圖
#
# 繪製各 category 總營收的長條圖，並加上標題與軸標籤

# %% [markdown]
# ## 題目 28：繪製每日營收趨勢
#
# 將訂單依 order_date 分組計算每日總營收，並繪製折線圖

# %% [markdown]
# ## 題目 29：比較不同通路的平均訂單金額
#
# 計算並繪製各 channel 的平均營收長條圖，比較通路差異

# %% [markdown]
# ## 題目 30：綜合分析與商業建議
#
# 根據以上分析結果，找出：
# 1. 營收最高的類別
# 2. 表現最好的地區
# 3. 高價值訂單（前 10%）的平均營收
#
# 並提出一項商業建議
