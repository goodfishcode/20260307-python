# %%
# 輔助函式（檢查答案用）
def assert_equal(actual, expected, msg=""):
    if actual == expected:
        print("✅ PASS")
    else:
        print(f"❌ FAIL: {msg}")
        print(f"   預期：{expected}")
        print(f"   實際：{actual}")

# %% [markdown]
# ---
#
# ## 題目 1：建立一個空的 Class
#
# 建立一個名為 `Book` 的類別，不需要任何內容（使用 `pass`）。

# %%
# TODO: 建立 Book 類別


# 測試
book = Book()
print(f"✅ 成功建立 Book 物件：{type(book).__name__}")

# %% [markdown]
# ---
#
# ## 題目 2：建立有屬性的 Class
#
# 建立一個 `Car` 類別，有兩個屬性：`brand`（品牌）和 `color`（顏色）。

# %%
# TODO: 建立 Car 類別，包含 __init__ 方法


# 測試
car = Car("Tesla", "白色")
assert_equal(car.brand, "Tesla", "brand 屬性")
assert_equal(car.color, "白色", "color 屬性")

# %% [markdown]
# ---
#
# ## 題目 3：建立有方法的 Class
#
# 建立一個 `Dog` 類別，有一個屬性 `name`，和一個方法 `bark()` 會回傳字串 `"汪汪！"`。

# %%
# TODO: 建立 Dog 類別


# 測試
dog = Dog("阿福")
assert_equal(dog.name, "阿福", "name 屬性")
assert_equal(dog.bark(), "汪汪！", "bark() 方法")

# %% [markdown]
# ---
#
# ## 題目 4：計數器 Class
#
# 建立一個 `Counter` 類別：
# - 初始值為 0
# - 有 `increment()` 方法（加 1）
# - 有 `get_value()` 方法（回傳目前的值）

# %%
# TODO: 建立 Counter 類別


# 測試
counter = Counter()
assert_equal(counter.get_value(), 0, "初始值")
counter.increment()
counter.increment()
assert_equal(counter.get_value(), 2, "呼叫兩次 increment 後")

# %% [markdown]
# ---
#
# ## 題目 5：溫度轉換 Class
#
# 建立一個 `Temperature` 類別：
# - `__init__` 接收攝氏溫度 `celsius`
# - 有方法 `to_fahrenheit()` 回傳華氏溫度（公式：F = C × 9/5 + 32）

# %%
# TODO: 建立 Temperature 類別


# 測試
temp = Temperature(0)
assert_equal(temp.to_fahrenheit(), 32.0, "0°C = 32°F")
temp2 = Temperature(100)
assert_equal(temp2.to_fahrenheit(), 212.0, "100°C = 212°F")

# %% [markdown]
# ---
#
# ## 題目 6：Rectangle 類別
#
# 建立一個 `Rectangle` 類別：
# - 屬性：`width`（寬）、`height`（高）
# - 方法 `area()` 回傳面積
# - 方法 `perimeter()` 回傳周長

# %%
# TODO: 建立 Rectangle 類別


# 測試
rect = Rectangle(5, 10)
assert_equal(rect.area(), 50, "面積")
assert_equal(rect.perimeter(), 30, "周長")

# %% [markdown]
# ---
#
# ## 題目 7：Student 類別（有預設值）
#
# 建立一個 `Student` 類別：
# - 屬性：`name`、`grade`（預設值為 1）
# - 方法 `introduce()` 回傳字串：`"我是{name}，{grade}年級"`

# %%
# TODO: 建立 Student 類別


# 測試
student1 = Student("小明")
assert_equal(student1.introduce(), "我是小明，1年級", "有預設值")
student2 = Student("小華", 3)
assert_equal(student2.introduce(), "我是小華，3年級", "自訂年級")

# %% [markdown]
# ---
#
# ## 題目 8：可變動的屬性
#
# 建立一個 `Battery` 類別：
# - 初始電量為 100
# - 方法 `use(amount)` 會減少電量
# - 方法 `charge(amount)` 會增加電量
# - 方法 `get_level()` 回傳目前電量

# %%
# TODO: 建立 Battery 類別


# 測試
battery = Battery()
assert_equal(battery.get_level(), 100, "初始電量")
battery.use(30)
assert_equal(battery.get_level(), 70, "使用 30 後")
battery.charge(20)
assert_equal(battery.get_level(), 90, "充電 20 後")

# %% [markdown]
# ---
#
# ## 題目 9：List 管理
#
# 建立一個 `ShoppingList` 類別：
# - 初始化時有一個空的項目清單
# - 方法 `add(item)` 新增項目
# - 方法 `count()` 回傳項目總數

# %%
# TODO: 建立 ShoppingList 類別


# 測試
shopping = ShoppingList()
assert_equal(shopping.count(), 0, "初始為空")
shopping.add("蘋果")
shopping.add("香蕉")
assert_equal(shopping.count(), 2, "新增兩個項目後")

# %% [markdown]
# ---
#
# ## 題目 10：BMI 計算器
#
# 建立一個 `Person` 類別：
# - 屬性：`weight`（公斤）、`height`（公尺）
# - 方法 `calculate_bmi()` 回傳 BMI 值（公式：體重 ÷ 身高²）

# %%
# TODO: 建立 Person 類別


# 測試
person = Person(70, 1.75)
bmi = person.calculate_bmi()
assert_equal(round(bmi, 2), 22.86, "BMI 計算")

# %% [markdown]
# ---
#
# ## 題目 11：使用 @property（唯讀） - 選修
#
# 建立一個 `Circle` 類別：
# - 屬性：`radius`（半徑）
# - 使用 `@property` 建立唯讀屬性 `area`（面積 = π × r²，π 用 3.14）

# %%
# TODO: 建立 Circle 類別


# 測試
circle = Circle(10)
assert_equal(circle.area, 314.0, "面積計算")
assert_equal(circle.radius, 10, "半徑屬性")

# %% [markdown]
# ---
#
# ## 題目 12：保護屬性（用 _ 開頭）
#
# 建立一個 `Wallet` 類別：
# - 用 `_money` 儲存金額（初始為 0）
# - 方法 `add_money(amount)` 增加金額
# - 用 `@property` 建立 `money` 唯讀屬性

# %%
# TODO: 建立 Wallet 類別


# 測試
wallet = Wallet()
assert_equal(wallet.money, 0, "初始金額")
wallet.add_money(100)
wallet.add_money(50)
assert_equal(wallet.money, 150, "增加金額後")

# %% [markdown]
# ---
#
# ## 題目 13：驗證邏輯（不能為負數）
#
# 建立一個 `Stock` 類別：
# - 屬性 `quantity`（數量，初始為 0）
# - 方法 `add(amount)` 增加數量（如果 amount < 0 則不執行）
# - 方法 `remove(amount)` 減少數量（如果會變成負數則不執行）
# - 方法 `get_quantity()` 回傳目前數量

# %%
# TODO: 建立 Stock 類別


# 測試
stock = Stock()
stock.add(50)
assert_equal(stock.get_quantity(), 50, "新增 50")
stock.remove(20)
assert_equal(stock.get_quantity(), 30, "移除 20")
stock.remove(100)  # 超過數量，不應該執行
assert_equal(stock.get_quantity(), 30, "移除失敗，數量不變")
stock.add(-10)  # 負數，不應該執行
assert_equal(stock.get_quantity(), 30, "新增負數失敗")

# %% [markdown]
# ---
#
# ## 題目 14：類別變數 vs 實例變數
#
# 建立一個 `Robot` 類別：
# - 類別變數 `total_robots` 記錄總共建立了幾個機器人（初始為 0）
# - 實例變數 `name`
# - 每次建立新機器人時，`total_robots` 要 +1

# %%
# TODO: 建立 Robot 類別


# 測試
assert_equal(Robot.total_robots, 0, "初始為 0")
robot1 = Robot("R2D2")
assert_equal(Robot.total_robots, 1, "建立第一個機器人")
robot2 = Robot("C3PO")
assert_equal(Robot.total_robots, 2, "建立第二個機器人")

# %% [markdown]
# ---
#
# ## 題目 15：__str__ 方法
#
# 建立一個 `Product` 類別：
# - 屬性：`name`、`price`
# - 實作 `__str__` 方法，回傳格式：`"產品：{name}，價格：${price}"`

# %%
# TODO: 建立 Product 類別


# 測試
product = Product("iPhone", 30000)
assert_equal(str(product), "產品：iPhone，價格：$30000", "__str__ 方法")

# %% [markdown]
# ---
#
# ## 題目 16：基本繼承
#
# 建立一個 `Animal` 父類別和 `Cat` 子類別：
# - `Animal` 有屬性 `name` 和方法 `eat()` 回傳 `"正在吃飯"`
# - `Cat` 繼承 `Animal`，並新增方法 `meow()` 回傳 `"喵喵"`

# %%
# TODO: 建立 Animal 和 Cat 類別


# 測試
cat = Cat("小花")
assert_equal(cat.name, "小花", "繼承的屬性")
assert_equal(cat.eat(), "正在吃飯", "繼承的方法")
assert_equal(cat.meow(), "喵喵", "子類別的方法")

# %% [markdown]
# ---
#
# ## 題目 17：方法覆寫（Override）
#
# 建立 `Vehicle` 和 `Car` 類別：
# - `Vehicle` 有方法 `move()` 回傳 `"移動中"`
# - `Car` 繼承 `Vehicle`，覆寫 `move()` 方法回傳 `"開車中"`

# %%
# TODO: 建立 Vehicle 和 Car 類別


# 測試
vehicle = Vehicle()
assert_equal(vehicle.move(), "移動中", "父類別方法")
car = Car()
assert_equal(car.move(), "開車中", "子類別覆寫方法")

# %% [markdown]
# ---
#
# ## 題目 18：使用 super() 呼叫父類別的 __init__
#
# 建立 `Person` 和 `Employee` 類別：
# - `Person` 有屬性 `name` 和 `age`
# - `Employee` 繼承 `Person`，新增屬性 `employee_id`
# - `Employee` 的 `__init__` 要用 `super()` 呼叫父類別的 `__init__`

# %%
# TODO: 建立 Person 和 Employee 類別


# 測試
emp = Employee("小明", 30, "E001")
assert_equal(emp.name, "小明", "繼承的 name")
assert_equal(emp.age, 30, "繼承的 age")
assert_equal(emp.employee_id, "E001", "新增的 employee_id")

# %% [markdown]
# ---
#
# ## 題目 19：super() 與方法擴充
#
# 建立 `Rectangle` 和 `Square` 類別：
# - `Rectangle` 有 `__init__(width, height)` 和方法 `area()` 計算面積
# - `Square` 繼承 `Rectangle`，`__init__` 只接收 `side`（邊長）
# - `Square` 的 `__init__` 用 `super().__init__(side, side)` 初始化

# %%
# TODO: 建立 Rectangle 和 Square 類別


# 測試
square = Square(5)
assert_equal(square.area(), 25, "正方形面積")

# %% [markdown]
# ---
#
# ## 題目 20：多層繼承
#
# 建立三個類別：
# - `LivingThing`（生物）有方法 `breathe()` 回傳 `"呼吸中"`
# - `Animal` 繼承 `LivingThing`，新增方法 `move()` 回傳 `"移動中"`
# - `Dog` 繼承 `Animal`，新增方法 `bark()` 回傳 `"汪汪"`

# %%
# TODO: 建立 LivingThing、Animal、Dog 類別


# 測試
dog = Dog()
assert_equal(dog.breathe(), "呼吸中", "繼承自 LivingThing")
assert_equal(dog.move(), "移動中", "繼承自 Animal")
assert_equal(dog.bark(), "汪汪", "Dog 自己的方法")

# %% [markdown]
# ---
#
# ## 題目 21：多型（Polymorphism）基礎
#
# 建立 `Shape` 父類別和兩個子類別 `Circle` 和 `Rectangle`：
# - 所有類別都有方法 `describe()` 回傳形狀的描述
# - `Circle` 的 `describe()` 回傳 `"我是圓形"`
# - `Rectangle` 的 `describe()` 回傳 `"我是矩形"`

# %%
# TODO: 建立 Shape、Circle、Rectangle 類別


# 測試（多型：同樣的方法名稱，不同的行為）
shapes = [Circle(), Rectangle()]
results = [shape.describe() for shape in shapes]
assert_equal(results, ["我是圓形", "我是矩形"], "多型測試")

# %% [markdown]
# ---
#
# ## 題目 22：Shape 面積計算（多型應用）
#
# 建立 `Shape`、`Circle`、`Rectangle` 類別：
# - `Circle` 有 `__init__(radius)`，方法 `area()` 回傳 π × r²（π 用 3.14）
# - `Rectangle` 有 `__init__(width, height)`，方法 `area()` 回傳 寬 × 高

# %%
# TODO: 建立 Shape、Circle、Rectangle 類別


# 測試
shapes = [
    Circle(10),
    Rectangle(5, 8)
]
areas = [shape.area() for shape in shapes]
assert_equal(areas, [314.0, 40], "多型面積計算")

# %% [markdown]
# ---
#
# ## 題目 23：動物叫聲（多型）
#
# 建立 `Animal`、`Dog`、`Cat`、`Duck` 類別：
# - 所有類別都有方法 `speak()`
# - `Dog` 的 `speak()` 回傳 `"汪汪"`
# - `Cat` 的 `speak()` 回傳 `"喵喵"`
# - `Duck` 的 `speak()` 回傳 `"呱呱"`

# %%
# TODO: 建立 Animal、Dog、Cat、Duck 類別


# 測試
animals = [Dog(), Cat(), Duck()]
sounds = [animal.speak() for animal in animals]
assert_equal(sounds, ["汪汪", "喵喵", "呱呱"], "多型動物叫聲")

# %% [markdown]
# ---
#
# ## 題目 24：支付方式（多型）
#
# 建立 `Payment`、`CreditCard`、`Cash` 類別：
# - 所有類別都有方法 `pay(amount)`
# - `CreditCard` 的 `pay(amount)` 回傳 `f"信用卡支付 ${amount}"`
# - `Cash` 的 `pay(amount)` 回傳 `f"現金支付 ${amount}"`

# %%
# TODO: 建立 Payment、CreditCard、Cash 類別


# 測試
payments = [CreditCard(), Cash()]
results = [payment.pay(100) for payment in payments]
assert_equal(results, ["信用卡支付 $100", "現金支付 $100"], "多型支付方式")

# %% [markdown]
# ---
#
# ## 題目 25：super() 與方法擴充（進階）
#
# 建立 `BankAccount` 和 `SavingsAccount` 類別：
# - `BankAccount` 有 `__init__(balance)` 和方法 `deposit(amount)` 增加餘額
# - `SavingsAccount` 繼承 `BankAccount`，覆寫 `deposit(amount)`
# - `SavingsAccount` 的 `deposit()` 要先呼叫 `super().deposit(amount)`，然後再額外加 1% 利息

# %%
# TODO: 建立 BankAccount 和 SavingsAccount 類別


# 測試
savings = SavingsAccount(0)
savings.deposit(100)  # 100 + 1% = 101
assert_equal(savings.balance, 101, "存款 100，加 1% 利息")

# %% [markdown]
# ---
#
# ## 題目 26：綜合應用 — Item 類別
#
# 建立一個 `Item` 類別（商品）：
# - 屬性：`name`（名稱）、`price`（單價）、`quantity`（數量）
# - 方法 `total()` 回傳總價（單價 × 數量）

# %%
# TODO: 建立 Item 類別


# 測試
item = Item("蘋果", 30, 5)
assert_equal(item.total(), 150, "總價計算")

# %% [markdown]
# ---
#
# ## 題目 27：綜合應用 — ShoppingCart 類別
#
# 建立一個 `ShoppingCart` 類別（購物車）：
# - 初始化時有一個空的商品清單 `_items`
# - 方法 `add_item(item)` 新增商品（item 是 Item 物件）
# - 方法 `get_total()` 回傳購物車總金額（所有商品的 total() 加總）

# %%
# TODO: 建立 ShoppingCart 類別（需要先有 Item 類別）


# 測試
cart = ShoppingCart()
cart.add_item(Item("蘋果", 30, 5))   # 150
cart.add_item(Item("香蕉", 20, 3))   # 60
assert_equal(cart.get_total(), 210, "購物車總金額")

# %% [markdown]
# ---
#
# ## 題目 28：綜合應用 — Library 與 Book
#
# 建立 `Book` 和 `Library` 類別：
# - `Book` 有屬性 `title`、`author`、`available`（預設 True）
# - `Book` 有方法 `borrow()` 將 `available` 設為 False
# - `Book` 有方法 `return_book()` 將 `available` 設為 True
# - `Library` 有方法 `add_book(book)` 新增書籍
# - `Library` 有方法 `available_count()` 回傳可借閱書籍數量

# %%
# TODO: 建立 Book 和 Library 類別


# 測試
library = Library()
book1 = Book("Python 入門", "作者 A")
book2 = Book("JavaScript 入門", "作者 B")
library.add_book(book1)
library.add_book(book2)
assert_equal(library.available_count(), 2, "初始兩本可借")
book1.borrow()
assert_equal(library.available_count(), 1, "借走一本後")
book1.return_book()
assert_equal(library.available_count(), 2, "歸還後")

# %% [markdown]
# ---
#
# ## 題目 29：綜合應用 — 成績管理系統
#
# 建立 `Student` 和 `Classroom` 類別：
# - `Student` 有屬性 `name` 和 `_scores`（成績列表）
# - `Student` 有方法 `add_score(score)` 新增成績
# - `Student` 有 `@property average` 回傳平均分數
# - `Classroom` 有方法 `add_student(student)` 新增學生
# - `Classroom` 有方法 `class_average()` 回傳全班平均

# %%
# TODO: 建立 Student 和 Classroom 類別


# 測試
classroom = Classroom()
s1 = Student("小明")
s1.add_score(80)
s1.add_score(90)
s2 = Student("小華")
s2.add_score(70)
s2.add_score(80)
classroom.add_student(s1)
classroom.add_student(s2)
assert_equal(s1.average, 85.0, "小明平均")
assert_equal(s2.average, 75.0, "小華平均")
assert_equal(classroom.class_average(), 80.0, "全班平均")

# %% [markdown]
# ---
#
# ## 題目 30：終極挑戰 — 遊戲角色系統
#
# 建立完整的遊戲角色系統：
# - `Character` 父類別：屬性 `name`、`hp`、`attack_power`；方法 `attack()` 回傳攻擊力
# - `Warrior` 繼承 `Character`：覆寫 `attack()` 回傳攻擊力 × 1.5（戰士加成）
# - `Mage` 繼承 `Character`：覆寫 `attack()` 回傳攻擊力 × 2（法師加成）
# - `Battle` 類別：方法 `fight(char1, char2)` 比較兩個角色的 `attack()`，回傳攻擊力較高的角色名稱

# %%
# TODO: 建立 Character、Warrior、Mage、Battle 類別


# 測試
warrior = Warrior("戰士", 100, 20)  # 攻擊 20 × 1.5 = 30
mage = Mage("法師", 80, 15)         # 攻擊 15 × 2 = 30
battle = Battle()
assert_equal(warrior.attack(), 30.0, "戰士攻擊力")
assert_equal(mage.attack(), 30.0, "法師攻擊力")
# 這邊因為攻擊力相同，可以回傳任一個（題目可自行設計規則）
winner = battle.fight(warrior, mage)
print(f"✅ 對戰完成，結果：{winner}")

# %% [markdown]
# ---
#
# ## 🎉 恭喜完成所有練習！
#
# 如果你全部答對，代表你已經掌握：
# - ✅ Class 與 Object 的建立
# - ✅ 屬性與方法的使用
# - ✅ 封裝與 @property
# - ✅ 繼承與方法覆寫
# - ✅ super() 的使用
# - ✅ 多型的應用
# - ✅ 綜合專案設計
#
# **下一步**：
# - 複習答錯的題目
# - 嘗試修改測試案例，測試邊界情況
# - 設計自己的小專案練習 OOP
#
# 繼續加油！💪🚀
