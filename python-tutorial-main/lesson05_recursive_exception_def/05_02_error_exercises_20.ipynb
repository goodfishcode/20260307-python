# %% [markdown]
# ## 第一部分：判斷錯誤類型（第 1～10 題）
#
# **規則：** 下面每題都給一段「會出錯的程式碼」，請你：
# 1. **判斷**出是哪種錯誤類型（SyntaxError / NameError / TypeError 等）
# 2. **寫出修正版**，讓它可以正常執行
#
# ---

# %% [markdown]
# ### 題目 1-1
#
# **會出錯的程式碼：**
# ```python
# book = '聯成Python'
# print(book[20])
# ```
#
# **問題：**
# 1. 會出現什麼錯誤？
# 2. 寫出修正版，印出字串的第 1 個字
#
# **提示：** 字串有長度限制，索引也有範圍

# %%
# 寫出你的答案
# 1. 錯誤類型：
# 2. 修正版：

# %% [markdown]
# ---
#
# ### 題目 1-2
#
# **會出錯的程式碼：**
# ```python
# age = 25
# name = 'Bob'
# info = name + age
# print(info)
# ```
#
# **問題：**
# 1. 會出現什麼錯誤？
# 2. 寫出修正版，印出類似 `Bob25` 的結果
#
# **提示：** 不同的資料類型無法直接相加

# %%
# 寫出你的答案
# 1. 錯誤類型：
# 2. 修正版：

# %% [markdown]
# ---
#
# ### 題目 1-3
#
# **會出錯的程式碼：**
# ```python
# if score > 60
#     print('及格')
# ```
#
# **問題：**
# 1. 會出現什麼錯誤？
# 2. 寫出修正版（score = 75）
#
# **提示：** Python 的 if 語句有特定的語法要求

# %%
# 寫出你的答案
# 1. 錯誤類型：
# 2. 修正版：

# %% [markdown]
# ---
#
# ### 題目 1-4
#
# **會出錯的程式碼：**
# ```python
# score = int('python')
# print(score)
# ```
#
# **問題：**
# 1. 會出現什麼錯誤？
# 2. 寫出修正版，印出轉換後的整數（改成有效的數字字串）
#
# **提示：** int() 只能轉換看起來像數字的字串

# %%
# 寫出你的答案
# 1. 錯誤類型：
# 2. 修正版：

# %% [markdown]
# ---
#
# ### 題目 1-5
#
# **會出錯的程式碼：**
# ```python
# print(name)
# ```
#
# **問題：**
# 1. 會出現什麼錯誤？
# 2. 寫出修正版，先定義 name，再印出
#
# **提示：** 變數要先定義才能使用

# %%
# 寫出你的答案
# 1. 錯誤類型：
# 2. 修正版：

# %% [markdown]
# ---
#
# ### 題目 1-6
#
# **會出錯的程式碼：**
# ```python
# result = 100 / 0
# print(result)
# ```
#
# **問題：**
# 1. 會出現什麼錯誤？
# 2. 寫出修正版（改成除以 10 而不是 0）
#
# **提示：** 數學上，除以 0 是未定義的

# %%
# 寫出你的答案
# 1. 錯誤類型：
# 2. 修正版：

# %% [markdown]
# ---
#
# ### 題目 1-7
#
# **會出錯的程式碼：**
# ```python
# for i in 5:
#     print(i)
# ```
#
# **問題：**
# 1. 會出現什麼錯誤？
# 2. 寫出修正版，讓迴圈正常列印 0～4
#
# **提示：** for 迴圈需要可以迭代的對象，整數不行

# %%
# 寫出你的答案
# 1. 錯誤類型：
# 2. 修正版：

# %% [markdown]
# ---
#
# ### 題目 1-8
#
# **會出錯的程式碼：**
# ```python
# if x > 10
#         print('x 很大')
# ```
#
# **問題：**
# 1. 會出現什麼錯誤？（可能有多個）
# 2. 寫出修正版（設定 x = 15）
#
# **提示：** 注意冒號和縮排

# %%
# 寫出你的答案
# 1. 錯誤類型：
# 2. 修正版：

# %% [markdown]
# ---
#
# ### 題目 1-9
#
# **會出錯的程式碼：**
# ```python
# students = ['Alice', 'Bob', 'Charlie']
# print(students[5])
# ```
#
# **問題：**
# 1. 會出現什麼錯誤？
# 2. 寫出修正版，印出列表的最後一個元素
#
# **提示：** 列表的索引也有範圍限制

# %%
# 寫出你的答案
# 1. 錯誤類型：
# 2. 修正版：

# %% [markdown]
# ---
#
# ### 題目 1-10
#
# **會出錯的程式碼：**
# ```python
# nums = [1, 2, 3]
# for i in range(nums):
#     print(nums[i])
# ```
#
# **問題：**
# 1. 會出現什麼錯誤？
# 2. 寫出修正版，正確列印列表中的每個元素
#
# **提示：** range() 的參數應該是整數，不是列表

# %%
# 寫出你的答案
# 1. 錯誤類型：
# 2. 修正版：

# %% [markdown]
# ---
#
# ## 🎯 下一步
#
# 當你完成了第 1～10 題，準備好了嗎？
#
# **請繼續產第 11～20 題** → 修正程式讓它正常運作
#
# 💪 加油！你已經掌握了「判斷錯誤類型」的技能，下一個挑戰是「主動修正程式」。

# %% [markdown]
# ## 第二部分：修正程式讓它正常運作（第 11～20 題）
#
# **規則：** 下面每題都給一段「有問題的程式碼」，加上「題目需求」，請你：
# 1. **修改程式碼**，讓它可以正常執行
# 2. **印出正確的結果**（需求中會說明預期的輸出）
#
# ---
#
# ### 題目 2-1
#
# **需求：** 計算三個數字的總和（a=10, b=20, c=30），印出結果
#
# **有問題的程式碼：**
# ```python
# a = 10
# b = 20
# c = 30
# total = a + b + c
# print(total
# ```
#
# **提示：** 這應該是個簡單的語法問題

# %%
# 修正上面的程式碼，讓它正常計算總和並印出結果

# %% [markdown]
# ---
#
# ### 題目 2-2
#
# **需求：** 轉換使用者輸入的年齡為整數，並檢查是否成人（>=18）。如果輸入 "25"，應印出「成人」
#
# **有問題的程式碼：**
# ```python
# age_str = "25"
# age = int(age_str)
# if age >= 18
#     print('成人')
# else
#     print('未成年')
# ```
#
# **提示：** 有多個地方需要修正

# %%
# 修正上面的程式碼，讓年齡檢查正常運作

# %% [markdown]
# ---
#
# ### 題目 2-3
#
# **需求：** 從字串取出第 1、3、5 個字，組成新字串。原字串是 "聯成電腦Python"，應印出 "聯電P"
#
# **有問題的程式碼：**
# ```python
# text = '聯成電腦Python'
# result = text[0] + text[2] + text[4]
# result[0] = 'X'
# print(result)
# ```
#
# **提示：** 字串是不可變的，不能直接修改索引

# %%
# 修正上面的程式碼，讓它正確提取和組合字符

# %% [markdown]
# ---
#
# ### 題目 2-4
#
# **需求：** 計算清單 [5, 10, 15] 中每個元素的平方，印出結果
#
# **有問題的程式碼：**
# ```python
# numbers = [5, 10, 15]
# for i in range(len(numbers)+1):
#     square = numbers[i] ** 2
#     print(square)
# ```
#
# **提示：** 小心索引超出範圍

# %%
# 修正上面的程式碼，讓迴圈正確處理列表

# %% [markdown]
# ---
#
# ### 題目 2-5
#
# **需求：** 計算平均分數。分數清單是 [85, 90, 78, 95]，應印出平均數 87.0
#
# **有問題的程式碼：**
# ```python
# scores = [85, 90, 78, 95]
# total = sum(scores)
# average = total / (len(scores) - 4)
# print(average)
# ```
#
# **提示：** 檢查分母的計算邏輯

# %%
# 修正上面的程式碼，計算正確的平均分數

# %% [markdown]
# ---
#
# ### 題目 2-6
#
# **需求：** 列印星號圖案。列印 3 行，第 i 行印 i 個星號（共 3 行）
#
# **有問題的程式碼：**
# ```python
# for i in range(3)
#     print('*' * i)
# ```
#
# **提示：** 缺少冒號，也注意 range(3) 產生的值

# %%
# 修正上面的程式碼，正確列印星號圖案
# 預期輸出：
# (第 1 行：0 個星號，空白)
# * (第 2 行：1 個星號)
# ** (第 3 行：2 個星號)

# %% [markdown]
# ---
#
# ### 題目 2-7
#
# **需求：** 過濾列表中的偶數。輸入 [1, 2, 3, 4, 5, 6]，應印出 [2, 4, 6]
#
# **有問題的程式碼：**
# ```python
# numbers = [1, 2, 3, 4, 5, 6]
# evens = []
# for num in numbers:
#     if num % 2 = 0:
#         evens.append(num)
# print(evens)
# ```
#
# **提示：** 檢查條件判斷的語法

# %%
# 修正上面的程式碼，過濾出所有偶數

# %% [markdown]
# ---
#
# ### 題目 2-8
#
# **需求：** 檢查字串是否為迴文（正向和反向相同）。"racecar" 是迴文，"hello" 不是
#
# **有問題的程式碼：**
# ```python
# word = 'racecar'
# reversed_word = word[::-1]
# if word = reversed_word:
#     print('是迴文')
# else:
#     print('不是迴文')
# ```
#
# **提示：** 條件判斷要用 == 而不是 =

# %%
# 修正上面的程式碼，正確檢查迴文

# %% [markdown]
# ---
#
# ### 題目 2-9
#
# **需求：** 計算字典中所有值的總和。字典是 {'a': 10, 'b': 20, 'c': 30}，總和應該是 60
#
# **有問題的程式碼：**
# ```python
# data = {'a': 10, 'b': 20, 'c': 30}
# total = 0
# for key in data:
#     total = total + data[key]
# print(total
# ```
#
# **提示：** 檢查括號和迴圈邏輯

# %%
# 修正上面的程式碼，計算字典中所有值的總和

# %% [markdown]
# ---
#
# ### 題目 2-10
#
# **需求：** 將字符串轉大寫，計數其中有多少個字母。字符串是 "Python Programming"，應印出 17（不計空格）
#
# **有問題的程式碼：**
# ```python
# text = 'Python Programming'
# upper_text = text.upper()
# count = 0
# for char in upper_text
#     if char != ' ':
#         count = count + 1
# print(count)
# ```
#
# **提示：** 缺少冒號和其他語法問題

# %%
# 修正上面的程式碼，計算大寫字母的個數

# %% [markdown]
# ---
#
# ## 📝 本練習總結
#
# 恭喜你！你已經完成了 20 題練習，涵蓋：
#
# **第 1～10 題（判斷錯誤類型）**
# - IndexError、TypeError、SyntaxError、ValueError、NameError、ZeroDivisionError
#
# **第 11～20 題（修正程式）**
# - 語法修正（缺冒號、括號、縮排）
# - 邏輯修正（索引範圍、分母計算、比較運算符）
# - 資料類型修正（字串串接、條件判斷）
# - 迴圈和條件流程修正
#
# ### 💡 關鍵學習點
# 1. **看懂錯誤訊息** → 識別問題類型
# 2. **主動修正程式** → 從錯誤中學習
# 3. **測試程式碼** → 確保修正後可以執行
# 4. **理解邏輯** → 不只是修法，更要理解為什麼
#
# ### 🚀 下一步建議
# - 把這 20 題都完成一遍
# - 試著預測錯誤類型，再執行確認
# - 看看是否能舉出更多錯誤的例子
# - 準備學習「try-except」來主動捕捉錯誤！
#
# 祝學習愉快！🎉
