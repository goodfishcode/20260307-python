# %% [markdown]
# ## 題目 1：理解流程 — countdown(n)
#
# ### 題目描述
#
# 請寫一個遞迴函式 `countdown(n)`，會印出從 n 倒數到 1 的數字。
#
# ### 範例
#
# ```python
# countdown(5)
# ```
#
# **輸出：**
# ```
# 5
# 4
# 3
# 2
# 1
# ```
#
# ### 提示
#
# - **終止條件**：當 n == 0 時，不要再繼續
# - **遞迴部分**：印出 n，然後呼叫 countdown(n-1)
# - 每次呼叫時，n 要變小

# %%
# TODO: 請在這裡寫程式
def countdown(n):
    pass

# 測試
# countdown(5)

# %% [markdown]
# ## 題目 2：生活化理解 — open_doll(size)
#
# ### 題目描述
#
# 請寫一個遞迴函式 `open_doll(size)`，模擬打開俄羅斯娃娃的過程。
#
# - `size` 代表娃娃大小（整數）
# - 當 `size == 1`：印出「找到最小的娃娃！」
# - 否則：印出「打開大小 {size} 的娃娃」，然後繼續打開 `size-1`
#
# ### 範例
#
# ```python
# open_doll(3)
# ```
#
# **輸出：**
# ```
# 打開大小 3 的娃娃
# 打開大小 2 的娃娃
# 找到最小的娃娃！
# ```
#
# ### 提示
#
# - **終止條件**：size == 1
# - **問題變小**：每次 size 減 1
# - 使用 print() 輸出訊息

# %%
# TODO: 請在這裡寫程式
def open_doll(size):
    pass

# 測試
# open_doll(3)

# %% [markdown]
# ## 題目 3：數字總和 — sum_rec(n)
#
# ### 題目描述
#
# 請用遞迴寫一個函式 `sum_rec(n)`，計算 1 + 2 + 3 + ... + n 的總和。
#
# ### 範例
#
# ```python
# sum_rec(5)  # 應該回傳 15 (1+2+3+4+5)
# sum_rec(3)  # 應該回傳 6 (1+2+3)
# ```
#
# ### 提示
#
# - **終止條件**：當 n == 0 或 n == 1 時，回傳什麼？
# - **遞迴關係**：sum_rec(n) = n + sum_rec(n-1)
# - 記得要 `return` 結果

# %%
# TODO: 請在這裡寫程式
def sum_rec(n):
    pass

# 測試
# print(sum_rec(5))  # 應該是 15
# print(sum_rec(3))  # 應該是 6

# %% [markdown]
# ## 題目 4：階乘（基礎）— factorial(n)
#
# ### 題目描述
#
# 請用遞迴寫一個函式 `factorial(n)`，計算 n 的階乘（n!）。
#
# **階乘定義：**
# - n! = n × (n-1) × (n-2) × ... × 2 × 1
# - 0! = 1
# - 1! = 1
#
# ### 範例
#
# ```python
# factorial(4)  # 應該回傳 24 (4×3×2×1)
# factorial(5)  # 應該回傳 120 (5×4×3×2×1)
# factorial(0)  # 應該回傳 1
# ```
#
# ### 提示
#
# - **終止條件**：n == 0 或 n == 1 時，回傳 1
# - **遞迴關係**：n! = n × (n-1)!
# - factorial(n) = n × factorial(n-1)

# %%
# TODO: 請在這裡寫程式
def factorial(n):
    pass

# 測試
# print(factorial(4))  # 應該是 24
# print(factorial(5))  # 應該是 120
# print(factorial(0))  # 應該是 1

# %% [markdown]
# ## 題目 5：倒數回傳 — reverse_print(n)
#
# ### 題目描述
#
# 請寫一個遞迴函式 `reverse_print(n)`，會印出從 1 到 n 的數字（順序）。
#
# **注意**：這題跟題目 1 相反！要先遞迴到底，再印出來。
#
# ### 範例
#
# ```python
# reverse_print(3)
# ```
#
# **輸出：**
# ```
# 1
# 2
# 3
# ```
#
# ### 提示
#
# - **關鍵**：print() 要放在遞迴呼叫的**後面**
# - **終止條件**：n == 0 時停止
# - 順序：先呼叫 reverse_print(n-1)，再印出 n

# %%
# TODO: 請在這裡寫程式
def reverse_print(n):
    pass

# 測試
# reverse_print(3)

# %% [markdown]
# ## 題目 6：費氏數列（遞迴）— fib(n)
#
# ### 題目描述
#
# 請用遞迴寫一個函式 `fib(n)`，回傳第 n 個費氏數。
#
# **費氏數列定義：**
# - f(0) = 0
# - f(1) = 1
# - f(n) = f(n-1) + f(n-2)
#
# **數列：** 0, 1, 1, 2, 3, 5, 8, 13, 21, ...
#
# ### 範例
#
# ```python
# fib(0)  # 應該回傳 0
# fib(1)  # 應該回傳 1
# fib(5)  # 應該回傳 5
# fib(7)  # 應該回傳 13
# ```
#
# ### 提示
#
# - **終止條件有兩個**：n == 0 和 n == 1
# - **遞迴關係**：f(n) = f(n-1) + f(n-2)
# - 這題需要呼叫兩次遞迴

# %%
# TODO: 請在這裡寫程式
def fib(n):
    pass

# 測試
# print(fib(0))  # 應該是 0
# print(fib(1))  # 應該是 1
# print(fib(5))  # 應該是 5
# print(fib(7))  # 應該是 13

# %% [markdown]
# ## 題目 7：字串反轉 — reverse_string(s)
#
# ### 題目描述
#
# 請用遞迴寫一個函式 `reverse_string(s)`，回傳反轉後的字串。
#
# ### 範例
#
# ```python
# reverse_string("hello")  # 應該回傳 "olleh"
# reverse_string("abc")    # 應該回傳 "cba"
# reverse_string("a")      # 應該回傳 "a"
# ```
#
# ### 提示
#
# - **終止條件**：字串長度為 0 或 1 時，直接回傳
# - **遞迴思路**：
#   - 字串的第一個字元是 `s[0]`
#   - 剩下的字串是 `s[1:]`
#   - reverse_string("hello") = reverse_string("ello") + "h"
# - 字串可以用 `+` 連接

# %%
# TODO: 請在這裡寫程式
def reverse_string(s):
    pass

# 測試
# print(reverse_string("hello"))  # 應該是 "olleh"
# print(reverse_string("abc"))    # 應該是 "cba"

# %% [markdown]
# ## 題目 8：計算清單長度 — list_length(lst)
#
# ### 題目描述
#
# 請用遞迴寫一個函式 `list_length(lst)`，計算清單的長度。
#
# **限制：不可以使用內建的 `len()` 函式！**
#
# ### 範例
#
# ```python
# list_length([1, 2, 3, 4, 5])  # 應該回傳 5
# list_length([10, 20])          # 應該回傳 2
# list_length([])                # 應該回傳 0
# ```
#
# ### 提示
#
# - **終止條件**：空清單的長度是 0
# - **遞迴思路**：
#   - 清單有一個元素 + 剩下的清單長度
#   - `lst[1:]` 代表從第二個元素開始的子清單
#   - list_length([1,2,3]) = 1 + list_length([2,3])

# %%
# TODO: 請在這裡寫程式
def list_length(lst):
    pass

# 測試
# print(list_length([1, 2, 3, 4, 5]))  # 應該是 5
# print(list_length([10, 20]))          # 應該是 2
# print(list_length([]))                # 應該是 0

# %% [markdown]
# ## 題目 9：最大值（遞迴）— find_max(lst)
#
# ### 題目描述
#
# 請用遞迴寫一個函式 `find_max(lst)`，回傳清單中的最大值。
#
# **假設清單不為空。**
#
# ### 範例
#
# ```python
# find_max([3, 7, 2, 9, 1])  # 應該回傳 9
# find_max([5, 2, 8, 1])     # 應該回傳 8
# find_max([10])             # 應該回傳 10
# ```
#
# ### 提示
#
# - **終止條件**：清單只剩一個元素時，那個元素就是最大值
# - **遞迴思路**：
#   - 比較第一個元素 `lst[0]` 和剩下元素的最大值
#   - 使用 `max()` 函式比較兩個數字
#   - find_max([3,7,2]) = max(3, find_max([7,2]))

# %%
# TODO: 請在這裡寫程式
def find_max(lst):
    pass

# 測試
# print(find_max([3, 7, 2, 9, 1]))  # 應該是 9
# print(find_max([5, 2, 8, 1]))     # 應該是 8
# print(find_max([10]))             # 應該是 10

# %% [markdown]
# ## 題目 10：遞迴思考題 💭
#
# ### 題目描述
#
# 請用文字說明（不用寫程式）：
#
# **為什麼「沒有終止條件的遞迴」一定會出問題？**
#
# 請從以下角度思考：
# 1. 函式會一直呼叫自己，會發生什麼事？
# 2. 記憶體會怎麼樣？
# 3. 最後會出現什麼錯誤？
#
# ### 請在下方 Markdown cell 用自己的話回答

# %% [markdown]
# ### 💡 我的回答：
#
# <!-- 請在這裡寫下你的想法 -->

# %% [markdown]
# ---
#
# ## 🎉 完成練習！
#
# 恭喜你完成所有遞迴練習題！
#
# ### 📚 複習重點：
#
# 1. **終止條件（base case）** 是遞迴的關鍵
# 2. 每次遞迴呼叫時，**問題要變小**
# 3. 遞迴適合處理「可拆成相似子問題」的情況
# 4. 要注意效能問題（如費氏數列的重複計算）
#
# ### 💪 下一步：
#
# - 比較遞迴與迴圈的寫法
# - 學習記憶化（Memoization）優化遞迴
# - 探索更複雜的遞迴應用（樹、圖、回溯法）
#
# **繼續加油！🚀**
