# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目20：串列元素累加
# 給定串列 `values = [5, 12, 8, 3, 15]`，使用 while 迴圈和索引計算串列所有元素的總和。

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目19：尋找第一個可被7整除的數
# 使用 while 迴圈從 50 開始往上找，找到第一個可被 7 整除的數字並印出。

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目18：累加到目標值
# 使用 while 迴圈，從 0 開始累加，每次加 1，直到總和大於等於 50，印出總和及執行次數。

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目17：倒數計數
# 使用 while 迴圈從 10 倒數到 1，然後印出 "發射！"

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目16：基本 while 迴圈
# 使用 while 迴圈印出 1 到 5 的數字。

# %% [markdown]
# ## while 迴圈題目 (16-20題)

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目15：串列元素走訪
# 給定串列 `names = ["Alice", "Bob", "Charlie", "David"]`，使用 for 迴圈印出每個名字，格式為："Hello, [名字]!"

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目14：九九乘法表（單行）
# 使用 for range 迴圈印出 5 的乘法表（5x1 到 5x9）。

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目13：偶數印出
# 使用 for range 迴圈印出 0 到 20 之間的所有偶數。

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目12：計算總和
# 使用 for range 迴圈計算 1 到 100 的總和，並印出結果。

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目11：印出數字
# 使用 for range 迴圈印出 1 到 10 的所有數字（每個數字一行）。

# %% [markdown]
# ## for range 迴圈題目 (11-15題)

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目10：串列長度與最大最小值
# 給定串列 `scores = [85, 92, 78, 90, 88]`，印出串列長度、最大值和最小值。

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目9：串列刪除元素
# 給定串列 `items = [1, 2, 3, 4, 5]`，刪除第3個元素（索引為2），然後印出串列。

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目8：串列切片
# 給定串列 `colors = ["red", "green", "blue", "yellow", "purple"]`，取出中間三個元素並印出。

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目7：串列索引取值
# 給定串列 `numbers = [10, 20, 30, 40, 50]`，印出第一個和最後一個元素。

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目6：串列新增元素
# 建立一個空串列 `fruits = []`，依序加入 "apple"、"banana"、"cherry"，然後印出串列。

# %% [markdown]
# ## 串列題目 (6-10題)

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目5：字符串分割
# 給定字符串 `email = "user@example.com"`，使用 split() 方法以 "@" 分割，並印出分割後的串列。

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目4：字符串取代
# 給定字符串 `sentence = "I love Java"`，將 "Java" 取代為 "Python" 並印出。

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目3：字符串大小寫轉換
# 給定字符串 `message = "python is FUN"`，將它全部轉為大寫並印出。

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目2：字符串切片
# 給定字符串 `text = "Hello World"`，取出並印出前5個字元。

# %%
# 請在此處撰寫程式碼

# %% [markdown]
# ### 題目1：字符串長度
# 宣告一個字符串變數 `name = "Python程式設計"`，印出這個字符串的長度。

# %% [markdown]
# ## 字符串題目 (1-5題)

# %% [markdown]
# # L1-L4 複習測驗：字符串、串列、迴圈
#
# 本測驗包含20道題目，涵蓋以下主題：
# - 字符串 (str) 操作
# - 串列 (list) 操作
# - for range 迴圈
# - while 迴圈
#
# 請在每題下方的程式碼區塊中完成答案。
