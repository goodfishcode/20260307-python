# %% [markdown]
# ---
#
# ## 題目 1：無參數函式 - 打招呼
#
# **題目描述：**
#
# 請定義一個函式 `say_hello()`，此函式**不接受任何參數**，功能是**回傳**字串 `"Hello, Python!"`。
#
# **要求：**
# - 函式名稱：`say_hello`
# - 參數：無
# - 回傳：字串 `"Hello, Python!"`
#
# **範例：**
# ```python
# result = say_hello()
# print(result)  # 輸出：Hello, Python!
# ```

# %%
# 作答區
def say_hello():
    # TODO: 回傳 "Hello, Python!"
    pass

# %%
# 測試
result = say_hello()
assert result == "Hello, Python!", "測試失敗"
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 2：簡單計算 - 面積計算
#
# **題目描述：**
#
# 請定義一個函式 `calculate_area(width, height)`，計算矩形面積並回傳。
#
# **要求：**
# - 函式名稱：`calculate_area`
# - 參數：`width`（寬）、`height`（高）
# - 回傳：矩形面積（width × height）
#
# **範例：**
# ```python
# area = calculate_area(5, 10)
# print(area)  # 輸出：50
# ```

# %%
# 作答區
def calculate_area(width, height):
    # TODO: 計算並回傳面積
    pass

# %%
# 測試
assert calculate_area(5, 10) == 50
assert calculate_area(3, 7) == 21
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 3：字典查詢 - 取得分數
#
# **題目描述：**
#
# 給定一個字典 `scores`（學生姓名對應分數），請定義函式 `get_score(scores, name)`，查詢指定學生的分數。
#
# **要求：**
# - 函式名稱：`get_score`
# - 參數：`scores`（字典）、`name`（學生姓名）
# - 回傳：如果學生存在，回傳分數；否則回傳 `None`
# - 提示：使用 `.get()` 方法
#
# **範例：**
# ```python
# scores = {'Alice': 85, 'Bob': 92, 'Charlie': 78}
# print(get_score(scores, 'Alice'))    # 輸出：85
# print(get_score(scores, 'David'))    # 輸出：None
# ```

# %%
# 作答區
def get_score(scores, name):
    # TODO: 使用 .get() 查詢並回傳分數
    pass

# %%
# 測試
scores = {'Alice': 85, 'Bob': 92, 'Charlie': 78}
assert get_score(scores, 'Alice') == 85
assert get_score(scores, 'David') is None
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 4：排序比較 - sorted vs sort
#
# **題目描述：**
#
# 請定義函式 `sort_comparison(numbers)`，此函式接收一個數字串列，分別使用 `sorted()` 和 `.sort()` 進行排序，並**回傳 tuple**：`(sorted_result, original_after_sort)`。
#
# **要求：**
# - 先使用 `sorted(numbers)` 得到排序後的新串列
# - 再對 `numbers` 使用 `.sort()` 方法（會修改原串列）
# - 回傳 `(sorted_result, numbers)`
#
# **範例：**
# ```python
# result = sort_comparison([3, 1, 4, 1, 5])
# print(result)  # 輸出：([1, 1, 3, 4, 5], [1, 1, 3, 4, 5])
# ```

# %%
# 作答區
def sort_comparison(numbers):
    # TODO: 使用 sorted() 和 .sort()，回傳 tuple
    pass

# %%
# 測試
result = sort_comparison([3, 1, 4, 1, 5])
assert result == ([1, 1, 3, 4, 5], [1, 1, 3, 4, 5])
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 5：預設參數 - 問候函式
#
# **題目描述：**
#
# 請定義函式 `greet(name, greeting="Hello")`，回傳問候語。
#
# **要求：**
# - 參數 `greeting` 預設值為 `"Hello"`
# - 回傳格式：`"{greeting}, {name}!"`
#
# **範例：**
# ```python
# print(greet("Alice"))              # 輸出：Hello, Alice!
# print(greet("Bob", "Hi"))          # 輸出：Hi, Bob!
# ```

# %%
# 作答區
def greet(name, greeting="Hello"):
    # TODO: 回傳問候語
    pass

# %%
# 測試
assert greet("Alice") == "Hello, Alice!"
assert greet("Bob", "Hi") == "Hi, Bob!"
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 6：字典統計 - 字元計數
#
# **題目描述：**
#
# 請定義函式 `count_chars(text)`，統計字串中每個字元出現的次數，回傳字典。
#
# **要求：**
# - 參數：`text`（字串）
# - 回傳：字典，key 為字元，value 為出現次數
# - 提示：可以用 for 迴圈 + dict 的 get() 或直接判斷 key in dict
#
# **範例：**
# ```python
# result = count_chars("hello")
# print(result)  # 輸出：{'h': 1, 'e': 1, 'l': 2, 'o': 1}
# ```

# %%
# 作答區
def count_chars(text):
    # TODO: 統計字元出現次數並回傳字典
    pass

# %%
# 測試
result = count_chars("hello")
assert result == {'h': 1, 'e': 1, 'l': 2, 'o': 1}
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 7：函式排序 - 數字排序回傳
#
# **題目描述：**
#
# 請定義函式 `sort_numbers(numbers, reverse=False)`，將數字串列排序後回傳。
#
# **要求：**
# - 使用 `sorted()` 函式
# - 參數 `reverse` 決定是否遞減排序（預設為 False，即遞增）
# - 回傳排序後的新串列
#
# **範例：**
# ```python
# print(sort_numbers([3, 1, 4, 1, 5]))           # 輸出：[1, 1, 3, 4, 5]
# print(sort_numbers([3, 1, 4, 1, 5], True))     # 輸出：[5, 4, 3, 1, 1]
# ```

# %%
# 作答區
def sort_numbers(numbers, reverse=False):
    # TODO: 使用 sorted() 排序並回傳
    pass

# %%
# 測試
assert sort_numbers([3, 1, 4, 1, 5]) == [1, 1, 3, 4, 5]
assert sort_numbers([3, 1, 4, 1, 5], True) == [5, 4, 3, 1, 1]
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 8：函式字典 - 更新學生成績
#
# **題目描述：**
#
# 請定義函式 `update_score(scores, name, new_score)`，更新指定學生的成績。
#
# **要求：**
# - 如果學生存在，更新其分數
# - 如果學生不存在，新增此學生
# - 回傳更新後的字典
#
# **範例：**
# ```python
# scores = {'Alice': 85, 'Bob': 92}
# result = update_score(scores, 'Alice', 90)
# print(result)  # 輸出：{'Alice': 90, 'Bob': 92}
# ```

# %%
# 作答區
def update_score(scores, name, new_score):
    # TODO: 更新或新增成績，回傳字典
    pass

# %%
# 測試
scores = {'Alice': 85, 'Bob': 92}
result = update_score(scores, 'Alice', 90)
assert result['Alice'] == 90
result = update_score(scores, 'Charlie', 88)
assert result['Charlie'] == 88
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 9：Lambda 排序 - 依絕對值排序
#
# **題目描述：**
#
# 請定義函式 `sort_by_abs(numbers)`，將數字串列依照**絕對值大小**排序。
#
# **要求：**
# - 使用 `sorted()` 搭配 `key` 參數
# - `key` 使用 lambda 函式，取得絕對值
# - 回傳排序後的串列
#
# **範例：**
# ```python
# result = sort_by_abs([3, -5, 2, -1, 4])
# print(result)  # 輸出：[-1, 2, 3, 4, -5]
# ```

# %%
# 作答區
def sort_by_abs(numbers):
    # TODO: 使用 sorted() + key=lambda 依絕對值排序
    pass

# %%
# 測試
result = sort_by_abs([3, -5, 2, -1, 4])
assert result == [-1, 2, 3, 4, -5]
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 10：字典合併 - 相同 key 相加
#
# **題目描述：**
#
# 請定義函式 `merge_dicts(dict1, dict2)`，合併兩個字典。如果有相同的 key，則將 value 相加。
#
# **要求：**
# - 回傳新的字典（不修改原字典）
# - 相同 key 的 value 要相加
#
# **範例：**
# ```python
# d1 = {'a': 1, 'b': 2}
# d2 = {'b': 3, 'c': 4}
# result = merge_dicts(d1, d2)
# print(result)  # 輸出：{'a': 1, 'b': 5, 'c': 4}
# ```

# %%
# 作答區
def merge_dicts(dict1, dict2):
    # TODO: 合併兩個字典，相同 key 的值相加
    pass

# %%
# 測試
d1 = {'a': 1, 'b': 2}
d2 = {'b': 3, 'c': 4}
result = merge_dicts(d1, d2)
assert result == {'a': 1, 'b': 5, 'c': 4}
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 11：多值回傳 - 統計資訊
#
# **題目描述：**
#
# 請定義函式 `get_stats(numbers)`，計算串列的總和、平均值、最大值、最小值，並以 tuple 回傳。
#
# **要求：**
# - 回傳格式：`(總和, 平均值, 最大值, 最小值)`
# - 平均值請使用浮點數
#
# **範例：**
# ```python
# result = get_stats([1, 2, 3, 4, 5])
# print(result)  # 輸出：(15, 3.0, 5, 1)
# ```

# %%
# 作答區
def get_stats(numbers):
    # TODO: 計算統計資訊並回傳 tuple
    pass

# %%
# 測試
result = get_stats([1, 2, 3, 4, 5])
assert result == (15, 3.0, 5, 1)
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 12：Helper 函式 - 溫度轉換
#
# **題目描述：**
#
# 請定義兩個函式：
# 1. `celsius_to_fahrenheit(c)`：將攝氏轉為華氏（公式：F = C × 9/5 + 32）
# 2. `convert_temperatures(temps)`：接收攝氏溫度串列，回傳華氏溫度串列
#
# **要求：**
# - `convert_temperatures()` 要**呼叫** `celsius_to_fahrenheit()`
# - 回傳轉換後的串列
#
# **範例：**
# ```python
# result = convert_temperatures([0, 100, 37])
# print(result)  # 輸出：[32.0, 212.0, 98.6]
# ```

# %%
# 作答區
def celsius_to_fahrenheit(c):
    # TODO: 攝氏轉華氏
    pass

def convert_temperatures(temps):
    # TODO: 呼叫 celsius_to_fahrenheit()，回傳轉換後的串列
    pass

# %%
# 測試
result = convert_temperatures([0, 100, 37])
assert result == [32.0, 212.0, 98.6]
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 13：Tuple 排序 - 依第二元素排序
#
# **題目描述：**
#
# 給定一個 list of tuple（學生姓名與分數），請定義函式 `sort_by_score(students)`，依照分數由高到低排序。
#
# **要求：**
# - 使用 `sorted()` 搭配 `key` 參數
# - 分數由高到低（reverse=True）
#
# **範例：**
# ```python
# students = [('Alice', 85), ('Bob', 92), ('Charlie', 78)]
# result = sort_by_score(students)
# print(result)  # 輸出：[('Bob', 92), ('Alice', 85), ('Charlie', 78)]
# ```

# %%
# 作答區
def sort_by_score(students):
    # TODO: 依分數排序（高到低）
    pass

# %%
# 測試
students = [('Alice', 85), ('Bob', 92), ('Charlie', 78)]
result = sort_by_score(students)
assert result == [('Bob', 92), ('Alice', 85), ('Charlie', 78)]
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 14：分類統計 - 年齡分組
#
# **題目描述：**
#
# 請定義函式 `group_by_age(people)`，將人員依年齡分組。
#
# **要求：**
# - 輸入：list of dict，格式：`[{'name': 'Alice', 'age': 25}, ...]`
# - 輸出：dict，key 為年齡，value 為該年齡的人名串列
#
# **範例：**
# ```python
# people = [
#     {'name': 'Alice', 'age': 25},
#     {'name': 'Bob', 'age': 30},
#     {'name': 'Charlie', 'age': 25}
# ]
# result = group_by_age(people)
# print(result)  # 輸出：{25: ['Alice', 'Charlie'], 30: ['Bob']}
# ```

# %%
# 作答區
def group_by_age(people):
    # TODO: 依年齡分組，回傳字典
    pass

# %%
# 測試
people = [
    {'name': 'Alice', 'age': 25},
    {'name': 'Bob', 'age': 30},
    {'name': 'Charlie', 'age': 25}
]
result = group_by_age(people)
assert result == {25: ['Alice', 'Charlie'], 30: ['Bob']}
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 15：單字統計 - 計算單字頻率
#
# **題目描述：**
#
# 請定義函式 `word_frequency(text)`，統計文字中每個單字出現的次數。
#
# **要求：**
# - 使用 `.split()` 分割單字
# - 回傳字典，key 為單字，value 為出現次數
# - 不區分大小寫（全部轉為小寫）
#
# **範例：**
# ```python
# text = "Hello world hello Python"
# result = word_frequency(text)
# print(result)  # 輸出：{'hello': 2, 'world': 1, 'python': 1}
# ```

# %%
# 作答區
def word_frequency(text):
    # TODO: 統計單字頻率並回傳字典
    pass

# %%
# 測試
text = "Hello world hello Python"
result = word_frequency(text)
assert result == {'hello': 2, 'world': 1, 'python': 1}
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 16：自訂排序 - 依字串長度排序
#
# **題目描述：**
#
# 請定義函式 `sort_by_length(words)`，將字串串列依照長度排序（由短到長）。如果長度相同，則依字母順序排序。
#
# **要求：**
# - 使用 `sorted()` 搭配 `key` 參數
# - key 可以回傳 tuple：`(長度, 字串本身)`
#
# **範例：**
# ```python
# words = ["apple", "pie", "banana", "cat"]
# result = sort_by_length(words)
# print(result)  # 輸出：['cat', 'pie', 'apple', 'banana']
# ```

# %%
# 作答區
def sort_by_length(words):
    # TODO: 依長度排序（相同長度則依字母順序）
    pass

# %%
# 測試
words = ["apple", "pie", "banana", "cat"]
result = sort_by_length(words)
assert result == ['cat', 'pie', 'apple', 'banana']
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 17：條件篩選 - 及格名單
#
# **題目描述：**
#
# 請定義函式 `get_passed_students(scores, passing_score=60)`，從成績字典中篩選出及格的學生。
#
# **要求：**
# - 參數：`scores`（字典）、`passing_score`（及格分數，預設 60）
# - 回傳：新字典，只包含及格的學生
#
# **範例：**
# ```python
# scores = {'Alice': 85, 'Bob': 55, 'Charlie': 70}
# result = get_passed_students(scores)
# print(result)  # 輸出：{'Alice': 85, 'Charlie': 70}
# ```

# %%
# 作答區
def get_passed_students(scores, passing_score=60):
    # TODO: 篩選及格學生並回傳新字典
    pass

# %%
# 測試
scores = {'Alice': 85, 'Bob': 55, 'Charlie': 70}
result = get_passed_students(scores)
assert result == {'Alice': 85, 'Charlie': 70}
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 18：成績處理 - 排序與統計
#
# **題目描述：**
#
# 請定義以下函式：
# 1. `calculate_average(scores)`：計算平均分數（helper function）
# 2. `process_scores(students)`：處理學生成績，回傳排序後的串列與平均分數
#
# **要求：**
# - 輸入：list of dict，格式：`[{'name': 'Alice', 'score': 85}, ...]`
# - 依分數由高到低排序
# - 回傳 tuple：`(排序後的串列, 平均分數)`
#
# **範例：**
# ```python
# students = [
#     {'name': 'Alice', 'score': 85},
#     {'name': 'Bob', 'score': 92},
#     {'name': 'Charlie', 'score': 78}
# ]
# sorted_list, avg = process_scores(students)
# print(sorted_list[0])  # 輸出：{'name': 'Bob', 'score': 92}
# print(avg)  # 輸出：85.0
# ```

# %%
# 作答區
def calculate_average(scores):
    # TODO: 計算平均分數（helper function）
    pass

def process_scores(students):
    # TODO: 排序並計算平均，回傳 tuple
    pass

# %%
# 測試
students = [
    {'name': 'Alice', 'score': 85},
    {'name': 'Bob', 'score': 92},
    {'name': 'Charlie', 'score': 78}
]
sorted_list, avg = process_scores(students)
assert sorted_list[0]['name'] == 'Bob'
assert avg == 85.0
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 19：Dict 排序 - 依分數排序學生
#
# **題目描述：**
#
# 給定一個字典（學生姓名對應分數），請定義函式 `sort_students_by_score(scores)`，依分數由高到低排序，回傳 list of tuple。
#
# **要求：**
# - 使用 `.items()` 取得 (name, score) tuple
# - 使用 `sorted()` 依分數排序（reverse=True）
# - 回傳 list of tuple
#
# **範例：**
# ```python
# scores = {'Alice': 85, 'Bob': 92, 'Charlie': 78}
# result = sort_students_by_score(scores)
# print(result)  # 輸出：[('Bob', 92), ('Alice', 85), ('Charlie', 78)]
# ```

# %%
# 作答區
def sort_students_by_score(scores):
    # TODO: 使用 .items() 和 sorted() 依分數排序
    pass

# %%
# 測試
scores = {'Alice': 85, 'Bob': 92, 'Charlie': 78}
result = sort_students_by_score(scores)
assert result == [('Bob', 92), ('Alice', 85), ('Charlie', 78)]
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 題目 20：綜合應用 - 商品排名系統
#
# **題目描述：**
#
# 請建立一個商品排名系統，包含以下三個函式：
#
# 1. `calculate_score(sales, rating)`：計算商品評分（helper function）
#    - 公式：`sales * 0.7 + rating * 10`
#
# 2. `add_scores(products)`：為每個商品計算評分並加入字典（helper function）
#    - 輸入：list of dict，格式：`[{'name': 'A', 'sales': 100, 'rating': 4.5}, ...]`
#    - 為每個商品新增 'score' 欄位
#
# 3. `rank_products(products)`：主函式，回傳排名後的商品清單
#    - 依 score 由高到低排序
#    - 回傳排序後的 list
#
# **範例：**
# ```python
# products = [
#     {'name': 'ProductA', 'sales': 100, 'rating': 4.5},
#     {'name': 'ProductB', 'sales': 150, 'rating': 4.0},
#     {'name': 'ProductC', 'sales': 80, 'rating': 4.8}
# ]
# result = rank_products(products)
# print(result[0]['name'])  # 輸出：ProductB（最高分）
# ```

# %%
# 作答區
def calculate_score(sales, rating):
    # TODO: 計算商品評分
    pass

def add_scores(products):
    # TODO: 為每個商品新增 score 欄位（呼叫 calculate_score）
    pass

def rank_products(products):
    # TODO: 先呼叫 add_scores，再依 score 排序並回傳
    pass

# %%
# 測試
products = [
    {'name': 'ProductA', 'sales': 100, 'rating': 4.5},
    {'name': 'ProductB', 'sales': 150, 'rating': 4.0},
    {'name': 'ProductC', 'sales': 80, 'rating': 4.8}
]
result = rank_products(products)
assert result[0]['name'] == 'ProductB'
assert result[0]['score'] == 145.0
print("✅ 測試通過！")

# %% [markdown]
# ---
#
# ## 🎉 測驗結束！
#
# ### 完成檢查清單
#
# 請確認你已經：
# - ✅ 完成所有 20 題
# - ✅ 每題的測試都通過
# - ✅ 函式名稱和參數沒有修改
# - ✅ 程式碼有適當的註解
#
# ### 成績評估
#
# - **18-20 題正確**：優秀！完全掌握 def、dict、sorting 的應用
# - **15-17 題正確**：良好！大部分概念都理解了
# - **12-14 題正確**：及格！需要再加強練習
# - **11 題以下**：建議重新複習 Lesson 5-6 的內容
#
# ### 🔍 複習重點
#
# 如果有題目做錯，請特別複習：
#
# **def（函式）：**
# - 參數傳遞（位置參數、預設參數、keyword arguments）
# - 回傳值（單一值、tuple、list、dict）
# - Helper function 的設計與呼叫
#
# **dict（字典）：**
# - 基本操作：`get()`, `in`, `items()`, `keys()`, `values()`
# - 統計與計數
# - 合併與更新
# - 條件篩選
#
# **sorting（排序）：**
# - `sorted()` vs `.sort()` 的差異
# - `key` 參數的使用（lambda、自訂函式）
# - `reverse` 參數
# - 複雜資料結構的排序（list of tuple、list of dict）
#
# ### 💪 繼續加油！
#
# 多練習、多思考，你會越來越進步的！
