# %% [markdown]
# ---
#
# ## 單元 1：L1 Basics（6 題）
#
# ### 📌 考點重點
# - 型別轉換（int/float/str）
# - f-string 格式化
# - 運算優先序
# - input() 轉型
# - 字串基本操作
#
# ### ⚠️ 常見錯誤
# - `input()` 回傳的是字串，需要手動轉型
# - 整數除法 `//` vs 一般除法 `/`
# - f-string 忘記加 `f` 前綴
# - 字串和數字不能直接相加
#
# ---

# %% [markdown]
# ### Q01：型別轉換與計算
#
# 給定字串 `"123"` 和 `"456"`，將它們轉成整數後相加，結果存入變數 `result`。
#
# **預期輸出**：`579`

# %%
# Q01
a = "123"
b = "456"

# TODO: 將 a 和 b 轉成整數後相加
result = None

print(result)  # 應該輸出 579

# %% [markdown]
# ### Q02：f-string 格式化
#
# 給定姓名 `name = "小明"` 和年齡 `age = 18`，用 f-string 輸出：`「小明今年 18 歲」`

# %%
# Q02
name = "小明"
age = 18

# TODO: 用 f-string 建立字串
message = None

print(message)  # 應該輸出：小明今年 18 歲

# %% [markdown]
# ### Q03：運算優先序
#
# 計算 `(10 + 5) * 2 - 8 / 4`，結果儲存在 `result`。
#
# **提示**：先算括號、再乘除、後加減
#
# **預期輸出**：`28.0`

# %%
# Q03
# TODO: 計算 (10 + 5) * 2 - 8 / 4
result = None

print(result)  # 應該輸出 28.0

# %% [markdown]
# ### Q04：整數除法 vs 一般除法
#
# 計算 `17 / 5` 和 `17 // 5`，分別存入 `div1` 和 `div2`。
#
# **預期輸出**：
# ```
# 3.4
# 3
# ```

# %%
# Q04
# TODO: 一般除法
div1 = None

# TODO: 整數除法
div2 = None

print(div1)
print(div2)

# %% [markdown]
# ### Q05：字串重複與連接
#
# 用 `"*"` 建立一個長度為 10 的分隔線，然後在前後各加上 `"---"`。
#
# **預期輸出**：`"---**********---"`

# %%
# Q05
# TODO: 建立分隔線
line = None

print(line)  # 應該輸出 ---**********---

# %% [markdown]
# ### Q06：簡單格式化輸出
#
# 給定價格 `price = 1234.5678`，將它格式化為小數點後 2 位並輸出。
#
# **預期輸出**：`"1234.57"`
#
# **提示**：可用 f-string `{變數:.2f}` 或 `round()` 函式

# %%
# Q06
price = 1234.5678

# TODO: 格式化為小數點後 2 位
formatted_price = None

print(formatted_price)  # 應該輸出 1234.57

# %% [markdown]
# ---
#
# ## 單元 2：L3 Strings / Lists / Conditions（10 題）
#
# ### 📌 考點重點
# - 字串切片、split、join、strip
# - list 的 append、extend、insert、remove
# - in 運算子
# - if / elif / else
# - 布林邏輯（and / or / not）
#
# ### ⚠️ 常見錯誤
# - `split()` 回傳的是 list，不是字串
# - `append()` vs `extend()` 的差異
# - `elif` 不是 `else if`
# - 條件判斷中 `==` vs `=`
# - `in` 是檢查「是否包含」，不是「等於」
#
# ---

# %% [markdown]
# ### Q07：字串切片
#
# 給定字串 `text = "Python Programming"`，取出前 6 個字元。
#
# **預期輸出**：`"Python"`

# %%
# Q07
text = "Python Programming"

# TODO: 取出前 6 個字元
result = None

print(result)  # 應該輸出 Python

# %% [markdown]
# ### Q08：split 與 join
#
# 給定字串 `sentence = "apple,banana,orange"`，用 `,` 分割後，再用 ` - ` 連接。
#
# **預期輸出**：`"apple - banana - orange"`

# %%
# Q08
sentence = "apple,banana,orange"

# TODO: 分割後重新連接
result = None

print(result)  # 應該輸出 apple - banana - orange

# %% [markdown]
# ### Q09：strip 去除空白
#
# 給定字串 `text = "   hello world   "`，去除前後空白。
#
# **預期輸出**：`"hello world"`

# %%
# Q09
text = "   hello world   "

# TODO: 去除前後空白
result = None

print(f"'{result}'")  # 應該輸出 'hello world'（沒有前後空白）

# %% [markdown]
# ### Q10：list append
#
# 建立一個空 list，依序加入 `1, 2, 3`。
#
# **預期輸出**：`[1, 2, 3]`

# %%
# Q10
# TODO: 建立空 list 並加入元素
numbers = []

# TODO: 用 append 加入 1, 2, 3

print(numbers)  # 應該輸出 [1, 2, 3]

# %% [markdown]
# ### Q11：list extend vs append
#
# 給定 `list1 = [1, 2]` 和 `list2 = [3, 4]`，用 `extend` 將 list2 的元素加入 list1。
#
# **預期輸出**：`[1, 2, 3, 4]`
#
# **注意**：如果用 `append` 會變成 `[1, 2, [3, 4]]`

# %%
# Q11
list1 = [1, 2]
list2 = [3, 4]

# TODO: 用 extend 合併

print(list1)  # 應該輸出 [1, 2, 3, 4]

# %% [markdown]
# ### Q12：in 運算子
#
# 檢查字串 `"Python"` 是否包含字母 `"y"`（不分大小寫）。
#
# **預期輸出**：`True`
#
# **提示**：先轉成小寫再檢查

# %%
# Q12
text = "Python"

# TODO: 檢查是否包含 'y'（不分大小寫）
result = None

print(result)  # 應該輸出 True

# %% [markdown]
# ### Q13：if / elif / else
#
# 給定分數 `score`，輸出等級：
# - 90 以上：`"A"`
# - 80-89：`"B"`
# - 70-79：`"C"`
# - 60-69：`"D"`
# - 60 以下：`"F"`
#
# **測試範例**：`score = 85` → 輸出 `"B"`

# %%
# Q13
score = 85

# TODO: 用 if/elif/else 判斷等級
grade = None

print(grade)  # 應該輸出 B

# %% [markdown]
# ### Q14：布林邏輯 and / or
#
# 給定年齡 `age = 25` 和是否有駕照 `has_license = True`，
# 判斷是否可以租車（年齡 >= 18 且有駕照）。
#
# **預期輸出**：`True`

# %%
# Q14
age = 25
has_license = True

# TODO: 判斷是否可以租車
can_rent = None

print(can_rent)  # 應該輸出 True

# %% [markdown]
# ### Q15：list 反轉
#
# 給定 list `[1, 2, 3, 4, 5]`，將它反轉。
#
# **預期輸出**：`[5, 4, 3, 2, 1]`
#
# **提示**：可用切片 `[::-1]` 或 `reverse()` 方法

# %%
# Q15
numbers = [1, 2, 3, 4, 5]

# TODO: 反轉 list
reversed_numbers = None

print(reversed_numbers)  # 應該輸出 [5, 4, 3, 2, 1]

# %% [markdown]
# ### Q16：綜合小練習 — 密碼驗證
#
# 檢查密碼是否符合規則：
# - 長度至少 8 個字元
# - 包含數字
#
# 給定 `password = "abc12345"`，判斷是否符合規則。
#
# **預期輸出**：`True`
#
# **提示**：用 `len()` 和 `any(c.isdigit() for c in password)`

# %%
# Q16
password = "abc12345"

# TODO: 檢查密碼規則
is_valid = None

print(is_valid)  # 應該輸出 True

# %% [markdown]
# ---
#
# ## 單元 3：L4 Loops（8 題）
#
# ### 📌 考點重點
# - for 迴圈與 range
# - enumerate 取得索引
# - while 迴圈
# - break / continue
# - 巢狀迴圈
# - 累加器模式
# - 圖案輸出
#
# ### ⚠️ 常見錯誤
# - `range(n)` 是從 0 到 n-1
# - `enumerate` 回傳 `(index, value)` tuple
# - while 條件要小心無窮迴圈
# - break 跳出當前迴圈，continue 跳過本次迭代
# - 巢狀迴圈要注意縮排
#
# ---

# %% [markdown]
# ### Q17：for 迴圈與 range
#
# 用 for 迴圈計算 1 到 10 的總和。
#
# **預期輸出**：`55`

# %%
# Q17
# TODO: 計算 1 到 10 的總和
total = 0

print(total)  # 應該輸出 55

# %% [markdown]
# ### Q18：enumerate 取得索引
#
# 給定 list `fruits = ["apple", "banana", "orange"]`，
# 用 enumerate 輸出：
# ```
# 0: apple
# 1: banana
# 2: orange
# ```

# %%
# Q18
fruits = ["apple", "banana", "orange"]

# TODO: 用 enumerate 輸出索引和值

# %% [markdown]
# ### Q19：while 迴圈
#
# 用 while 迴圈計算 1 + 2 + 3 + ... 直到總和 >= 100，
# 輸出總和和累加了幾個數字。
#
# **預期輸出範例**：
# ```
# 總和：105
# 累加了 14 個數字
# ```

# %%
# Q19
# TODO: 用 while 累加到 >= 100
total = 0
count = 0

print(f"總和：{total}")
print(f"累加了 {count} 個數字")

# %% [markdown]
# ### Q20：break 跳出迴圈
#
# 在 1 到 20 中找出第一個能被 7 整除的數字。
#
# **預期輸出**：`7`

# %%
# Q20
# TODO: 找出第一個能被 7 整除的數字
result = None

print(result)  # 應該輸出 7

# %% [markdown]
# ### Q21：continue 跳過
#
# 輸出 1 到 10 中所有的奇數（用 continue 跳過偶數）。
#
# **預期輸出**：
# ```
# 1
# 3
# 5
# 7
# 9
# ```

# %%
# Q21
# TODO: 用 continue 跳過偶數

# %% [markdown]
# ### Q22：巢狀迴圈 — 九九乘法表
#
# 輸出 2 到 4 的乘法表（部分）：
# ```
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# ---
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# ---
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# ---
# ```

# %%
# Q22
# TODO: 用巢狀迴圈輸出乘法表

# %% [markdown]
# ### Q23：累加器 — 計算偶數總和
#
# 計算 1 到 20 中所有偶數的總和。
#
# **預期輸出**：`110`（2+4+6+...+20）

# %%
# Q23
# TODO: 計算偶數總和
total = 0

print(total)  # 應該輸出 110

# %% [markdown]
# ### Q24：圖案輸出 — 直角三角形
#
# 輸出以下圖案：
# ```
# *
# **
# ***
# ****
# *****
# ```

# %%
# Q24
# TODO: 用迴圈輸出三角形

# %% [markdown]
# ---
#
# ## 單元 4：L5 Functions / Recursion / Exception（4 題）
#
# ### 📌 考點重點
# - 函式定義與呼叫
# - 參數與回傳值
# - 遞迴基礎
# - try / except 基本用法
#
# ### ⚠️ 常見錯誤
# - 忘記 `return`
# - 遞迴沒有終止條件會無限遞迴
# - except 要指定例外類型
#
# ---

# %% [markdown]
# ### Q25：函式定義
#
# 定義一個函式 `calculate_area(width, height)`，計算矩形面積。
#
# **測試**：`calculate_area(5, 10)` → `50`

# %%
# Q25
# TODO: 定義函式
def calculate_area(width, height):
    pass

# 測試
print(calculate_area(5, 10))  # 應該輸出 50

# %% [markdown]
# ### Q26：函式回傳多個值
#
# 定義函式 `get_min_max(numbers)`，回傳 list 的最小值和最大值。
#
# **測試**：`get_min_max([3, 1, 4, 1, 5])` → `(1, 5)`

# %%
# Q26
# TODO: 定義函式
def get_min_max(numbers):
    pass

# 測試
print(get_min_max([3, 1, 4, 1, 5]))  # 應該輸出 (1, 5)

# %% [markdown]
# ### Q27：遞迴 — 階乘
#
# 用遞迴計算 n 的階乘（n!）。
#
# **提示**：
# - `factorial(0) = 1`
# - `factorial(n) = n * factorial(n-1)`
#
# **測試**：`factorial(5)` → `120`

# %%
# Q27
# TODO: 定義遞迴函式
def factorial(n):
    pass

# 測試
print(factorial(5))  # 應該輸出 120

# %% [markdown]
# ### Q28：基礎 try-except
#
# 嘗試將字串轉成整數，如果失敗就回傳 0。
#
# **測試**：
# - `safe_int("123")` → `123`
# - `safe_int("abc")` → `0`

# %%
# Q28
# TODO: 定義函式
def safe_int(s):
    pass

# 測試
print(safe_int("123"))  # 應該輸出 123
print(safe_int("abc"))  # 應該輸出 0

# %% [markdown]
# ---
#
# ## 單元 5：L6 Dictionary / Try-Except（4 題）
#
# ### 📌 考點重點
# - dict 基本操作（建立、存取、修改）
# - dict.get() 方法
# - KeyError 處理
# - ValueError 處理
#
# ### ⚠️ 常見錯誤
# - 存取不存在的 key 會引發 KeyError
# - `dict.get(key, default)` 可避免 KeyError
# - ValueError 常見於型別轉換失敗
#
# ---

# %% [markdown]
# ### Q29：dict 基本操作
#
# 建立一個字典儲存學生成績：
# ```python
# {
#     "小明": 85,
#     "小華": 90,
#     "小美": 78
# }
# ```
#
# 然後新增 `"小強": 88`，並輸出整個字典。

# %%
# Q29
# TODO: 建立字典並新增資料
scores = None

print(scores)

# %% [markdown]
# ### Q30：dict.get() 避免 KeyError
#
# 給定字典 `prices = {"apple": 30, "banana": 20}`，
# 用 `get()` 方法取得 `"orange"` 的價格，如果不存在就回傳 `0`。
#
# **預期輸出**：`0`

# %%
# Q30
prices = {"apple": 30, "banana": 20}

# TODO: 用 get 取得價格
orange_price = None

print(orange_price)  # 應該輸出 0

# %% [markdown]
# ### Q31：處理 KeyError
#
# 嘗試從字典取值，如果 key 不存在就輸出 `"找不到該 key"`。
#
# **測試**：
# ```python
# data = {"a": 1, "b": 2}
# safe_get(data, "c")  # 應該輸出 "找不到該 key"
# ```

# %%
# Q31
# TODO: 定義函式處理 KeyError
def safe_get(d, key):
    pass

# 測試
data = {"a": 1, "b": 2}
safe_get(data, "c")

# %% [markdown]
# ### Q32：處理 ValueError
#
# 定義函式 `parse_int(s)`，將字串轉成整數，
# 如果轉換失敗就回傳 `None` 並印出錯誤訊息。
#
# **測試**：
# - `parse_int("123")` → `123`
# - `parse_int("abc")` → `None`（並印出錯誤訊息）

# %%
# Q32
# TODO: 定義函式處理 ValueError
def parse_int(s):
    pass

# 測試
print(parse_int("123"))
print(parse_int("abc"))

# %% [markdown]
# ---
#
# ## 單元 6：L7 File Handling（3 題）
#
# ### 📌 考點重點
# - 檔案讀取（read、readlines）
# - 檔案寫入（write）
# - with 語法
# - csv 基礎（用標準庫 csv）
#
# ### ⚠️ 常見錯誤
# - 忘記關閉檔案（建議用 with）
# - 寫入模式 `'w'` 會覆蓋原檔案
# - 讀取後游標在檔案結尾，要重新開啟才能再讀
#
# ---

# %% [markdown]
# ### Q33：檔案寫入與讀取
#
# 用 `with` 語法：
# 1. 建立 `test.txt`，寫入三行：`"Line 1"`, `"Line 2"`, `"Line 3"`
# 2. 讀取檔案內容並印出
#
# **預期輸出**：
# ```
# Line 1
# Line 2
# Line 3
# ```

# %%
# Q33
# TODO: 寫入檔案

# TODO: 讀取檔案並印出

# %% [markdown]
# ### Q34：讀取檔案並計算行數
#
# 假設已有 `test.txt`（從 Q33 建立），
# 讀取檔案並計算共有幾行。
#
# **預期輸出**：`3`

# %%
# Q34
# TODO: 讀取檔案並計算行數
line_count = 0

print(f"共有 {line_count} 行")

# %% [markdown]
# ### Q35：csv 基礎操作
#
# 用標準庫 `csv` 模組：
# 1. 建立 `students.csv`，寫入標題和兩筆資料：
#    ```
#    姓名,成績
#    小明,85
#    小華,90
#    ```
# 2. 讀取 csv 並印出每一行
#
# **預期輸出**：
# ```
# ['姓名', '成績']
# ['小明', '85']
# ['小華', '90']
# ```

# %%
# Q35
import csv

# TODO: 寫入 csv

# TODO: 讀取 csv 並印出

# %% [markdown]
# ---
#
# ## 單元 7：L8 Module（1 題）
#
# ### 📌 考點重點
# - import 用法
# - from ... import ...
# - `__name__ == '__main__'` 概念
# - 自訂模組概念（文字題）
#
# ### ⚠️ 常見錯誤
# - import 後要用「模組名稱.函式」
# - from ... import * 容易命名衝突
# - `__name__` 的理解
#
# ---

# %% [markdown]
# ### Q36：import 與 __name__ 概念題（文字作答）
#
# **問題**：
#
# 1. 如果要使用 `math` 模組的 `sqrt` 函式，有哪兩種 import 方式？
# 2. `__name__ == '__main__'` 這行程式碼的用途是什麼？
# 3. 如果你建立一個檔案 `mymodule.py`，裡面定義了函式 `hello()`，
#    在另一個檔案要如何 import 並使用這個函式？
#
# **請在下面的 Markdown cell 回答**

# %% [markdown]
# #### 你的答案：
#
# 1.
#
# 2.
#
# 3.

# %% [markdown]
# ---
#
# ## 🎉 測驗完成！
#
# ### 📊 自我檢測
#
# 完成這 36 題後，你應該能夠：
#
# - [ ] **L1 Basics**：熟悉變數、型別、運算、字串格式化
# - [ ] **L3 Strings/Lists/Conditions**：掌握字串/list 操作、條件判斷
# - [ ] **L4 Loops**：靈活運用 for/while、break/continue、巢狀迴圈
# - [ ] **L5 Functions**：定義函式、遞迴、基礎例外處理
# - [ ] **L6 Dict/Exception**：dict 操作、處理 KeyError/ValueError
# - [ ] **L7 File**：檔案讀寫、with 語法、csv 基礎
# - [ ] **L8 Module**：import 用法、模組概念
#
# ---
#
# ### 💡 學習建議
#
# 1. **不會的題目**：回去複習該單元的教學筆記
# 2. **錯誤訊息**：仔細閱讀，它會告訴你問題在哪
# 3. **多練習**：改改參數、試試不同的輸入
# 4. **理解優於記憶**：知道「為什麼」比「怎麼做」更重要
#
# ---
#
# ### 🚀 下一步
#
# 完成這份測驗後，你已經掌握了 Python 的基礎！
#
# 接下來可以學習：
# - **Lesson 09**：物件導向程式設計（OOP）
# - **進階主題**：裝飾器、生成器、上下文管理器
# - **實務專案**：爬蟲、資料分析、網頁開發
#
# **繼續加油！** 💪
