# %% [markdown]
# ## 2025-12-20 筆記

# %%
# Split 進階用法
txt = "I like Python"
print(txt.split(' ', 1))
# Out:
# ['I', 'like Python']

# %%
lst_1 = [1,2,3]
lst_2 = lst_1

print('lst_1')
print(lst_1)
print('lst_2')
print(lst_2)

print('After =======')
lst_2[0] = 0
print('lst_1')
print(lst_1)
print('lst_2')
print(lst_2)
# Out:
# lst_1
# [1, 2, 3]
# lst_2
# [1, 2, 3]
# After =======
# lst_1
# [0, 2, 3]
# lst_2
# [0, 2, 3]

# %%
lst_1 = [1,2,3]
lst_2 = lst_1[:]

print('Copy:')
print('lst_1')
print(lst_1)
print('lst_2')
print(lst_2)

print('After =======')
lst_2[0] = 0
print('lst_1')
print(lst_1)
print('lst_2')
print(lst_2)
# Out:
# Copy:
# lst_1
# [1, 2, 3]
# lst_2
# [1, 2, 3]
# After =======
# lst_1
# [1, 2, 3]
# lst_2
# [0, 2, 3]

# %%
nums = [1,2]
new_nums = nums[:]

nums.append([3,4])

print(len(nums))
print(nums)


print('new_nums',new_nums)

new_nums.extend([3,4])
print('new_nums extend',new_nums)
# Out:
# 3
# [1, 2, [3, 4]]
# new_nums [1, 2]
# new_nums extend [1, 2, 3, 4]

# %%
todo = ['A', 'B']
removed_todo = todo.pop()
print('removed_todo', removed_todo)
print(todo)
# Out:
# removed_todo B
# ['A']

# %%
nums = [1,2,3,4,5]

nums.extend((6,7))

print(nums)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
#➜ 1. 將 'python' 轉大寫
lang = 'python'

print(lang.upper())
# Out:
# PYTHON

# %%
#➜ 2. 字串 'a-b-c' 切成 List
alphabets = 'a-b-c'
print(alphabets.split('-'))
# Out:
# ['a', 'b', 'c']

# %%
# ➜ 3. 建立 [1, 2, 3] 並 append 4
lst = [1, 2, 3]
lst.append(4)
print(lst)
# Out:
# [1, 2, 3, 4]

# %%
#➜ 4. 取出 List 最後一個元素
print(lst)

new_lst = lst[:]
print(new_lst)
# last_element = lst.pop()
# print('last_element', last_element)

last_element = new_lst[-1]
print('last_element', last_element)
# Out:
# [1, 2]
# [1, 2]
# last_element 2

# %%
# 如果輸入的 a 大於或等於 90，條件為 True。
a = input("請輸入分數：")
if int(a) >= 90:
    print("A+")
# Out:
# A+
