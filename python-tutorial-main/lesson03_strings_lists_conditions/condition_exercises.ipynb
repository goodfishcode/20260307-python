# %% [markdown]
# ## 如何使用本教材
#
# 1. **閱讀題目**：仔細閱讀每個 Markdown cell 中的題目說明
# 2. **完成程式**：在對應的 Code cell 中完成 TODO 部分
# 3. **執行測試**：按 `Shift + Enter` 執行程式碼，檢查輸出是否符合預期
# 4. **對照解答**：完成後可參考 `condition_solutions.ipynb` 檢查答案
# 5. **重複練習**：遇到困難的題目可以多練習幾次
#
# **提示**：
# - 所有題目都使用標準 Python，不需要安裝額外套件
# - 有些題目使用 `input()`，已提供測試用的預設值註解
# - 注意 Python 的縮排規則，條件內的程式碼必須縮排

# %% [markdown]
# ---
# ## if 基礎
# ---

# %% [markdown]
# ### Q1：完成程式 - 基本 if 判斷
#
# 如果年齡大於等於 18，印出「已成年」：

# %%
age = 20

# TODO: 使用 if 判斷，如果 age >= 18 則印出「已成年」


print("程式結束")

# %% [markdown]
# ### Q2：完成程式 - 正數判斷
#
# 判斷一個數字是否為正數：

# %%
number = 10

# TODO: 如果 number > 0，印出「這是正數」


print(f"數字是: {number}")

# %% [markdown]
# ### Q3：使用者輸入 - 密碼檢查
#
# 檢查使用者輸入的密碼是否正確：

# %%
# 測試輸入：python123
password = input("請輸入密碼: ")
# 測試時可以直接賦值：password = "python123"

correct_password = "python123"

# TODO: 如果 password == correct_password，印出「密碼正確」

# %% [markdown]
# ---
# ## if-else
# ---

# %% [markdown]
# ### Q4：完成程式 - 奇偶數判斷
#
# 判斷一個數字是奇數還是偶數：

# %%
number = 7

# TODO: 使用 if-else 判斷奇偶數
# 提示：使用 % 運算子，偶數除以 2 餘數為 0

# %% [markdown]
# ### Q5：完成程式 - 及格判斷
#
# 判斷分數是否及格（60 分及格）：

# %%
score = 75

# TODO: 如果 score >= 60 印出「及格」，否則印出「不及格」

# %% [markdown]
# ### Q6：使用者輸入 - 年齡判斷
#
# 根據年齡判斷是否可以投票：

# %%
# 測試輸入：20
age = int(input("請輸入你的年齡: "))
# 測試時可以直接賦值：age = 20

# TODO: 如果 age >= 20 印出「可以投票」，否則印出「不能投票」

# %% [markdown]
# ---
# ## if-elif-else
# ---

# %% [markdown]
# ### Q7：完成程式 - 成績等第
#
# 根據分數給予等第（A: 90+, B: 80-89, C: 70-79, D: 60-69, F: <60）：

# %%
score = 85

# TODO: 使用 if-elif-else 判斷等第

# %% [markdown]
# ### Q8：使用者輸入 - 體溫判斷
#
# 根據體溫判斷健康狀態：

# %%
# 測試輸入：37.5
temperature = float(input("請輸入體溫 (°C): "))
# 測試時可以直接賦值：temperature = 37.5

# TODO: 使用 if-elif-else 判斷
# 體溫 < 36: 體溫過低
# 36 <= 體溫 < 37.5: 正常
# 37.5 <= 體溫 < 38: 微燒
# 體溫 >= 38: 發燒

# %% [markdown]
# ### Q9：完成程式 - BMI 判斷
#
# 根據 BMI 值判斷體重狀態：

# %%
bmi = 22.5

# TODO: 使用 if-elif-else 判斷
# BMI < 18.5: 體重過輕
# 18.5 <= BMI < 24: 正常範圍
# 24 <= BMI < 27: 過重
# BMI >= 27: 肥胖

# %% [markdown]
# ### Q10：完成程式 - 季節判斷
#
# 根據月份判斷季節（春：3-5月，夏：6-8月，秋：9-11月，冬：12-2月）：

# %%
month = 7

# TODO: 使用 if-elif-else 判斷季節
# 提示：可以使用 3 <= month <= 5 這樣的寫法

# %% [markdown]
# ---
# ## 邏輯運算子 (and, or, not)
# ---

# %% [markdown]
# ### Q11：完成程式 - and 運算
#
# 判斷是否可以考駕照（年齡 >= 18 且有身分證）：

# %%
age = 20
has_id = True

# TODO: 使用 and 判斷是否可以考駕照

# %% [markdown]
# ### Q12：完成程式 - or 運算
#
# 判斷是否有優惠（是會員或消費滿千）：

# %%
is_member = False
amount = 1200

# TODO: 使用 or 判斷是否有優惠
# 條件：is_member 為 True 或 amount >= 1000

# %% [markdown]
# ### Q13：完成程式 - not 運算
#
# 判斷使用者是否不是黑名單：

# %%
is_banned = False

# TODO: 使用 not 判斷
# 如果不在黑名單（not is_banned），印出「歡迎使用」

# %% [markdown]
# ### Q14：使用者輸入 - 登入判斷
#
# 檢查帳號和密碼是否都正確：

# %%
# 測試輸入：alice / pass123
username = input("請輸入帳號: ")
password = input("請輸入密碼: ")
# 測試時可以直接賦值：username = "alice"; password = "pass123"

correct_username = "alice"
correct_password = "pass123"

# TODO: 使用 and 判斷帳號和密碼是否都正確

# %% [markdown]
# ### Q15：完成程式 - 複雜條件判斷
#
# 判斷是否可以借書（是會員且沒有逾期或是 VIP）：

# %%
is_member = True
has_overdue = False
is_vip = False

# TODO: 使用 and、or 判斷
# 條件：(is_member and not has_overdue) or is_vip

# %% [markdown]
# ---
# ## 成員運算子 (in)
# ---

# %% [markdown]
# ### Q16：完成程式 - 檢查字串包含
#
# 判斷子字串是否在字串中：

# %%
text = "Python is awesome"

# TODO: 使用 in 判斷 "Python" 是否在 text 中

# %% [markdown]
# ### Q17：完成程式 - 檢查元素在串列中
#
# 判斷水果是否在清單中：

# %%
fruits = ["apple", "banana", "cherry"]
fruit = "banana"

# TODO: 使用 in 判斷 fruit 是否在 fruits 中

# %% [markdown]
# ### Q18：使用者輸入 - 權限檢查
#
# 檢查使用者是否有管理員權限：

# %%
# 測試輸入：alice
username = input("請輸入使用者名稱: ")
# 測試時可以直接賦值：username = "alice"

admins = ["admin", "alice", "bob"]

# TODO: 使用 in 判斷 username 是否在 admins 中

# %% [markdown]
# ---
# ## 巢狀條件 (Nested if)
# ---

# %% [markdown]
# ### Q19：完成程式 - 簡單巢狀判斷
#
# 先判斷是否及格，再判斷是否優良：

# %%
score = 85

# TODO: 先判斷 score >= 60
#       如果及格，再判斷 score >= 80 是否優良
#       如果不及格，印出「不及格」

# %% [markdown]
# ### Q20：完成程式 - 三角形判斷
#
# 判斷三個邊長能否組成三角形，並判斷類型：

# %%
a, b, c = 3, 4, 5

# TODO: 先判斷能否組成三角形（任兩邊之和大於第三邊）
#       如果可以，再判斷是等邊、等腰還是不等邊三角形
#       如果不行，印出「無法組成三角形」

# 提示：
# 等邊：a == b == c
# 等腰：a == b or b == c or a == c
# 不等邊：其他情況

# %% [markdown]
# ### Q21：使用者輸入 - 門票價格
#
# 根據年齡和學生身分計算門票價格：

# %%
# 測試輸入：20 / yes
age = int(input("請輸入年齡: "))
is_student = input("是否為學生 (yes/no): ").lower() == "yes"
# 測試時可以直接賦值：age = 20; is_student = True

# TODO: 根據以下規則計算票價
# 年齡 < 6: 免費
# 6 <= 年齡 < 18: 如果是學生 100 元，否則 150 元
# 年齡 >= 18: 如果是學生 200 元，否則 300 元

# %% [markdown]
# ---
# ## 綜合應用題
# ---

# %% [markdown]
# ### Q22：使用者輸入 - 會員折扣計算
#
# 根據會員等級和消費金額計算折扣：

# %%
# 測試輸入：1500 / gold
amount = float(input("請輸入消費金額: "))
member_level = input("請輸入會員等級 (none/silver/gold/platinum): ").lower()
# 測試時可以直接賦值：amount = 1500; member_level = "gold"

# TODO: 根據以下規則計算折扣後價格
# none: 滿 1000 打 95 折，否則原價
# silver: 9 折
# gold: 85 折
# platinum: 8 折

# %% [markdown]
# ### Q23：使用者輸入 - 運費計算
#
# 根據地區和重量計算運費：

# %%
# 測試輸入：2.5 / north
weight = float(input("請輸入重量 (kg): "))
region = input("請輸入地區 (north/central/south/east): ").lower()
# 測試時可以直接賦值：weight = 2.5; region = "north"

# TODO: 根據以下規則計算運費
# 北部 (north): 重量 <= 2kg: 60 元，否則每公斤 30 元
# 中部 (central): 重量 <= 2kg: 70 元，否則每公斤 35 元
# 南部 (south): 重量 <= 2kg: 80 元，否則每公斤 40 元
# 東部 (east): 重量 <= 2kg: 100 元，否則每公斤 50 元

# %% [markdown]
# ### Q24：完成程式 - 閏年判斷
#
# 判斷是否為閏年：

# %%
year = 2024

# TODO: 閏年規則
# 1. 能被 4 整除且不能被 100 整除
# 2. 或能被 400 整除
# 使用 and、or 運算子完成

# %% [markdown]
# ### Q25：使用者輸入 - 密碼強度檢查
#
# 檢查密碼強度（長度、包含數字、包含字母）：

# %%
# 測試輸入：Python123
password = input("請輸入密碼: ")
# 測試時可以直接賦值：password = "Python123"

# TODO: 檢查密碼強度
# 弱：長度 < 6
# 中：長度 >= 6 且（包含數字或包含字母）
# 強：長度 >= 8 且包含數字且包含字母

# 提示：可以使用 any() 和 str.isdigit(), str.isalpha()
has_digit = any(c.isdigit() for c in password)
has_alpha = any(c.isalpha() for c in password)

# %% [markdown]
# ### Q26：完成程式 - 數字範圍判斷
#
# 判斷數字在哪個範圍：

# %%
number = 45

# TODO: 判斷數字範圍
# 0-25: 第一區間
# 26-50: 第二區間
# 51-75: 第三區間
# 76-100: 第四區間
# 其他: 超出範圍

# %% [markdown]
# ### Q27：完成程式 - 計算折扣價（多條件）
#
# 根據數量和單價計算折扣：

# %%
quantity = 15
unit_price = 100

# TODO: 根據數量計算折扣
# 數量 >= 20: 8 折
# 10 <= 數量 < 20: 9 折
# 數量 < 10: 原價
# 計算總價並印出

# %% [markdown]
# ### Q28：使用者輸入 - 飲料點餐
#
# 根據選擇計算飲料價格：

# %%
# 測試輸入：coffee / L / yes
drink = input("請選擇飲料 (coffee/tea/juice): ").lower()
size = input("請選擇尺寸 (S/M/L): ").upper()
add_ice = input("是否加冰 (yes/no): ").lower() == "yes"
# 測試時可以直接賦值：drink = "coffee"; size = "L"; add_ice = True

# TODO: 根據以下價格計算
# coffee: S=50, M=60, L=70
# tea: S=30, M=40, L=50
# juice: S=60, M=70, L=80
# 加冰不加價

# %% [markdown]
# ### Q29：完成程式 - 星期判斷
#
# 根據數字判斷星期幾並分類工作日/週末：

# %%
day_number = 3

# TODO: 根據數字判斷星期幾 (1=星期一, 7=星期日)
# 並判斷是工作日還是週末

# %% [markdown]
# ### Q30：使用者輸入 - 學生成績系統
#
# 綜合練習：輸入成績，判斷等第、及格與否、是否需要補考：

# %%
# 測試輸入：75
score = float(input("請輸入成績 (0-100): "))
# 測試時可以直接賦值：score = 75

# TODO: 完成以下判斷
# 1. 檢查分數是否在 0-100 範圍內
# 2. 判斷等第 (A/B/C/D/F)
# 3. 判斷是否及格 (>= 60)
# 4. 如果 40 <= 分數 < 60，提示可以補考
# 5. 如果分數 < 40，提示需要重修

# %% [markdown]
# ---
# ## 練習完成！
#
# 完成所有題目後，請參考 `condition_solutions.ipynb` 檢查你的答案。
#
# **恭喜你完成所有 lesson03 的練習！**
