# %% [markdown]
# ## 題目 1：基礎 import - 計算平方根
#
# **題目**：匯入 math 模組，計算 25 的平方根並印出。

# %%
# 匯入 math 模組
import math

# 計算 25 的平方根並印出
result = math.sqrt(25)
print(f"25 的平方根是：{result}")

# %% [markdown]
# **預期輸出**：
# ```
# 25 的平方根是：5.0
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `import math`：匯入 math 模組，才能使用裡面的函式
# - `math.sqrt(25)`：使用 math 模組的 sqrt() 函式計算平方根
# - 必須用「模組名稱.函式名稱」的格式，不能直接寫 `sqrt(25)`
#
# **常見錯誤**：
# ❌ `sqrt(25)` → 錯誤！沒有 import 或沒加 `math.`
# ❌ `import Math` → 錯誤！模組名稱是小寫 `math`
# ✅ `import math` + `math.sqrt(25)` → 正確！
#
# ---

# %% [markdown]
# ## 題目 2：import as - 縮寫使用
#
# **題目**：匯入 statistics 模組並縮寫為 st，計算 [75, 80, 85, 90, 95] 的平均分數。

# %%
# 匯入 statistics 模組並縮寫為 st
import statistics as st

# 建立分數清單
scores = [75, 80, 85, 90, 95]

# 計算並印出平均分數
average = st.mean(scores)
print(f"平均分數：{average}")

# %% [markdown]
# **預期輸出**：
# ```
# 平均分數：85.0
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `import statistics as st`：給模組一個縮寫，之後就可以用 `st` 代替 `statistics`
# - `st.mean(scores)`：使用縮寫呼叫函式，比打全名方便
# - `as` 關鍵字後面可以是任何合法的變數名稱，但建議使用有意義的縮寫
#
# **常見錯誤**：
# ❌ `statistics.mean(scores)` → 不算錯，但沒用到縮寫
# ❌ `import statistics as st` 後還寫 `statistics.mean()` → 要用 `st.mean()`
# ✅ `import statistics as st` + `st.mean(scores)` → 正確！
#
# **小技巧**：常見縮寫慣例：`numpy as np`、`pandas as pd`、`matplotlib.pyplot as plt`
#
# ---

# %% [markdown]
# ## 題目 3：使用模組變數 - 圓周率
#
# **題目**：取得 math.pi 的值，四捨五入到小數點後 4 位並印出。

# %%
# 匯入 math 模組
import math

# 取得 pi 並四捨五入到小數點後 4 位
pi_rounded = round(math.pi, 4)

# 印出結果
print(f"π ≈ {pi_rounded}")

# %% [markdown]
# **預期輸出**：
# ```
# π ≈ 3.1416
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `math.pi`：這是 math 模組提供的**常數變數**，不是函式，所以不用加 `()`
# - `round(math.pi, 4)`：Python 內建的 `round()` 函式，第二個參數是小數位數
# - 模組不只有函式，也可以有變數（像 `math.pi`、`math.e`）
#
# **常見錯誤**：
# ❌ `math.pi()` → 錯誤！`pi` 是變數不是函式，不用加 `()`
# ❌ `round(math.pi, 4)` 但沒有 import math → 錯誤！要先 import
# ✅ `round(math.pi, 4)` → 正確！
#
# **補充說明**：`math.pi` 的完整值是 3.141592653589793
#
# ---

# %% [markdown]
# ## 題目 4：多個函式使用 - floor 與 ceil
#
# **題目**：給定 x = 8.7，分別使用 floor 和 ceil 並印出兩行結果。

# %%
# 匯入 math 模組
import math

# 定義 x = 8.7
x = 8.7

# 計算 floor(x) 和 ceil(x) 並印出兩行
print(f"floor({x}) = {math.floor(x)}")
print(f"ceil({x}) = {math.ceil(x)}")

# %% [markdown]
# **預期輸出**：
# ```
# floor(8.7) = 8
# ceil(8.7) = 9
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `math.floor(x)`：無條件捨去（往下取整），8.7 變成 8
# - `math.ceil(x)`：無條件進位（往上取整），8.7 變成 9
# - 可以在同一個程式中使用多個模組函式
#
# **記憶法**：
# - **floor** = 地板 = 數字掉到地板（往下）
# - **ceil** = ceiling = 天花板 = 數字撞到天花板（往上）
#
# **常見錯誤**：
# ❌ `floor(x)` → 錯誤！要寫 `math.floor(x)`
# ❌ `math.round(x)` → 沒有這個函式！四捨五入用 Python 內建的 `round()`
# ✅ `math.floor(x)` 和 `math.ceil(x)` → 正確！
#
# ---

# %% [markdown]
# ## 題目 5：sqrt + round - 平方根運算
#
# **題目**：計算 50 的平方根，四捨五入到小數點後 2 位。

# %%
# 匯入 math 模組
import math

# 計算 50 的平方根並四捨五入到小數點 2 位
result = round(math.sqrt(50), 2)

# 印出結果
print(f"√50 ≈ {result}")

# %% [markdown]
# **預期輸出**：
# ```
# √50 ≈ 7.07
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `math.sqrt(50)`：先計算 50 的平方根（約 7.0710678...）
# - `round(..., 2)`：再對結果四捨五入到小數點後 2 位
# - 可以把函式「巢狀」使用：`round(math.sqrt(50), 2)`
#
# **常見錯誤**：
# ❌ `math.round(math.sqrt(50), 2)` → 錯誤！沒有 `math.round()`，要用 `round()`
# ❌ `sqrt(50)` → 錯誤！要寫 `math.sqrt(50)`
# ✅ `round(math.sqrt(50), 2)` → 正確！
#
# **補充**：√50 = √(25×2) = 5√2 ≈ 7.07
#
# ---

# %% [markdown]
# ## 題目 6：圓面積計算 - pi 與 pow
#
# **題目**：計算半徑 r = 5 的圓面積（π × r²），使用 math.pi 和 math.pow。

# %%
# 匯入 math 模組
import math

# 定義半徑 r = 5
r = 5

# 計算圓面積（π × r²）
area = math.pi * math.pow(r, 2)

# 印出結果（四捨五入到小數點 2 位）
print(f"半徑 {r} 的圓面積：{round(area, 2)}")

# %% [markdown]
# **預期輸出**：
# ```
# 半徑 5 的圓面積：78.54
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - 圓面積公式：A = π × r²
# - `math.pi`：取得圓周率
# - `math.pow(r, 2)`：計算 r 的 2 次方（r²）
# - 也可以寫成：`math.pi * (r ** 2)` 或 `math.pi * r * r`
#
# **常見錯誤**：
# ❌ `math.pi * pow(r, 2)` → 雖然能執行（Python 內建有 `pow()`），但建議用 `math.pow()`
# ❌ `math.pi * r ^ 2` → 錯誤！`^` 在 Python 是 XOR，不是次方
# ✅ `math.pi * math.pow(r, 2)` 或 `math.pi * (r ** 2)` → 正確！
#
# **小知識**：π × 5² = 3.14159... × 25 ≈ 78.54
#
# ---

# %% [markdown]
# ## 題目 7：floor 與 ceil 比較
#
# **題目**：給定 num = 7.3，印出原始數字、floor 和 ceil 三行結果。

# %%
# 匯入 math 模組
import math

# 定義 num = 7.3
num = 7.3

# 計算 floor 和 ceil，印出三行結果
print(f"原始數字：{num}")
print(f"無條件捨去（floor）：{math.floor(num)}")
print(f"無條件進位（ceil）：{math.ceil(num)}")

# %% [markdown]
# **預期輸出**：
# ```
# 原始數字：7.3
# 無條件捨去（floor）：7
# 無條件進位（ceil）：8
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - 三個 print 分別印出：原始數字、floor 結果、ceil 結果
# - 使用 f-string 讓輸出格式更清楚易讀
# - floor 永遠往下，ceil 永遠往上
#
# **重要觀念**：
# - `floor(7.3)` = 7（往下取到 7）
# - `ceil(7.3)` = 8（往上取到 8）
# - `floor(7.0)` = 7，`ceil(7.0)` = 7（整數不變）
#
# **常見錯誤**：
# ❌ 混淆 floor 和 ceil 的方向
# ❌ 以為 floor 是四捨五入（不是！是無條件捨去）
# ✅ 記住：floor = 地板（往下），ceil = 天花板（往上）
#
# ---

# %% [markdown]
# ## 題目 8：pow 比較 - math.pow vs **
#
# **題目**：計算 3 的 4 次方，分別使用 math.pow 和 ** 運算子。

# %%
# 匯入 math 模組
import math

# 使用兩種方法計算 3 的 4 次方
method1 = math.pow(3, 4)
method2 = 3 ** 4

# 印出兩行結果
print(f"math.pow(3, 4) = {method1}")
print(f"3 ** 4 = {method2}")

# %% [markdown]
# **預期輸出**：
# ```
# math.pow(3, 4) = 81.0
# 3 ** 4 = 81
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `math.pow(3, 4)`：math 模組的函式，**回傳浮點數**（81.0）
# - `3 ** 4`：Python 內建的次方運算子，**回傳整數**（81）
# - 兩者計算結果相同，但資料型態不同
#
# **差異比較**：
# | 方法 | 語法 | 回傳型態 | 使用時機 |
# |------|------|----------|----------|
# | `math.pow()` | `math.pow(3, 4)` | 浮點數 (81.0) | 需要浮點數結果 |
# | `**` | `3 ** 4` | 整數 (81) | 一般次方運算 |
#
# **常見錯誤**：
# ❌ `3 ^ 4` → 錯誤！`^` 是 XOR，不是次方
# ❌ `pow(3, 4)` → 雖然能執行（內建函式），但主題是 math 模組
# ✅ `math.pow(3, 4)` 或 `3 ** 4` → 正確！
#
# **建議**：一般情況用 `**` 比較簡潔，需要浮點數才用 `math.pow()`
#
# ---

# %% [markdown]
# ## 題目 9：三角函數 - sin 與 cos
#
# **題目**：計算 sin(π/2) 和 cos(0)，四捨五入到小數點後 2 位。

# %%
# 匯入 math 模組
import math

# 計算 sin(π/2) 和 cos(0)
sin_value = round(math.sin(math.pi / 2), 2)
cos_value = round(math.cos(0), 2)

# 印出兩行結果（四捨五入到小數點 2 位）
print(f"sin(π/2) = {sin_value}")
print(f"cos(0) = {cos_value}")

# %% [markdown]
# **預期輸出**：
# ```
# sin(π/2) = 1.0
# cos(0) = 1.0
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `math.sin()` 和 `math.cos()`：三角函數，**輸入是弧度不是角度**
# - `math.pi / 2`：π/2 弧度 = 90 度
# - `sin(90°) = 1`，`cos(0°) = 1`
#
# **重要觀念**：
# - Python 的三角函數使用**弧度制**（radians），不是角度制（degrees）
# - 轉換公式：弧度 = 角度 × π / 180
# - 也可以用 `math.radians(90)` 將 90 度轉成弧度
#
# **常見錯誤**：
# ❌ `math.sin(90)` → 錯誤！這是 90 弧度，不是 90 度
# ❌ 忘記三角函數輸入要用弧度
# ✅ `math.sin(math.pi / 2)` 或 `math.sin(math.radians(90))` → 正確！
#
# **補充**：如果要算 sin(90°)，可以寫 `math.sin(math.radians(90))`
#
# ---

# %% [markdown]
# ## 題目 10：fabs - 絕對值差距
#
# **題目**：計算 a = 15.8 和 b = 23.2 的差距絕對值。

# %%
# 匯入 math 模組
import math

# 定義 a = 15.8, b = 23.2
a = 15.8
b = 23.2

# 計算差距的絕對值
difference = math.fabs(a - b)

# 印出結果
print(f"{a} 與 {b} 的差距：{difference}")

# %% [markdown]
# **預期輸出**：
# ```
# 15.8 與 23.2 的差距：7.4
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `a - b` = 15.8 - 23.2 = -7.4（負數）
# - `math.fabs(-7.4)`：取絕對值，變成 7.4（正數）
# - `fabs` = floating-point absolute value（浮點數絕對值）
#
# **fabs vs abs 差異**：
# | 函式 | 來源 | 回傳型態 | 使用時機 |
# |------|------|----------|----------|
# | `math.fabs()` | math 模組 | 永遠是浮點數 | 需要浮點數絕對值 |
# | `abs()` | Python 內建 | 保持原型態 | 一般絕對值計算 |
#
# **範例**：
# - `math.fabs(-5)` → 5.0（浮點數）
# - `abs(-5)` → 5（整數）
#
# **常見錯誤**：
# ❌ `fabs(a - b)` → 錯誤！要寫 `math.fabs()`
# ❌ 忘記先算 `a - b`，直接寫 `math.fabs(a, b)`
# ✅ `math.fabs(a - b)` 或 `abs(a - b)` → 正確！
#
# ---

# %% [markdown]
# ## 題目 11：mean - 計算平均值
#
# **題目**：計算成績 [68, 72, 75, 80, 85, 90, 92] 的平均分數。

# %%
# 匯入 statistics 模組
import statistics

# 建立成績清單
grades = [68, 72, 75, 80, 85, 90, 92]

# 計算平均分數並印出（四捨五入到小數點 2 位）
average = statistics.mean(grades)
print(f"班級平均分數：{round(average, 2)}")

# %% [markdown]
# **預期輸出**：
# ```
# 班級平均分數：80.29
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `statistics.mean()`：計算清單的平均值
# - 平均值 = 所有數字加總 ÷ 個數
# - (68+72+75+80+85+90+92) ÷ 7 = 562 ÷ 7 ≈ 80.29
#
# **重要觀念**：
# - `mean()` 接受一個清單（或其他可迭代物件）作為參數
# - 清單至少要有 1 個元素，否則會報錯
#
# **常見錯誤**：
# ❌ `statistics.mean(68, 72, 75, ...)` → 錯誤！要傳入清單
# ❌ `mean(grades)` → 錯誤！要寫 `statistics.mean()`
# ✅ `statistics.mean([68, 72, 75, ...])` → 正確！
#
# **補充**：也可以手動計算：`sum(grades) / len(grades)`
#
# ---

# %% [markdown]
# ## 題目 12：median - 計算中位數
#
# **題目**：分別計算奇數個和偶數個數據的中位數。

# %%
# 匯入 statistics 模組
import statistics

# 建立兩組數據
data1 = [1, 3, 5, 7, 9]  # 奇數個（5 個）
data2 = [2, 4, 6, 8, 10, 12]  # 偶數個（6 個）

# 計算兩組的中位數並印出
median1 = statistics.median(data1)
median2 = statistics.median(data2)

print(f"data1 的中位數：{median1}")
print(f"data2 的中位數：{median2}")

# %% [markdown]
# **預期輸出**：
# ```
# data1 的中位數：5
# data2 的中位數：7.0
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `statistics.median()`：計算中位數（排序後取中間值）
# - **奇數個**：直接取中間那個數（第 3 個 = 5）
# - **偶數個**：取中間兩個數的平均（(6+8)/2 = 7.0）
#
# **中位數計算方式**：
# 1. 將數據由小到大排序
# 2. 如果是奇數個：取正中間那個數
# 3. 如果是偶數個：取中間兩個數的平均
#
# **範例**：
# - [1, 3, **5**, 7, 9] → 中位數 = 5
# - [2, 4, **6**, **8**, 10, 12] → 中位數 = (6+8)/2 = 7.0
#
# **常見錯誤**：
# ❌ 以為中位數就是平均值（不是！）
# ❌ 忘記資料要先排序（`median()` 會自動處理）
# ✅ 直接用 `statistics.median()` 即可 → 正確！
#
# **優點**：中位數不受極端值影響，比平均值更穩定
#
# ---

# %% [markdown]
# ## 題目 13：mode - 找出眾數
#
# **題目**：找出 [5, 3, 8, 3, 7, 3, 9, 5, 3] 的眾數。

# %%
# 匯入 statistics 模組
import statistics

# 建立清單
numbers = [5, 3, 8, 3, 7, 3, 9, 5, 3]

# 找出眾數並印出
mode_value = statistics.mode(numbers)
print(f"眾數（最常出現）：{mode_value}")

# %% [markdown]
# **預期輸出**：
# ```
# 眾數（最常出現）：3
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `statistics.mode()`：找出出現次數最多的數字
# - 在清單中，3 出現 4 次，5 出現 2 次，其他都只出現 1 次
# - 所以眾數是 3
#
# **眾數定義**：
# - 眾數（mode）= 出現頻率最高的數值
# - 用途：了解「最常見」的數值
#
# **重要注意**：
# - 如果有多個數字出現次數相同且最多，`mode()` 會回傳第一個遇到的
# - Python 3.8+ 可以用 `statistics.multimode()` 找出所有眾數
#
# **常見錯誤**：
# ❌ 以為眾數是「最大的數」（不是！是「最常出現的數」）
# ❌ 資料沒有重複值時用 `mode()` → 會報錯或回傳任意值
# ✅ 確認資料有重複值再用 `mode()` → 正確！
#
# **範例應用**：問卷調查中最多人選的選項、商品銷售量最高的品項
#
# ---

# %% [markdown]
# ## 題目 14：stdev - 標準差比較
#
# **題目**：比較兩組數據的標準差，判斷哪組更分散。

# %%
# 匯入 statistics 模組
import statistics

# 建立兩組數據
group_a = [50, 50, 50, 50, 50]  # 數據集中
group_b = [10, 30, 50, 70, 90]  # 數據分散

# 計算兩組的標準差
stdev_a = round(statistics.stdev(group_a), 2)
stdev_b = round(statistics.stdev(group_b), 2)

# 印出結果（四捨五入到小數點 2 位）並比較
print(f"A 組標準差：{stdev_a}")
print(f"B 組標準差：{stdev_b}")
print("B 組數據更分散")

# %% [markdown]
# **預期輸出**：
# ```
# A 組標準差：0.0
# B 組標準差：30.0
# B 組數據更分散
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `statistics.stdev()`：計算標準差（Standard Deviation）
# - **標準差 = 數據分散程度的指標**
# - A 組所有數字都是 50 → 完全沒波動 → 標準差 = 0
# - B 組數字從 10 到 90 → 波動很大 → 標準差 = 30
#
# **標準差意義**：
# - **標準差越小** → 數據越集中、越穩定
# - **標準差越大** → 數據越分散、波動越大
# - 標準差 = 0 → 所有數據都相同
#
# **實際應用**：
# - 考試成績：標準差小 = 全班程度接近；標準差大 = 程度參差不齊
# - 股票：標準差小 = 價格穩定；標準差大 = 價格波動劇烈
#
# **常見錯誤**：
# ❌ 混淆標準差和平均值（完全不同概念）
# ❌ 資料少於 2 個時用 `stdev()` → 會報錯
# ✅ 標準差用來衡量「分散程度」，不是「平均大小」 → 正確！
#
# ---

# %% [markdown]
# ## 題目 15：綜合統計 - 一次計算四個統計值
#
# **題目**：計算 [65, 70, 70, 75, 80, 85, 85, 85, 90, 95] 的 mean、median、mode、stdev。

# %%
# 匯入 statistics 模組
import statistics

# 建立數據
scores = [65, 70, 70, 75, 80, 85, 85, 85, 90, 95]

# 計算四個統計值
mean_value = statistics.mean(scores)
median_value = statistics.median(scores)
mode_value = statistics.mode(scores)
stdev_value = statistics.stdev(scores)

# 印出報告（格式如題目要求）
print("=== 成績統計報告 ===")
print(f"平均值：{mean_value}")
print(f"中位數：{median_value}")
print(f"眾數：{mode_value}")
print(f"標準差：{round(stdev_value, 2)}")

# %% [markdown]
# **預期輸出**：
# ```
# === 成績統計報告 ===
# 平均值：80.0
# 中位數：82.5
# 眾數：85
# 標準差：9.72
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - 一次計算四個統計值，展示數據的完整統計特性
# - 每個統計值都有不同意義：
#   - **平均值 80.0**：數據中心（總和 ÷ 個數）
#   - **中位數 82.5**：排序後中間值（(80+85)/2）
#   - **眾數 85**：出現最多次（3 次）
#   - **標準差 9.72**：數據分散程度
#
# **四個統計值的關係**：
# - 平均值：反映數據整體水平
# - 中位數：不受極端值影響的中心位置
# - 眾數：最常見的數值
# - 標準差：波動大小
#
# **常見錯誤**：
# ❌ 搞混四個統計值的定義
# ❌ 忘記標準差要四捨五入
# ✅ 清楚理解每個統計值的意義 → 正確！
#
# **小技巧**：實務上這四個值常一起使用，可以寫成函式方便重複呼叫
#
# ---

# %% [markdown]
# ## 題目 16：randint - 模擬擲骰子
#
# **題目**：使用 random.randint(1, 6) 模擬擲一顆骰子。

# %%
# 匯入 random 模組
import random

# 擲骰子並印出結果
dice = random.randint(1, 6)
print(f"🎲 擲骰子結果：{dice}")

# %% [markdown]
# **預期輸出**（⚠️ 每次執行結果都不同）：
# ```
# 🎲 擲骰子結果：3
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `random.randint(1, 6)`：產生 1 到 6 之間的隨機**整數**
# - **包含 1 和 6**（兩端都包含）
# - 每次執行都會得到不同的隨機結果
#
# **randint 特性**：
# - 語法：`random.randint(a, b)` → 回傳 [a, b] 之間的隨機整數
# - **包含端點**：可能回傳 1 或 6
# - 用途：擲骰子、抽號碼、隨機選擇等
#
# **常見錯誤**：
# ❌ `random.randint(1, 5)` → 錯誤！骰子是 1~6，不是 1~5
# ❌ `randint(1, 6)` → 錯誤！要寫 `random.randint()`
# ❌ `random.randint(1.0, 6.0)` → 錯誤！參數要是整數
# ✅ `random.randint(1, 6)` → 正確！
#
# **擴充應用**：
# - 擲兩顆骰子：`random.randint(1, 6) + random.randint(1, 6)`
# - 擲 20 面骰：`random.randint(1, 20)`
#
# ---

# %% [markdown]
# ## 題目 17：choice - 隨機選擇
#
# **題目**：從 ['蘋果', '香蕉', '橘子', '草莓', '芒果'] 隨機選一個水果。

# %%
# 匯入 random 模組
import random

# 建立水果清單
fruits = ['蘋果', '香蕉', '橘子', '草莓', '芒果']

# 隨機選一個水果並印出
chosen_fruit = random.choice(fruits)
print(f"今天吃：🍎 {chosen_fruit}")

# %% [markdown]
# **預期輸出**（⚠️ 每次執行結果都不同）：
# ```
# 今天吃：🍎 蘋果
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `random.choice()`：從序列中隨機選擇**一個元素**
# - 可以用在 list、tuple、字串等任何序列
# - 每個元素被選到的機率相等
#
# **choice 特性**：
# - 語法：`random.choice(序列)` → 回傳隨機選中的元素
# - 適用於：list、tuple、字串
# - 用途：隨機抽獎、隨機選擇、隨機決策
#
# **常見錯誤**：
# ❌ `random.choice('蘋果', '香蕉', ...)` → 錯誤！要傳入清單
# ❌ `choice(fruits)` → 錯誤！要寫 `random.choice()`
# ✅ `random.choice(fruits)` → 正確！
#
# **擴充應用**：
# - 隨機選字母：`random.choice('ABCDEFG')`
# - 隨機選多個（不重複）：`random.sample(fruits, 2)`
# - 隨機選多個（可重複）：`random.choices(fruits, k=3)`
#
# ---

# %% [markdown]
# ## 題目 18：uniform - 隨機浮點數
#
# **題目**：生成 5.0~10.0 之間的隨機溫度，四捨五入到小數點後 2 位。

# %%
# 匯入 random 模組
import random

# 生成 5.0~10.0 的隨機浮點數
temperature = random.uniform(5.0, 10.0)

# 四捨五入到小數點 2 位並印出
print(f"隨機溫度：{round(temperature, 2)}°C")

# %% [markdown]
# **預期輸出**（⚠️ 每次執行結果都不同）：
# ```
# 隨機溫度：7.23°C
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `random.uniform(5.0, 10.0)`：產生 5.0 到 10.0 之間的隨機**浮點數**
# - 可能產生：5.0、7.234、9.999、10.0 等任何浮點數
# - `round(..., 2)`：四捨五入到小數點後 2 位，方便閱讀
#
# **uniform 與 randint 差異**：
# | 函式 | 回傳型態 | 範圍 | 範例 |
# |------|----------|------|------|
# | `randint(1, 6)` | 整數 | [1, 6] | 1, 2, 3, 4, 5, 6 |
# | `uniform(1.0, 6.0)` | 浮點數 | [1.0, 6.0] | 1.0, 2.345, 5.999 |
#
# **常見錯誤**：
# ❌ `random.uniform(5, 10)` → 雖然能執行，但建議寫成浮點數 `5.0, 10.0`
# ❌ 期望得到整數結果 → `uniform` 是浮點數，要整數用 `randint`
# ✅ `random.uniform(5.0, 10.0)` → 正確！
#
# **擴充應用**：
# - 模擬測量誤差：`actual_value + random.uniform(-0.5, 0.5)`
# - 隨機折扣：`random.uniform(0.7, 0.9)` （7 折到 9 折）
#
# ---

# %% [markdown]
# ## 題目 19：random - 模擬中獎機率
#
# **題目**：使用 random.random() 模擬 30% 中獎機率。

# %%
# 匯入 random 模組
import random

# 生成隨機數並判斷是否中獎（< 0.3）
luck = random.random()

if luck < 0.3:
    print("🎉 恭喜中獎！")
else:
    print("😢 差一點，再試試！")

# %% [markdown]
# **預期輸出**（⚠️ 每次執行結果都不同）：
# ```
# 🎉 恭喜中獎！
# ```
# 或
# ```
# 😢 差一點，再試試！
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - `random.random()`：產生 0.0 到 1.0 之間的隨機浮點數（**不包含 1.0**）
# - `luck < 0.3`：有 30% 機率成立（0.0~0.3 範圍）
# - 用 if-else 判斷是否中獎
#
# **random() 特性**：
# - 語法：`random.random()` → 回傳 [0.0, 1.0) 的隨機浮點數
# - **不需要參數**，每次都是 0.0~1.0
# - 用途：機率判斷、隨機權重
#
# **機率控制技巧**：
# - 10% 機率：`random.random() < 0.1`
# - 50% 機率：`random.random() < 0.5`
# - 75% 機率：`random.random() < 0.75`
#
# **常見錯誤**：
# ❌ `random.random(0, 1)` → 錯誤！`random()` 不需要參數
# ❌ `luck < 30` → 錯誤！要寫 `< 0.3`（30% = 0.3）
# ✅ `random.random() < 0.3` → 正確！
#
# **實務應用**：遊戲掉寶、廣告輪播、A/B 測試
#
# ---

# %% [markdown]
# ## 題目 20：自訂模組 - 建立並使用 mymodule.py
#
# **題目**：建立 mymodule.py（包含 school 變數和 courses 清單），然後 import 並使用。

# %%
# 步驟 1：建立 mymodule.py 檔案
with open('mymodule.py', 'w', encoding='utf-8') as f:
    f.write("school = 'JWClub'\\n")
    f.write("courses = ['Python', 'JavaScript', 'Java']\\n")

print("✅ mymodule.py 已建立完成！")

# %% [markdown]
# **預期輸出**：
# ```
# ✅ mymodule.py 已建立完成！
# ```

# %%
# 步驟 2：import mymodule 並使用
import mymodule

# 印出 mymodule.school
print(f"學校：{mymodule.school}")

# 用迴圈印出 mymodule.courses 的每個課程
print("課程列表：")
for course in mymodule.courses:
    print(f"  - {course}")

# %% [markdown]
# **預期輸出**：
# ```
# 學校：JWClub
# 課程列表：
#   - Python
#   - JavaScript
#   - Java
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - **步驟 1**：用 Python 的檔案寫入功能建立 `mymodule.py`
# - **步驟 2**：用 `import mymodule` 匯入自己建立的模組
# - 然後可以用 `mymodule.變數名稱` 存取模組內的變數
#
# **自訂模組重點**：
# 1. **同資料夾**：mymodule.py 要和你的程式在同一個資料夾
# 2. **檔名規則**：不能有空格、不能用 Python 關鍵字
# 3. **import 行為**：Python 會執行一次整個 .py 檔案
#
# **常見錯誤**：
# ❌ `import mymodule.py` → 錯誤！不用加 `.py`
# ❌ `mymodule.school` 但沒先 import → 錯誤！要先 import
# ❌ mymodule.py 不在同一個資料夾 → 找不到模組
# ✅ `import mymodule` + `mymodule.school` → 正確！
#
# **重要觀念**：
# - import 時，Python 會**執行一次** mymodule.py 的所有程式碼
# - 如果 mymodule.py 裡有 `print()`，import 時就會執行
# - 這就是為什麼通常模組裡只放變數、函式定義，不放會執行的程式碼
#
# **進階技巧**（參考用）：
# 如果想讓程式碼只在直接執行時運行，可以用：
# ```python
# if __name__ == '__main__':
#     print('直接執行才會印出')
# ```
#
# ---

# %% [markdown]
# ## 🌟 加分挑戰：隨機成績統計分析器
#
# **任務**：結合 random 和 statistics 生成 30 筆隨機成績並進行統計分析。

# %%
# 匯入 random 和 statistics 模組
import random
import statistics

# 生成 30 筆隨機成績（60~100）
scores = [random.randint(60, 100) for _ in range(30)]

# 計算統計值
mean_score = statistics.mean(scores)
median_score = statistics.median(scores)
stdev_score = statistics.stdev(scores)
max_score = max(scores)
min_score = min(scores)

# 計算及格人數和優秀人數
pass_count = sum(1 for score in scores if score >= 60)
excellent_count = sum(1 for score in scores if score >= 80)
excellent_ratio = (excellent_count / len(scores)) * 100

# 印出完整報告
print("=== 隨機成績統計分析 ===")
print(f"生成成績數量：{len(scores)} 筆")
print()
print("統計結果：")
print(f"平均分數：{round(mean_score, 2)}")
print(f"中位數：{median_score}")
print(f"標準差：{round(stdev_score, 2)}")
print(f"最高分：{max_score}")
print(f"最低分：{min_score}")
print()
print("分析報告：")
print(f"及格人數（>= 60）：{pass_count} 人")
print(f"優秀人數（>= 80）：{excellent_count} 人")
print(f"優秀比例：{round(excellent_ratio, 1)}%")

# %% [markdown]
# **預期輸出**（⚠️ 每次執行結果都不同）：
# ```
# === 隨機成績統計分析 ===
# 生成成績數量：30 筆
#
# 統計結果：
# 平均分數：78.53
# 中位數：79.5
# 標準差：12.45
# 最高分：98
# 最低分：61
#
# 分析報告：
# 及格人數（>= 60）：30 人
# 優秀人數（>= 80）：12 人
# 優秀比例：40.0%
# ```
#
# ### 解析說明
#
# **為什麼這樣寫**：
# - **清單推導式**：`[random.randint(60, 100) for _ in range(30)]` 快速生成 30 筆成績
# - **結合兩個模組**：用 `random` 生成資料，用 `statistics` 分析資料
# - **條件統計**：`sum(1 for score in scores if score >= 80)` 計算符合條件的數量
#
# **技術重點**：
# 1. **清單推導式**：簡潔生成大量資料
#    - `[random.randint(60, 100) for _ in range(30)]`
#    - 相當於用迴圈建立 30 個隨機數
#
# 2. **條件統計**：
#    - `sum(1 for score in scores if score >= 80)`
#    - 每個符合條件的成績加 1，最後加總
#
# 3. **綜合運用**：
#    - 資料生成（random）
#    - 統計分析（statistics）
#    - 條件判斷（if）
#    - 格式化輸出（f-string）
#
# **常見錯誤**：
# ❌ 忘記用 `round()` 四捨五入結果
# ❌ 計算比例時忘記乘 100（0.4 要轉成 40%）
# ❌ 清單推導式寫錯語法
# ✅ 結合多個模組功能，完成複雜任務 → 正確！
#
# **學習重點**：
# - 這題展示了如何結合多個模組解決實際問題
# - 在真實專案中，經常需要組合不同模組的功能
# - 清單推導式是 Python 的強大特性，值得深入學習
#
# ---

# %% [markdown]
# ## 📚 本章重點整理
#
# ### 1. import 語法
#
# | 語法 | 使用方式 | 範例 |
# |------|----------|------|
# | `import module` | `module.function()` | `import math` → `math.sqrt(16)` |
# | `import module as alias` | `alias.function()` | `import statistics as st` → `st.mean([1,2,3])` |
#
# ### 2. 模組使用方式
#
# **存取模組內容**：
# - **變數**：`module.variable`（例如：`math.pi`）
# - **函式**：`module.function()`（例如：`math.sqrt(25)`）
#
# **重要規則**：
# - ✅ 必須先 `import` 才能使用
# - ✅ 使用時要加「模組名稱.」前綴
# - ✅ 變數不用加 `()`，函式要加 `()`
#
# ### 3. 內建模組 vs 第三方模組
#
# | 類型 | 特點 | 範例 | 安裝方式 |
# |------|------|------|----------|
# | **內建模組** | Python 自帶，不需安裝 | math, random, statistics | 無需安裝 |
# | **第三方模組** | 需要額外安裝 | requests, pandas, numpy | `pip install` 或 `conda install` |
#
# ### 4. 常用模組速查
#
# **math 模組**（數學運算）：
# - `sqrt(x)`：平方根
# - `floor(x)` / `ceil(x)`：無條件捨去/進位
# - `pow(x, y)`：x 的 y 次方
# - `sin(x)` / `cos(x)`：三角函數（輸入弧度）
# - `pi`：圓周率 3.14159...
# - `fabs(x)`：絕對值（浮點數）
#
# **statistics 模組**（統計分析）：
# - `mean(data)`：平均值
# - `median(data)`：中位數
# - `mode(data)`：眾數
# - `stdev(data)`：標準差
#
# **random 模組**（亂數產生）：
# - `randint(a, b)`：隨機整數 [a, b]
# - `random()`：隨機浮點數 [0.0, 1.0)
# - `uniform(a, b)`：隨機浮點數 [a, b]
# - `choice(seq)`：從序列隨機選一個
#
# ### 5. 自訂模組重點
#
# **建立自訂模組**：
# 1. 建立 `.py` 檔案（例如：mymodule.py）
# 2. 在裡面定義變數、函式、類別
# 3. 確保檔案在同一個資料夾
#
# **使用自訂模組**：
# ```python
# import mymodule
# print(mymodule.variable)
# mymodule.function()
# ```
#
# **重要觀念**：
# ⚠️ **import 會執行一次整個 .py 檔案**
# - 如果 mymodule.py 裡有 `print()`，import 時就會執行
# - 建議模組內只放定義（變數、函式），不放會執行的程式碼
# - 進階用法：用 `if __name__ == '__main__':` 保護執行程式碼
#
# ### 6. 常見錯誤與除錯
#
# | 錯誤 | 原因 | 解決方法 |
# |------|------|----------|
# | `NameError: name 'math' is not defined` | 沒有 import | 加上 `import math` |
# | `NameError: name 'sqrt' is not defined` | 忘記加模組前綴 | 改成 `math.sqrt()` |
# | `ModuleNotFoundError` | 模組不存在或未安裝 | 檢查拼字或用 pip 安裝 |
# | `TypeError: 'float' object is not callable` | 變數加了 `()` | `math.pi` 不要寫成 `math.pi()` |
#
# ### 7. 學習建議
#
# ✅ **多練習**：每個模組都實際寫 code 測試
# ✅ **查文件**：養成查閱 [Python 官方文件](https://docs.python.org/zh-tw/3/) 的習慣
# ✅ **建模組**：把常用功能整理成自己的模組
# ✅ **探索更多**：Python 有超過 30 萬個第三方模組可以探索！
#
# ---
#
# ## 🎉 恭喜完成所有練習！
#
# 你現在已經掌握：
# - ✅ import 各種用法
# - ✅ math / statistics / random 模組的實際應用
# - ✅ 自訂模組的建立與使用
# - ✅ 結合多個模組解決問題
#
# **下一步**：
# 1. 複習做錯的題目
# 2. 嘗試建立自己的工具模組
# 3. 探索更多有趣的 Python 模組（datetime、os、json 等）
# 4. 開始學習第三方模組（requests、pandas、numpy）
#
# 繼續加油！💪🚀
