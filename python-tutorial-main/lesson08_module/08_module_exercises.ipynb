# %% [markdown]
# ## 題目 1：基礎 import - 計算平方根
#
# **要求**：
# 1. 匯入 `math` 模組
# 2. 使用 `math.sqrt()` 計算 25 的平方根
# 3. 印出結果（格式：`25 的平方根是：5.0`）
#
# **預期輸出**：
# ```
# 25 的平方根是：5.0
# ```

# %%
# TODO: 匯入 math 模組
import math 


# TODO: 計算 25 的平方根並印出
result = math.sqrt(25)
print(result)
# Out:
# 5.0

# %% [markdown]
# ## 題目 2：import as - 縮寫使用
#
# **要求**：
# 1. 匯入 `statistics` 模組，縮寫為 `st`
# 2. 建立分數清單：`[75, 80, 85, 90, 95]`
# 3. 使用 `st.mean()` 計算平均分數
# 4. 印出結果（格式：`平均分數：85.0`）
#
# **預期輸出**：
# ```
# 平均分數：85.0
# ```

# %%
# TODO: 匯入 statistics 模組並縮寫為 st


# TODO: 建立分數清單


# TODO: 計算並印出平均分數

# %% [markdown]
# ## 題目 3：使用模組變數 - 圓周率
#
# **要求**：
# 1. 匯入 `math` 模組
# 2. 取得 `math.pi` 的值
# 3. 使用 `round()` 四捨五入到小數點後 4 位
# 4. 印出結果（格式：`π ≈ 3.1416`）
#
# **預期輸出**：
# ```
# π ≈ 3.1416
# ```

# %%
# TODO: 匯入 math 模組


# TODO: 取得 pi 並四捨五入到小數點後 4 位


# TODO: 印出結果

# %% [markdown]
# ## 題目 4：多個函式使用 - floor 與 ceil
#
# **要求**：
# 1. 匯入 `math` 模組
# 2. 給定數字：`x = 8.7`
# 3. 分別使用 `math.floor(x)` 和 `math.ceil(x)`
# 4. 印出兩行結果：
#    - `floor(8.7) = 8`
#    - `ceil(8.7) = 9`
#
# **預期輸出**：
# ```
# floor(8.7) = 8
# ceil(8.7) = 9
# ```

# %%
# TODO: 匯入 math 模組


# TODO: 定義 x = 8.7


# TODO: 計算 floor(x) 和 ceil(x) 並印出兩行

# %% [markdown]
# ## 題目 5：sqrt + round - 平方根運算
#
# **要求**：
# 1. 匯入 `math` 模組
# 2. 計算 50 的平方根
# 3. 四捨五入到小數點後 2 位
# 4. 印出結果（格式：`√50 ≈ 7.07`）
#
# **預期輸出**：
# ```
# √50 ≈ 7.07
# ```

# %%
# TODO: 匯入 math 模組


# TODO: 計算 50 的平方根並四捨五入到小數點 2 位


# TODO: 印出結果

# %% [markdown]
# ## 題目 6：圓面積計算 - pi 與 pow
#
# **要求**：
# 1. 匯入 `math` 模組
# 2. 給定圓的半徑 `r = 5`
# 3. 使用公式：面積 = π × r²
# 4. 使用 `math.pi` 和 `math.pow(r, 2)` 計算
# 5. 印出結果並四捨五入到小數點後 2 位（格式：`半徑 5 的圓面積：78.54`）
#
# **預期輸出**：
# ```
# 半徑 5 的圓面積：78.54
# ```

# %%
# TODO: 匯入 math 模組


# TODO: 定義半徑 r = 5


# TODO: 計算圓面積（π × r²）


# TODO: 印出結果（四捨五入到小數點 2 位）

# %% [markdown]
# ## 題目 7：floor 與 ceil 比較
#
# **要求**：
# 1. 匯入 `math` 模組
# 2. 給定數字：`num = 7.3`
# 3. 計算 `floor(num)` 和 `ceil(num)`
# 4. 印出三行：
#    - `原始數字：7.3`
#    - `無條件捨去（floor）：7`
#    - `無條件進位（ceil）：8`
#
# **預期輸出**：
# ```
# 原始數字：7.3
# 無條件捨去（floor）：7
# 無條件進位（ceil）：8
# ```

# %%
# TODO: 匯入 math 模組


# TODO: 定義 num = 7.3


# TODO: 計算 floor 和 ceil，印出三行結果

# %% [markdown]
# ## 題目 8：pow 比較 - math.pow vs **
#
# **要求**：
# 1. 匯入 `math` 模組
# 2. 計算 3 的 4 次方，使用兩種方法：
#    - 方法 1：`math.pow(3, 4)`
#    - 方法 2：`3 ** 4`
# 3. 印出兩行結果：
#    - `math.pow(3, 4) = 81.0`（浮點數）
#    - `3 ** 4 = 81`（整數）
#
# **預期輸出**：
# ```
# math.pow(3, 4) = 81.0
# 3 ** 4 = 81
# ```

# %%
# TODO: 匯入 math 模組


# TODO: 使用兩種方法計算 3 的 4 次方


# TODO: 印出兩行結果

# %% [markdown]
# ## 題目 9：三角函數 - sin 與 cos
#
# **要求**：
# 1. 匯入 `math` 模組
# 2. 計算以下兩個值（四捨五入到小數點後 2 位）：
#    - `sin(π/2)`（提示：π/2 = 90 度）
#    - `cos(0)`
# 3. 印出兩行結果：
#    - `sin(π/2) = 1.0`
#    - `cos(0) = 1.0`
#
# **預期輸出**：
# ```
# sin(π/2) = 1.0
# cos(0) = 1.0
# ```

# %%
# TODO: 匯入 math 模組


# TODO: 計算 sin(π/2) 和 cos(0)


# TODO: 印出兩行結果（四捨五入到小數點 2 位）

# %% [markdown]
# ## 題目 10：fabs - 絕對值差距
#
# **要求**：
# 1. 匯入 `math` 模組
# 2. 給定兩個數字：`a = 15.8`，`b = 23.2`
# 3. 計算兩數差距的絕對值：`|a - b|`
# 4. 使用 `math.fabs()` 計算
# 5. 印出結果（格式：`15.8 與 23.2 的差距：7.4`）
#
# **預期輸出**：
# ```
# 15.8 與 23.2 的差距：7.4
# ```

# %%
# TODO: 匯入 math 模組


# TODO: 定義 a = 15.8, b = 23.2


# TODO: 計算差距的絕對值


# TODO: 印出結果

# %% [markdown]
# ## 題目 11：mean - 計算平均值
#
# **要求**：
# 1. 匯入 `statistics` 模組
# 2. 建立成績清單：`grades = [68, 72, 75, 80, 85, 90, 92]`
# 3. 使用 `statistics.mean()` 計算平均分數
# 4. 印出結果並四捨五入到小數點後 2 位（格式：`班級平均分數：80.29`）
#
# **預期輸出**：
# ```
# 班級平均分數：80.29
# ```

# %%
# TODO: 匯入 statistics 模組


# TODO: 建立成績清單


# TODO: 計算平均分數並印出（四捨五入到小數點 2 位）

# %% [markdown]
# ## 題目 12：median - 計算中位數
#
# **要求**：
# 1. 匯入 `statistics` 模組
# 2. 建立兩組數據：
#    - `data1 = [1, 3, 5, 7, 9]`（奇數個）
#    - `data2 = [2, 4, 6, 8, 10, 12]`（偶數個）
# 3. 分別計算兩組的中位數
# 4. 印出兩行結果：
#    - `data1 的中位數：5`
#    - `data2 的中位數：7.0`
#
# **預期輸出**：
# ```
# data1 的中位數：5
# data2 的中位數：7.0
# ```

# %%
# TODO: 匯入 statistics 模組


# TODO: 建立兩組數據


# TODO: 計算兩組的中位數並印出

# %% [markdown]
# ## 題目 13：mode - 找出眾數
#
# **要求**：
# 1. 匯入 `statistics` 模組
# 2. 建立清單：`numbers = [5, 3, 8, 3, 7, 3, 9, 5, 3]`
# 3. 使用 `statistics.mode()` 找出眾數（出現最多次的數字）
# 4. 印出結果（格式：`眾數（最常出現）：3`）
#
# **預期輸出**：
# ```
# 眾數（最常出現）：3
# ```

# %%
# TODO: 匯入 statistics 模組


# TODO: 建立清單


# TODO: 找出眾數並印出

# %% [markdown]
# ## 題目 14：stdev - 標準差比較
#
# **要求**：
# 1. 匯入 `statistics` 模組
# 2. 建立兩組數據：
#    - `group_a = [50, 50, 50, 50, 50]`（數據集中）
#    - `group_b = [10, 30, 50, 70, 90]`（數據分散）
# 3. 分別計算兩組的標準差
# 4. 印出兩行結果（四捨五入到小數點後 2 位）：
#    - `A 組標準差：0.0`
#    - `B 組標準差：30.0`
# 5. 印出結論：`B 組數據更分散`
#
# **預期輸出**：
# ```
# A 組標準差：0.0
# B 組標準差：30.0
# B 組數據更分散
# ```

# %%
# TODO: 匯入 statistics 模組


# TODO: 建立兩組數據


# TODO: 計算兩組的標準差


# TODO: 印出結果（四捨五入到小數點 2 位）並比較

# %% [markdown]
# ## 題目 15：綜合統計 - 一次計算四個統計值
#
# **要求**：
# 1. 匯入 `statistics` 模組
# 2. 建立數據：`scores = [65, 70, 70, 75, 80, 85, 85, 85, 90, 95]`
# 3. 計算並印出四個統計值（適當四捨五入）：
#    - 平均值（mean）
#    - 中位數（median）
#    - 眾數（mode）
#    - 標準差（stdev）
# 4. 輸出格式：
#    ```
#    === 成績統計報告 ===
#    平均值：80.0
#    中位數：82.5
#    眾數：85
#    標準差：9.72
#    ```
#
# **預期輸出**：
# ```
# === 成績統計報告 ===
# 平均值：80.0
# 中位數：82.5
# 眾數：85
# 標準差：9.72
# ```

# %%
# TODO: 匯入 statistics 模組


# TODO: 建立數據


# TODO: 計算四個統計值


# TODO: 印出報告（格式如上）

# %% [markdown]
# ## 題目 16：randint - 模擬擲骰子
#
# **要求**：
# 1. 匯入 `random` 模組
# 2. 使用 `random.randint(1, 6)` 模擬擲一顆骰子
# 3. 印出結果（格式：`🎲 擲骰子結果：3`）
# 4. 執行 5 次，觀察每次結果是否不同
#
# **預期輸出**（每次執行結果都不同）：
# ```
# 🎲 擲骰子結果：3
# ```

# %%
# TODO: 匯入 random 模組


# TODO: 擲骰子並印出結果

# %% [markdown]
# ## 題目 17：choice - 隨機選擇
#
# **要求**：
# 1. 匯入 `random` 模組
# 2. 建立清單：`fruits = ['蘋果', '香蕉', '橘子', '草莓', '芒果']`
# 3. 使用 `random.choice()` 隨機選一個水果
# 4. 印出結果（格式：`今天吃：🍎 蘋果`）
#
# **預期輸出**（每次執行結果都不同）：
# ```
# 今天吃：🍎 蘋果
# ```

# %%
# TODO: 匯入 random 模組


# TODO: 建立水果清單


# TODO: 隨機選一個水果並印出

# %% [markdown]
# ## 題目 18：uniform - 隨機浮點數
#
# **要求**：
# 1. 匯入 `random` 模組
# 2. 使用 `random.uniform(5.0, 10.0)` 生成一個 5.0 到 10.0 之間的隨機浮點數
# 3. 四捨五入到小數點後 2 位
# 4. 印出結果（格式：`隨機溫度：7.23°C`）
#
# **預期輸出**（每次執行結果都不同）：
# ```
# 隨機溫度：7.23°C
# ```

# %%
# TODO: 匯入 random 模組


# TODO: 生成 5.0~10.0 的隨機浮點數


# TODO: 四捨五入到小數點 2 位並印出

# %% [markdown]
# ## 題目 19：random - 模擬中獎機率
#
# **要求**：
# 1. 匯入 `random` 模組
# 2. 使用 `random.random()` 生成一個 0.0 到 1.0 的隨機數
# 3. 如果這個數 < 0.3（30% 機率），印出 `🎉 恭喜中獎！`
# 4. 否則印出 `😢 差一點，再試試！`
# 5. 執行多次，觀察中獎機率
#
# **預期輸出**（每次執行結果都不同）：
# ```
# 🎉 恭喜中獎！
# ```
# 或
# ```
# 😢 差一點，再試試！
# ```

# %%
# TODO: 匯入 random 模組


# TODO: 生成隨機數並判斷是否中獎（< 0.3）


# TODO: 印出結果

# %% [markdown]
# ## 題目 20：自訂模組 - 建立並使用 mymodule.py
#
# **要求**：
# 1. 建立一個 `mymodule.py` 檔案（使用 Python 寫入檔案方式）
# 2. 在 `mymodule.py` 中定義：
#    - 變數：`school = 'JWClub'`
#    - 清單：`courses = ['Python', 'JavaScript', 'Java']`
# 3. 在下方 code cell 中：
#    - import mymodule
#    - 印出 `mymodule.school`
#    - 印出 `mymodule.courses` 的內容（用迴圈印出每個課程）
# 4. 輸出格式：
#    ```
#    學校：JWClub
#    課程列表：
#      - Python
#      - JavaScript
#      - Java
#    ```
#
# **預期輸出**：
# ```
# 學校：JWClub
# 課程列表：
#   - Python
#   - JavaScript
#   - Java
# ```

# %%
# TODO: 建立 mymodule.py 檔案（使用 with open 寫入）
# 內容：
#   school = 'JWClub'
#   courses = ['Python', 'JavaScript', 'Java']


# TODO: import mymodule


# TODO: 印出 mymodule.school


# TODO: 用迴圈印出 mymodule.courses 的每個課程

# %% [markdown]
# ---
#
# ## 🌟 加分挑戰：隨機成績統計分析器
#
# **任務說明**：
# 結合 `random` 和 `statistics` 模組，製作一個隨機成績生成與統計分析程式。
#
# **要求**：
# 1. 匯入 `random` 和 `statistics` 模組
# 2. 使用 `random.randint(60, 100)` 生成 30 筆隨機成績（存入清單）
# 3. 計算並印出以下統計值（適當四捨五入）：
#    - 平均分數
#    - 中位數
#    - 標準差
#    - 最高分（提示：使用 `max()`）
#    - 最低分（提示：使用 `min()`）
# 4. 額外分析：
#    - 計算及格人數（>= 60）
#    - 計算優秀人數（>= 80）
# 5. 輸出格式範例：
#    ```
#    === 隨機成績統計分析 ===
#    生成成績數量：30 筆
#
#    統計結果：
#    平均分數：78.53
#    中位數：79.5
#    標準差：12.45
#    最高分：98
#    最低分：61
#
#    分析報告：
#    及格人數（>= 60）：30 人
#    優秀人數（>= 80）：12 人
#    優秀比例：40.0%
#    ```
#
# **挑戰重點**：
# - 結合兩個模組的功能
# - 使用清單推導式或迴圈生成數據
# - 綜合運用統計函式
# - 格式化輸出清晰易讀
#
# **作答區** ↓

# %%
# TODO: 匯入 random 和 statistics 模組


# TODO: 生成 30 筆隨機成績（60~100）


# TODO: 計算統計值


# TODO: 計算及格人數和優秀人數


# TODO: 印出完整報告

# %% [markdown]
# ---
#
# ## ✅ 完成檢查表
#
# 在完成所有題目後，請確認：
#
# - [ ] 題目 1-4：import 相關（4 題）
# - [ ] 題目 5-10：math 模組（6 題）
# - [ ] 題目 11-15：statistics 模組（5 題）
# - [ ] 題目 16-19：random 模組（4 題）
# - [ ] 題目 20：自訂模組（1 題）
# - [ ] 加分挑戰：綜合應用
#
# **自我評估**：
# - 完成 18-20 題 + 挑戰題：優秀！你已精通模組使用 🌟
# - 完成 15-17 題：良好！繼續加油 👍
# - 完成 12-14 題：及格！建議多練習 ✓
# - < 12 題：建議重新複習教學內容，再回來挑戰 📚
#
# ---
#
# ## 🎯 學習重點回顧
#
# 透過這 20 題練習，你應該已經掌握：
#
# ✅ **import 用法**：基本匯入、as 縮寫、使用模組變數與函式
# ✅ **math 模組**：sqrt、pi、floor/ceil、pow、sin/cos、fabs
# ✅ **statistics 模組**：mean、median、mode、stdev
# ✅ **random 模組**：randint、random、uniform、choice
# ✅ **自訂模組**：建立 .py 檔並 import 使用
#
# **下一步建議**：
# 1. 複習做錯的題目
# 2. 探索更多模組功能（查看官方文件）
# 3. 嘗試在實際專案中應用這些模組
# 4. 建立自己的工具模組庫
#
# 加油！💪
